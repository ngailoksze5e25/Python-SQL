# %% [markdown]
# ## Import Libraries

# %%
import tkinter as tk # Library of the UI
import pandas as pd # Hold dataframe (Simulate Database)
from PIL import Image, ImageTk # Import Images
import os # Operating System
import tkinter.font as tkFont
from countries import * # Import list of countries
import datetime # Get date of today
import math
import smtplib
import time, re
from email import encoders
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.image import MIMEImage
from email.mime.base import MIMEBase


##### not added when submitted
! pip install cx_Oracle

class connection:
    def __init__(self):
        import io
        import base64
        from urllib.request import urlopen

        import os
        os.chdir("")
        import cx_Oracle

        dsn_tns = cx_Oracle.makedsn('','',service_name='')
        conn = cx_Oracle.connect(user=r'',password='',dsn=dsn_tns)
        self.c = conn.cursor()

connection()
# Out:
# ...
# WARNING: You are using pip version 20.0.2; however, version 20.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3.8 -m pip install --upgrade pip' command.

# %%
smtpserver = smtplib.SMTP("smtp.gmail.com", 587)
smtpserver.ehlo()
smtpserver.starttls()
smtpserver.ehlo()
smtpserver.login('eshop.grp204@gmail.com', 'eshop204')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bfb7a9dd2ed9> in <module>
# ----> 1 smtpserver = smtplib.SMTP("smtp.gmail.com", 587)
#       2 smtpserver.ehlo()
#       3 smtpserver.starttls()
#       4 smtpserver.ehlo()
#       5 smtpserver.login('eshop.grp204@gmail.com', 'eshop204')
#
# NameError: name 'smtplib' is not defined

# %% [markdown]
# ## Main Page

# %%
class Main_Page:
    
    def __init__(self):
        self.root = tk.Tk()
        self.root.geometry('850x600')
        self.root.title("Welcome")
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
    
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).\
        place(x = 270, y = 30)
        label_Introduction = tk.Label(self.root, text = "Welcome", width = 20, font = self.bodytext,\
                                      fg = 'blue').place(x = 340, y = 70)

        # Company Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # UST Logo
        self.logo2 = Image.open(get_image('UST_logo.png')) 
        self.logo2 = self.logo2.resize((140, 100), Image.ANTIALIAS)
        self.photo_logo2 = ImageTk.PhotoImage(self.logo2)
        label_Logo2 = tk.Label(image = self.photo_logo2)
        label_Logo2.place(x = 680,y = 0)
        
        # Background
        self.label_bg = tk.Label()
        self.label_bg.place(x = 0, y = 110)
        
        
        self.bg_ls = os.listdir('Image/Background')
        pattern = re.compile("^\.")
        for i in self.bg_ls:
            if pattern.match(i) is not None:
                self.bg_ls.remove(i)
        
        self.active = True; self.pointer = 0

        # Buttons
        But_Add = tk.Button(self.root, text = "Staff Login", width = 20, bg = 'black', fg = 'red', command\
                            = self.staff).place(x = 345, y = 510)
        But_Back = tk.Button(self.root, text = "Member Login", width = 20, bg = 'black',\
                             fg = 'black', command = self.member).place(x = 345, y = 470)
        But_S = tk.Button(self.root, width = 1, bg = 'black',\
                             fg = 'black', command = self.s).place(x = 840, y = 575)

        self.change_active()
        self.root.mainloop()

    def bg_update(self):
        self.bg = Image.open(get_image('Background/' + self.bg_ls[self.pointer])) 
        self.bg = self.bg.resize((850, 490), Image.ANTIALIAS)
        self.photo_bg = ImageTk.PhotoImage(self.bg)
        self.label_bg.configure(image = self.photo_bg)

        if self.pointer < len(self.bg_ls) - 1: self.pointer += 1
        else: self.pointer = 0

    def change_active(self):
        if self.active:
            self.bg_update()
            self.root.after(4000, self.change_active) # changed from 10ms to 30ms
 
    def staff(self):
        self.root.destroy()
        Staff_Login_Class()
    
    def member(self):
        self.root.destroy()
        MEM_Login_Class()
        
    def s(self):
        self.root.destroy()
        s()

# %%
class s:
    
    def __init__(self):
        self.root = tk.Tk()
        self.root.geometry('850x600')
        self.root.title("Happy Birthday!!!")
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
    
        label_CName = tk.Label(self.root, text = "Happy Birthday Cherry!!!", font = self.CNametext, fg = 'red').\
        place(x = 270, y = 50)

        # Background
        self.label_bg = tk.Label()
        self.label_bg.place(x = 0, y = 110)
        
        self.bg_ls = os.listdir('Image/S')
        pattern = re.compile("^\.")
        for i in self.bg_ls:
            if pattern.match(i) is not None:
                self.bg_ls.remove(i)
        
        self.active = True; self.pointer = 0

        self.change_active()
        self.root.mainloop()

    def bg_update(self):
        self.bg = Image.open(get_image('S/' + self.bg_ls[self.pointer])) 
        if self.bg_ls[self.pointer] == 'u2.jpeg':
            self.bg = self.bg.resize((200, 490), Image.ANTIALIAS)
            self.label_bg.place(x = 500, y = 110)
        elif self.bg_ls[self.pointer] == 'pic2.jpeg':
            self.bg = self.bg.resize((400, 490), Image.ANTIALIAS)
            self.label_bg.place(x = 200, y = 110)
        else:
            self.bg = self.bg.resize((850, 490), Image.ANTIALIAS)
            self.label_bg.place(x = 0, y = 110)
        self.photo_bg = ImageTk.PhotoImage(self.bg)
        self.label_bg.configure(image = self.photo_bg)

        if self.pointer < len(self.bg_ls) - 1: self.pointer += 1
        else: self.pointer = 0
            
    def change_active(self):
        if self.active:
            self.bg_update()
            self.root.after(4000, self.change_active) # changed from 10ms to 30ms

# %% [markdown]
# ## Global Helper funcitons

# %%
def get_image(Image_Name):
    filename = os.getcwd() + "/Image/" + Image_Name
    return filename

def Varchar_len_check(target, length):
    if type(target) == str:
        if len(target) <= length: return True
        else: return False
    else: return False
    
def Numeric_value_check(target, check, func):
    if type(target) == int:
        if func == 'max':
            if target <= check: return True
            else: return False
        elif func == 'min':
            if target >= check: return True
            else: return False
    else: return False
    
def Numeric_len_check(target, scale, percision = 0):
    if type(target) == int or type(target) == float:
        str_target = str(target)
        if '.' in str_target:
            if len(str_target) - 1 <= scale and len(str_target.split('.')[1]) <= percision: return True
            else: return False
        else:
            if len(str_target) <= scale: return True
            else: return False
    else: return False
    
def isempty(*target):
    for i in target:
        if i == "": return True
    else: return False
  
def welcome_email(Fname, Lname, password, username, email, Mname = ''):
    
    if Mname == '': name = Fname + ' ' + Lname
    else: name = Fname + ' ' + Mname + ' ' + Lname
        
    mail_content = '''Dear {},

        Thank you for register account in e-shop. Your username and password are {} and {} respectively.
        
        Please kindly keep them in a secure place. Thank you!
        
    Best Regards,
    e-shop - Team 204
        '''.format(name, username, password)

    # The mail addresses and password
    sender_address = 'eshop.grp204@gmail.com'
    sender_pass = 'eshop204'
    receiver_address = email
    # Setup the MIME
    message = MIMEMultipart()
    message['From'] = sender_address
    message['To'] = receiver_address
    message['Subject'] = '[Important] Succuessful Registration on e-shop'   # The subject line
    # The body and the attachments for the mail
    message.attach(MIMEText(mail_content, 'plain'))
    # Create SMTP session for sending the mail
    session = smtplib.SMTP('smtp.gmail.com', 587) #use gmail with port
    session.starttls() #enable security
    session.login(sender_address, sender_pass) #login with mail_id and password
    text = message.as_string()
    session.sendmail(sender_address, receiver_address, text)
    session.quit()
    print('Mail Sent')

def password_email(Fname, Lname, password, email, Mname = None):
    
    if Mname == None: name = Fname + ' ' + Lname
    else: name = Fname + ' ' + Mname + ' ' + Lname
        
    mail_content = '''Dear {},

        Thank you for supporting e-shop. We tracked that you have request the password in our system. Your password is {}.

        Please kindly ignore this email if you are not initiating the email.

    Best Regards,
    e-shop - Team 204
        '''.format(name, password)

    # The mail addresses and password
    sender_address = 'eshop.grp204@gmail.com'
    sender_pass = 'eshop204'
    receiver_address = email
    # Setup the MIME
    message = MIMEMultipart()
    message['From'] = sender_address
    message['To'] = receiver_address
    message['Subject'] = '[Important] Password Retreival'   #The subject line
    # The body and the attachments for the mail
    message.attach(MIMEText(mail_content, 'plain'))
    # Attach the Company Logo
#     with open(get_image('logo.jpg'), 'rb') as fp:
#         img = MIMEImage(fp.read())
#         img.add_header('Company Logo', 'attachment', filename = "logo.jpg")
#         message.attach(img)
    # Create SMTP session for sending the mail
    session = smtplib.SMTP("smtp.gmail.com", 587) # use gmail with port
    session.starttls() # enable security
    try:
        session.login(sender_address, sender_pass) # login with mail_id and password
        text = message.as_string()
        session.sendmail(sender_address, receiver_address, text)
        session.quit()
        print('Mail Sent')
    except:
        print('Error')

# %% [markdown]
# ## Entry Point

# %%
Main_Page()

# %% [markdown]
# ## UI Pages Definitions

# %% [markdown]
# ### Staff

# %% [markdown]
# #### Product Insert Page [Finished]

# %%
class Insert_Pro_Class:
    
    def __init__(self, identity):
        self.root = tk.Tk()
        self.root.geometry('1000x450')
        self.root.title("Product Insert Page")
        self.identity = identity
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Declare Variables
        self.ProName = tk.StringVar()
        self.AVA = tk.IntVar()
        self.Price = tk.StringVar()  
        self.Origin = tk.StringVar() 
        self.Brand = tk.StringVar()
        self.Inventory = tk.StringVar()
        self.DiscountR = tk.StringVar()
        self.Description = tk.StringVar()
        self.errorMessage = tk.StringVar()
        self.errorMessage.set('')
        
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).\
        place(x = 270, y = 30)
        label_Introduction = tk.Label(self.root, text = "New Product", width = 20, font = self.bodytext,\
                                      fg = 'blue').place(x = 340, y = 70)

        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # error Message Label
        tk.Label(self.root,textvariable=self.errorMessage,font=self.bodytext,fg='red').place(x=400,y=280)

        # Product
        tk.Label(self.root, text = "Product Name*", width = 20, font = ("bold", 15)).place(x = 30, y = 130)
        entry_ProName = tk.Entry(self.root, textvariable = self.ProName)
        entry_ProName.place(x = 200, y = 130)

        # AVA
        tk.Label(self.root, text = "Availability*", width = 20, font = ("bold", 15)).place(x = 400, y = 130)
        entry_AVA = tk.Checkbutton(self.root, text = "Yes", variable = self.AVA)
        entry_AVA.place(x = 570, y = 130)
        
        # Price
        tk.Label(self.root, text = "Price*", width = 20, font = ("bold", 15)).place(x = 30,y = 170)
        entry_Price = tk.Entry(self.root, textvariable = self.Price)
        entry_Price.place(x = 200, y = 170)

        # Origin
        tk.Label(self.root, text = "Origin*", width = 20, font = ("bold", 15)).place(x = 400,y = 170)
        entry_Origin = tk.Entry(self.root, textvariable = self.Origin)
        entry_Origin.place(x = 570,y = 170)

        # Brand
        tk.Label(self.root, text = "Brand*", width = 20, font = ("bold", 15)).place(x = 30,y = 210)
        entry_Brand = tk.Entry(self.root, textvariable = self.Brand)
        entry_Brand.place(x = 200,y = 210)

        # Inventory
        tk.Label(self.root, text = "Inventory*", width = 20, font = ("bold", 15)).place(x = 400,y = 210)
        entry_Inventory = tk.Entry(self.root, textvariable = self.Inventory)
        entry_Inventory.place(x = 570,y = 210)       
     
        # Discount Rate
        tk.Label(self.root, text = "Discount Rate*", width = 20, font = ("bold", 15)).place(x = 30,y = 250)
        entry_DiscountR = tk.Entry(self.root, textvariable = self.DiscountR)
        entry_DiscountR.place(x = 200,y = 250)
        
        # Description
        tk.Label(self.root, text = "Description", width = 20, font = ("bold", 15)).place(x = 400,y = 250)
        entry_Description = tk.Entry(self.root, textvariable = self.Description)
        entry_Description.place(x = 570,y = 250)

        # Buttons
        But_Add = tk.Button(self.root, text = "Add", width = 20, bg = 'black', fg = 'red', command\
                            = self.insert_pro).place(x = 345, y = 320)
        But_Back = tk.Button(self.root, text = "Back to Staff DashBoard", width = 20, bg = 'black',\
                             fg = 'black', command = self.back).place(x = 345, y = 360)

        self.root.mainloop()
        
    def back(self):
        self.root.destroy()
        if self.identity == 'Manager': MAN_Dashboard_Class()
        else: Staff_Dashboard_Class()
        
    def insert_pro(self): # Final Version of insert pro
        # Convert type and get data and prevent type conversion error
        self.ProName_info = self.ProName.get()
        self.AVA_info = self.AVA.get()
        self.Price_info = self.Price.get()
        self.Brand_info = self.Brand.get()
        self.Inventory_info = self.Inventory.get()
        self.Origin_info = self.Origin.get()
        self.DiscountR_info = self.DiscountR.get()
        if (self.ProName_info == '' or self.AVA_info == '' or self.ProName_info == '' or
           self.Price_info == '' or self.Brand_info == '' or self.Inventory_info =='') ==True:
            self.errorMessage.set('Entries with "*" cannot be blank.')
            return
        
        # get description coz it can be null
        self.Description_info = self.Description.get()
        
        # check discount rate
        try:
            round(float(self.DiscountR_info), 2)
            if (round(float(self.DiscountR_info), 2)) > 100 or round(float(self.DiscountR_info), 2) < 0: 
                self.errorMessage.set('The discount rate is out of range.')
                return
            else: 
                self.DiscountR_info = round(float(self.DiscountR_info), 2)
        except:
            if self.DiscountR_info[-1] == '%':
                try:
                    round(float(self.DiscountR_info[:-1]), 2)
                    if (round(float(self.DiscountR_info[:-1]), 2)) > 100 or round(float(self.DiscountR_info[:-1]), 2) < 0: 
                        sel.errorMessage.set('The discount rate out of range')
                        return
                    else: 
                        self.DiscountR_info = round(float(self.DiscountR_info[:-1]), 2)
                except: 
                    self.errorMessage.set('The discount input is not a numerical number')
                    return      
            else: 
                self.errorMessage.set('The discount input is not a numerical number')
                return
        
        # Check invalid length
        if Varchar_len_check(self.ProName_info, 20) == False :
            self.errorMessage.set('Product Name cannot exceed 20 characters')
            return
        if Varchar_len_check(self.Origin_info, 74) == False:
            self.errorMessage.set('Origin country cannot exceed 74 characters')
            return
        if Varchar_len_check(self.Brand_info, 30) == False:
            self.errorMessage.set('Brand Name cannot exceed 30 characters')
            return
        if Varchar_len_check(self.Description_info, 200) == False:
            self.errorMessage.set('Description cannot exceed 200 characters')
            return
        
        # inventory check
        try:
            isinstance(self.Inventory_info,int)
        except:
            self.errorMessage.set('Your inventory input is not valid')
            return
        
        if Varchar_len_check(self.Inventory_info,5) == False :
            self.errorMessage.set('Inventory amount cannot be added by more than 99999')
            return
        
        # price check
        try:
            isinstance(int(float(self.Price_info)),int) or isinstance(float(self.Price_info),float)
            if isinstance(int(float(self.Price_info)),int) == False and isinstance(self.Price_info,float) == False:
                self.errorMessage.set('This is not a valid price input.')
                return
            else:
                if int(self.Price_info[0]) == 0 and self.Price_info[1] != '.':
                    self.errorMessage.set('cannot have zero at beginning')
                    return
                else: self.Price_info = round(float(self.Price_info),2)
        except:
            self.errorMessage.set('This is not a valid price input.')
            return 
        
        # check price length
        if Numeric_len_check(round(float(self.Price_info),2), 8, 2) == False:
            self.errorMessage.set('Maximum number of digits for price is 8 in integer and 2 in decimal places')
            return
        
        if '.' in str(self.Inventory_info):
            self.errorMessage.set('No decimal places allowed in Inventory')
            return
        try:
            round(float(self.Inventory_info),2)
            self.Inventory_info = int(self.Inventory_info)
        except:
            self.errorMessage.set('Inventory input is not valid')
            return
        
        # Clear all previous input
        self.ProName.set(''); self.Price.set(0); self.Origin.set(''); self.Brand.set('')
        self.Inventory.set(0); self.DiscountR.set(0); self.Description.set('')
        # Calculate the Product ID    
        connect = connection()
        
        connect.c.execute(
            """
              SELECT PRO_ID 
              FROM PRODUCT
            """)

        ls_ID = []
        for row in connect.c:
            ls_ID.append(int(row[0]))
        for i in range(len(ls_ID) + 1):
            if i not in ls_ID:
                Pro_ID = i
                break

        connect.c.execute(
            """
              INSERT INTO PRODUCT 
              VALUES ('{}', '{}', {}, {}, '{}', {}, '{}', {}, '{}')
            """.format(Pro_ID, self.ProName_info, self.AVA_info, self.Price_info, self.Brand_info,
                       self.Inventory_info, self.Origin_info, self.DiscountR_info, self.Description_info))
            
        connect.c.execute("commit")
        connect.c.close()
        self.errorMessage.set('Product successfully added.')

# %% [markdown]
# #### Product Edit Page [Finished]

# %%
class Edit_Pro_Class:
    
    def __init__(self, Identity):
        self.root = tk.Tk()
        self.root.geometry('930x450')
        self.root.title("Product Edit Page")
        self.identity = Identity
        self.errorMessage = tk.StringVar()
        self.errorMessage.set('')
        self.retrieve_Pro_Name()

        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Declare Variables
        self.ProName = tk.StringVar(); self.AVA = tk.IntVar(); self.Price = tk.StringVar(); self.PNAME = tk.StringVar() 
        self.Origin = tk.StringVar() ; self.Brand = tk.StringVar(); self.Inventory = tk.StringVar()
        self.DiscountR = tk.StringVar(); self.Description = tk.StringVar(); self.choose_ProName = tk.StringVar()
    
        tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 30)
        tk.Label(self.root, text = "Edit Product", width = 20, font = self.bodytext, fg = 'blue').place(x = 30, y = 70)

        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Embush error message
        tk.Label(self.root,textvariable=self.errorMessage,font=self.bodytext,fg='red').place(x=500,y=320);
        self.errorMessage.set('')
        
        # Product Selection
        tk.Label(self.root, text = "Select Product*", width = 20, font = ("bold", 15)).place(x = 30, y = 130)
        self.droplist_Product = tk.OptionMenu(self.root, self.choose_ProName, *self.value)
        self.droplist_Product.config(width = 15)
        self.choose_ProName.set('Select Product') 
        self.droplist_Product.place(x = 200, y = 130)

        # Product Name
        tk.Label(self.root, text = "Product Name*", width = 20, font = ("bold", 15)).place(x = 30, y = 170)
        entry_PNAME = tk.Entry(self.root, textvariable = self.PNAME)
        entry_PNAME.place(x = 200, y = 170)
        
        # AVA
        label_AVA = tk.Label(self.root, text = "Availability*", width = 20, font = ("bold", 15)).place(x = 400, y = 170)
        entry_AVA = tk.Checkbutton(self.root, text = "Yes", variable = self.AVA)
        entry_AVA.place(x = 570, y = 170)
        
        # Price
        label_Price = tk.Label(self.root, text = "Price*", width = 20, font = ("bold", 15)).place(x = 30,y = 210)
        entry_Price = tk.Entry(self.root, textvariable = self.Price)
        entry_Price.place(x = 200, y = 210)

        # Origin
        label_Origin = tk.Label(self.root, text = "Origin*", width = 20, font = ("bold", 15)).place(x = 400,y = 210)
        entry_Origin = tk.Entry(self.root, textvariable = self.Origin)
        entry_Origin.place(x = 570,y = 210)

        # Brand
        label_Brand = tk.Label(self.root, text = "Brand*", width = 20, font = ("bold", 15)).place(x = 30,y = 250)
        entry_Brand = tk.Entry(self.root, textvariable = self.Brand)
        entry_Brand.place(x = 200,y = 250)

        # Inventory
        label_Inventory = tk.Label(self.root, text = "Inventory*", width = 20, font = ("bold", 15)).place(x = 400,y = 250)
        entry_Inventory = tk.Entry(self.root, textvariable = self.Inventory)
        entry_Inventory.place(x = 570,y = 250)       
     
        # Discount Rate
        label_DiscountR = tk.Label(self.root, text = "Discount Rate", width = 20, font = ("bold", 15)).place(x = 30,y = 290)
        entry_DiscountR = tk.Entry(self.root, textvariable = self.DiscountR)
        entry_DiscountR.place(x = 200,y = 290)
        
        # Description
        label_Description = tk.Label(self.root, text = "Description", width = 20, font = ("bold", 15)).place(x = 400,y = 290)
        entry_Description = tk.Entry(self.root, textvariable = self.Description)
        entry_Description.place(x = 570,y = 290)

        # Buttons
        tk.Button(self.root, text = "Retrieve", width = 7, fg = 'red', command = self.retrieve_others).place(x = 370,y = 130)
        tk.Button(self.root, text = "Edit and Save", width = 20, fg = 'red', command = self.edit_pro).place(x = 345,y = 360)
        tk.Button(self.root, text = "Back to Staff DashBoard", width = 20, fg = 'black', command = self.back).place(x = 345,y = 400)

        self.root.mainloop()
        
    def retrieve_Pro_Name(self):
        
        connect = connection()
        connect.c.execute(
            """
              SELECT PRO_NAME 
              FROM PRODUCT
            """)
        
        self.value = []
        for row in connect.c:
            self.value.append(row[0])
        
        connect.c.close()
        
        if len(self.value) == 0: self.value = ['N/A']
    
    def retrieve_others(self):
        self.chosen = self.choose_ProName.get()
        if self.chosen == 'Select Product':
            self.errorMessage.set('Please choose a product.')
            return
        self.errorMessage.set('')
        connect = connection()
        connect.c.execute(
            """
              SELECT PRO_NAME, PRO_PRICE, PRO_BRAND, PRO_ORIGIN, PRO_AVA, PRO_INVENTORY, PRO_DISCOUNT_RATE, PRO_SPECIFICATIONS, PRO_ID
              FROM PRODUCT
              WHERE PRO_NAME = '{}'
            """.format(self.choose_ProName.get()))
        
        for row in connect.c:
            self.pname = row[0]
            self.price = row[1]
            self.brand = row[2]
            self.origin = row[3]
            self.ava = row[4]
            self.inventory = row[5]
            self.discountr = row[6]
            self.specification = row[7]
            self.PRO_ID = row[8]
            
        connect.c.close()
        
 
        # Assign the value back to the entry
        self.PNAME.set(self.pname); self.Price.set(self.price); self.Origin.set(self.origin)
        self.AVA.set(self.ava); self.Brand.set(self.brand); self.Inventory.set(self.inventory)
        self.DiscountR.set(self.discountr); self.Description.set(self.specification)
        
        if self.specification == None:
            self.Description.set('')
            
    def edit_pro(self): # Final Version of insert pro
        self.ProName_info = self.PNAME.get()
        self.AVA_info = self.AVA.get()
        self.Price_info = self.Price.get()
        self.Brand_info = self.Brand.get()
        self.Inventory_info = self.Inventory.get()
        self.Origin_info = self.Origin.get()
        self.DiscountR_info = self.DiscountR.get()
        self.Description_info = self.Description.get()
        
        if (self.ProName_info == '' or self.AVA_info == '' or self.Price_info=='' or self.Brand_info==''
           or self.Inventory_info=='' or self.Origin_info==''):
            self.errorMessage.set('* Items should not be left empty.')
            return
        
        ## discount and description are nullable
        
        # check discount rate
        try:
            round(float(self.DiscountR_info), 2)
            if (round(float(self.DiscountR_info), 2)) > 100 or round(float(self.DiscountR_info), 2) < 0: 
                self.errorMessage.set('The discount rate is out of range.')
                return
            else: 
                self.DiscountR_info = round(float(self.DiscountR_info), 2)
        except:
            if self.DiscountR_info[-1] == '%':
                try:
                    round(float(self.DiscountR_info[:-1]), 2)
                    if (round(float(self.DiscountR_info[:-1]), 2)) > 100 or round(float(self.DiscountR_info[:-1]), 2) < 0: 
                        sel.errorMessage.set('The discount rate out of range')
                        return
                    else: 
                        self.DiscountR_info = round(float(self.DiscountR_info[:-1]), 2)
                except: 
                    self.errorMessage.set('The discount input is not a numerical number')
                    return      
            else: 
                self.errorMessage.set('The discount input is not a numerical number')
                return
        
        # Check invalid length
        if Varchar_len_check(self.ProName_info, 20) == False:
            self.errorMessage.set('Product Name cannot exceed 20 characters')
            return
        if Varchar_len_check(self.Origin_info, 74) == False:
            self.errorMessage.set('Origin country cannot exceed 74 characters')
            return
        if Varchar_len_check(self.Brand_info, 30) == False:
            self.errorMessage.set('Brand Name cannot exceed 30 characters')
            return
        if Varchar_len_check(self.Description_info, 200) == False:
            self.errorMessage.set('Description cannot exceed 200 characters')
            return
        # inventory check
        try:
            isinstance(self.Inventory_info,int)
        except:
            self.errorMessage.set('Your inventory input is not valid')
            return
        
        # price check
        try:
            isinstance(int(float(self.Price_info)),int) or isinstance(float(self.Price_info),float)
            if isinstance(int(float(self.Price_info)),int) == False and isinstance(self.Price_info,float) == False:
                self.errorMessage.set('This is not a valid price input.')
                return
            else:
                if int(self.Price_info[0]) == 0 and self.Price_info[1] != '.':
                    self.errorMessage.set('cannot have zero at beginning')
                    return
                else: self.Price_info = round(float(self.Price_info),2)
        except:
            self.errorMessage.set('This is not a valid price input.')
            return 
        
        # check price length
        if Numeric_len_check(round(float(self.Price_info),2), 8, 2) == False:
            self.errorMessage.set('Number of digits for price integer is 8.')
            return
        
        # inventory check 
        if '.' in str(self.Inventory_info):
            self.errorMessage.set('No decimal place is allowed in inventory')
            return
        if '-' in str(self.Inventory_info):
            self.errorMessage.set('No character is allowed in inventory')
            return
            
        try:
            isinstance(int(self.Inventory_info),int) == False
        except:
            self.errorMessage.set('Inventory entry must be an integer.')
            return
        if len(str(self.Inventory_info)) > 5:
            self.errorMessage.set('Digits of inventory cannot exceed 5')
            return
        
        try:
            round(float(self.Inventory_info),2)
            self.Inventory_info = int(self.Inventory_info)
        except:
            self.errorMessage.set('Inventory input is not valid')
            return
        
        connect = connection()
        connect.c.execute(
            """
              UPDATE PRODUCT 
              SET PRO_NAME = '{}', 
                  PRO_AVA = {},
                  PRO_PRICE = {},
                  PRO_BRAND = '{}',
                  PRO_INVENTORY = '{}',
                  PRO_ORIGIN = '{}',
                  PRO_DISCOUNT_RATE = {},
                  PRO_SPECIFICATIONS ='{}'
              WHERE PRO_ID = '{}'
            """.format(self.ProName_info, self.AVA_info, self.Price_info, self.Brand_info, self.Inventory_info,
                       self.Origin_info, self.DiscountR_info, self.Description_info, self.PRO_ID))

        connect.c.execute("commit")
        connect.c.close()

        # Clear all previous input
        self.ProName.set(''); self.PNAME.set(''); self.Price.set(0); self.choose_ProName.set('Select Product')
        self.Origin.set(''); self.Brand.set(''); self.Inventory.set(0)
        self.DiscountR.set(0); self.Description.set(''); self.AVA.set(0)
        
        # change options
        m = self.droplist_Product.children['menu']
        m.delete(0, tk.END)
        self.retrieve_Pro_Name()
        newvalues = self.value
        for val in newvalues:
            m.add_command(label = val, command = lambda v = self.choose_ProName, l = val: v.set(l))
        self.errorMessage.set('Edit has been saved')
        
    def back(self):
        self.root.destroy()
        if self.identity == 'Manager': MAN_Dashboard_Class()
        else: Staff_Dashboard_Class()

# %% [markdown]
# #### Staff DashBoard

# %%
class Staff_Dashboard_Class:
    
    def __init__(self):
        self.root = tk.Tk()
        self.root.geometry('850x450')
        self.root.title("Staff Dashboard")
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 30)
        label_Introduction = tk.Label(self.root, text = "Staff DashBoard", width = 20, font = self.bodytext, fg = 'blue').place(x = 340, y = 70)

        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Buttons
        But_Add_Pro = tk.Button(self.root, text = "Press to Add New Product", width = 30, bg = 'black', fg = 'black',
                               command = self.add_pro).place(x = 300, y = 140)
        But_Edit_Pro = tk.Button(self.root, text = "Press to Edit Exisiting Product", width = 30, bg = 'black', fg = 'black',
                                command = self.edit_pro).place(x = 300, y = 190)
        But_Edit_Status = tk.Button(self.root, text = "Press to Edit Order Status", width = 30, bg = 'black', fg = 'black',
                                command = self.edit_ord_status).place(x = 300, y = 240)
            
        But_Exit = tk.Button(self.root, text = "Logout", width = 15, bg = 'black', fg = 'red',
                            command = self.logout).place(x = 650,y = 380)

   
        self.root.mainloop()
        
    def add_pro(self):
        self.root.destroy()
        Insert_Pro_Class('Staff')
        
    def edit_pro(self):
        self.root.destroy()
        Edit_Pro_Class('Staff')
            
    def edit_ord_status(self):
        self.root.destroy()
        Edit_order_status_page('Staff')
        
    def logout(self):
        self.root.destroy()
        Staff_Login_Class()

# %% [markdown]
# #### Manager DashBoard

# %%
class MAN_Dashboard_Class:
    
    def __init__(self):
        self.root = tk.Tk()
        self.root.geometry('850x450')
        self.root.title("Manager Dashboard")
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 30)
        label_Introduction = tk.Label(self.root, text = "Manager DashBoard", width = 20, font = self.bodytext, fg = 'blue').place(x = 340, y = 70)

        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Buttons
        But_Add_Pro = tk.Button(self.root, text = "Press to Add New Product", width = 30, bg = 'black', fg = 'black',
                               command = self.add_pro).place(x = 150,y = 120)
        But_5_Pop_Pro = tk.Button(self.root, text = "Press to Show 5 most popular product", width = 30, bg = 'black', fg = 'black',
                               command = self.five_pop_pro).place(x = 450,y = 120)
        But_Edit_Pro = tk.Button(self.root, text = "Press to Edit Exisiting Product", width = 30, bg = 'black', fg = 'black',
                                command = self.edit_pro).place(x = 150,y = 160)
        But_5_Top_Mem = tk.Button(self.root, text = "Press to Show the 5 top members", width = 30, bg = 'black', fg = 'black',
                                command = self.five_top_mem).place(x = 450,y = 160)
        But_DM_Sales = tk.Button(self.root, text = "Press to Show Daily / Monthly Sales", width = 30, bg = 'black', fg = 'black',
                                command = self.day_mon_sales).place(x = 150,y = 200)
        But_PRO_Qsold = tk.Button(self.root, text = "Press to Show products quantity sold", width = 30, bg = 'black', fg = 'black',
                                command = self.pro_qsold).place(x = 450,y = 200)
        But_ORD_today = tk.Button(self.root, text = "Press to Show all sales order today", width = 30, bg = 'black', fg = 'black',
                                command = self.ord_today).place(x = 150,y = 240)
        But_PRO_STOCKOUT = tk.Button(self.root, text = "Press to Show all stockout product", width = 30, bg = 'black', fg = 'black',
                                command = self.pro_stockout).place(x = 450,y = 240)
        But_Discount_P = tk.Button(self.root, text = "Press to Show Discount Product", width = 30, bg = 'black', fg = 'black',
                                command = self.discount_prodcut).place(x = 150, y = 280)
        But_Edit_Status = tk.Button(self.root, text = "Press to Edit Order Status", width = 30, bg = 'black', fg = 'black',
                                command = self.edit_ord_status).place(x = 450, y = 280)
        But_Edit_Status = tk.Button(self.root, text = "Press to View and Hide Comments", width = 30, bg = 'black', fg = 'black',
                                command = self.view_hide_comment).place(x = 150, y = 320)
        But_View_Status = tk.Button(self.root, text = "Press to View Number of Order By Status", width = 30, bg = 'black', fg = 'black',
                                command = self.view_by_status).place(x = 450, y = 320)
    
        But_Exit = tk.Button(self.root, text = "Logout", width = 15, bg = 'black', fg = 'red',
                            command = self.logout).place(x = 650,y = 380)

        self.root.mainloop()
            
    def add_pro(self):
        self.root.destroy()
        Insert_Pro_Class('Manager')
        
    def edit_pro(self):
        self.root.destroy()
        Edit_Pro_Class('Manager')
        
    def five_pop_pro(self):
        self.root.destroy()  
        Top5_Pro_Class()
        
    def five_top_mem(self):
        self.root.destroy()
        Top5_MEM_Class()
    
    def day_mon_sales(self):
        self.root.destroy() 
        Mon_Day_Sales_Class()
    
    def pro_qsold(self):
        self.root.destroy()
        Search_Product_Quantity()
                                  
    def ord_today(self):
        self.root.destroy()
        Order_of_Today()
    
    def pro_stockout(self):
        self.root.destroy()
        Show_StockOut_Class()
        
    def discount_prodcut(self):
        self.root.destroy()
        Discounted_Products_Class('Manager')
        
    def edit_ord_status(self):
        self.root.destroy()
        Edit_order_status_page('Manager')
        
    def view_hide_comment(self):
        self.root.destroy()
        View_Hide_Comment_Select_Product()
        
    def view_by_status(self):
        self.root.destroy()
        View_By_Status_All()
                                         
    def logout(self):
        self.root.destroy()
        Staff_Login_Class()

# %% [markdown]
# #### Staff Login Page

# %%
class Staff_Login_Class:
    
    def __init__(self):
        self.root = tk.Tk()
        self.root.geometry('850x450')
        self.root.title("Staff Login Page")
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Declare Variables
        self.UserName = tk.StringVar()
        self.PWD = tk.StringVar()
        
        # error message
        self.ErrorMessage = tk.StringVar(); self.ErrorMessage.set('')
        tk.Label(self.root, textvariable = self.ErrorMessage, fg='red',font="bold").place(x=370,y=290)
        
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 30)
        label_Introduction = tk.Label(self.root, text = "Staff Login Page", width = 20, font = self.bodytext, fg = 'blue').place(x = 340, y = 70)

        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Titles
        label_Login = tk.Label(self.root, text = "Login", font = self.Titletext).place(x = 400, y = 130)

        # UserName
        label_UserName = tk.Label(self.root, text = "Staff UserName:", font = self.bodytext).place(x = 260,y = 190)
        entry_UserName = tk.Entry(self.root, textvariable = self.UserName)
        entry_UserName.place(x = 420, y = 190) 
    
        
        # Password
        label_PWD = tk.Label(self.root, text = "Password:", font = self.bodytext).place(x = 260,y = 240)
        entry_PWD = tk.Entry(self.root, textvariable = self.PWD)
        entry_PWD.place(x = 420, y = 240) 
        
        # Button
        But_forget_pwd = tk.Button(self.root, text = "Forget Password", font = "bold", fg = 'red',
                                width = 20, command = self.forget_pwd).place(x = 350, y = 330)
        But_login = tk.Button(self.root, text = "Login", font = "bold", fg = 'orange', width = 20,
                                command = self.login).place(x = 350, y = 370)
        
        self.root.mainloop()
        
    def forget_pwd(self):
        self.root.destroy()
        Forget_PWD_Class('Staff')
        
    def login(self):
        
        self.UName_Entry = self.UserName.get()
        self.PWD_Entry = self.PWD.get()
        
        # Check whetehr is empty
        connect = connection()
        
        connect.c.execute("""
            SELECT STAFF_USERNAME FROM STAFF
        """)
        
        self.ls_UName = []
        for row in connect.c:
            self.ls_UName.append(row[0])
            
        # Error Case 3: username no value
        if isempty(self.UName_Entry) is True: 
            self.ErrorMessage.set("Please enter Username")
            return
        
        # Error Case 3: password no value
        if isempty(self.PWD_Entry) is True: 
            self.ErrorMessage.set("Please enter Password")
            return
        
        # Error Case 1: No match username
        if (self.UName_Entry not in self.ls_UName) == True:
            self.ErrorMessage.set("No such Username is found.")
            return
        
        connect.c.execute(
            """
                SELECT STAFF_ID, STAFF_PWD, STAFF_TITLE 
                FROM STAFF 
                WHERE STAFF_USERNAME = '{}'
            """.format(self.UName_Entry))

        for row in connect.c:
            self.retrievePWD = row[1]
            self.MEM_ID = row[0]
            self.identity = row[2]
        
        # Error Case 2: PWD and username doesn't match
        if (self.PWD_Entry != self.retrievePWD) == True:
            self.ErrorMessage.set("The Password does not match with the UserName")
            return

        if self.identity == 'Manager':
            self.root.destroy()
            MAN_Dashboard_Class()
        else: 
            self.root.destroy()
            Staff_Dashboard_Class()

# %% [markdown]
# ### Report

# %% [markdown]
# #### Monthly / Daily Sales Page [Finished]

# %%
class Mon_Day_Sales_Class:
    
    def __init__(self):
        self.root = tk.Tk()
        self.root.geometry('850x550')
        self.root.title("Monthly / Daily Sales")
        
        # Craete Variable
        self.Date = tk.StringVar()
        self.ErrorMessage = tk.StringVar()
        
        # Create background template
        canvas = tk.Canvas(self.root, width = 850, height = 450)
        canvas.place(x = 0, y = 0)
        line = canvas.create_line(425, 220, 425, 450)
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 30)
        label_Introduction = tk.Label(self.root, text = "Monthly / Daily Sales", width = 20, font = self.bodytext, fg = 'blue').place(x = 340, y = 70)

        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50, y = 0)
        
        # Title
        label_Daily = tk.Label(self.root, text = "Daily Sales", width = 20, font = self.Titletext).place(x = 80, y = 190)
        label_Monthly = tk.Label(self.root, text = "Monthly Sales", width = 20, font = self.Titletext).place(x = 500, y = 190)
        label_Input = tk.Label(self.root, text = "Please input the date in form of dd-mm-yyyy:", width = 50, font = self.bodytext).place(x = 120, y = 140)
        tk.Label(self.root, textvariable = self.ErrorMessage, width = 50, font = self.Titletext, fg = "red").place(x = 100, y = 110)
        tk.Entry(self.root, textvariable = self.Date).place(x = 550, y = 135)
        
        # Buttons
        But_Retreieve = tk.Button(self.root, text = "Retrieve", width = 20, bg = 'black', fg = 'black',
                               command = self.retrieve).place(x = 340, y = 480)

        But_Back = tk.Button(self.root, text = "Back to Dashboard", width = 15, bg = 'black', fg = 'black',
                            command = self.back).place(x = 650, y = 480)

        self.root.mainloop()
        
    def back(self):
        self.root.destroy()
        MAN_Dashboard_Class()
            
    def retrieve(self):

        
        connect = connection()
        self.Date.info = self.Date.get()
        
        # Check invalid input
        if  len(self.Date.info) != 10 or self.Date.info[2] != '-' or self.Date.info[5] != '-':
            self.ErrorMessage.set("Please enter in correct form")
            return
        try:
            if int(self.Date.info[0:2]) <= 0 or int(self.Date.info[0:2]) > 31: 
                self.ErrorMessage.set("Please enter in correct form")
                return
        except:
            self.ErrorMessage.set("Please enter in correct form")
            return
        try:
            if int(self.Date.info[3:5]) <= 0 or int(self.Date.info[3:5]) > 12: 
                self.ErrorMessage.set("Please enter in correct form")
                return
        except:
            self.ErrorMessage.set("Please enter in correct form")
            return
            
        
        self.ErrorMessage.set("")
        # Get Daily Transaction
        connect.c.execute(
            """
              SELECT ORD_DATE, ODL_TRAN_PRICE * ODL_QUANTITY
              FROM "ORDER", ORDER_LINE
            WHERE TO_CHAR(ORD_DATE, 'DD-MM-YYYY') = '{}' AND "ORDER".ORD_ID = ORDER_LINE.ORDER_ORD_ID
            """.format(self.Date.info))
        
        # Get the value of Daily Transaction
        ls_daily_tran = []
        for row in connect.c:
            ls_daily_tran.append(row[1])

        # Sum up and display the Daily Sales
        if len(ls_daily_tran) == 0:
            label_Daily_Sales = tk.Label(self.root, text = "$0", width = 20, font = self.Titletext).place(x = 80, y = 300)
        else:   
            label_Daily_Sales = tk.Label(self.root, text = "$" + str(sum(ls_daily_tran)), width = 20, font = self.Titletext).place(x = 80, y = 300)
        
        label_today_Date = tk.Label(self.root, text = "for {}-{}-{}".format(self.Date.info[0:2], self.Date.info[3:5], self.Date.info[6:]), width = 20, font = self.bodytext).place(x = 120, y = 350)
        
        # Get Monthly Transaction
        connect.c.execute(
            """
              SELECT ORD_DATE, ODL_TRAN_PRICE * ODL_QUANTITY
              FROM "ORDER", ORDER_LINE
              WHERE TO_CHAR(ORD_DATE, 'MM-YYYY') = '{}' AND "ORDER".ORD_ID = ORDER_LINE.ORDER_ORD_ID
            """.format(self.Date.info[3:]))
        
        
        # Get the value of Monthly Transaction
        ls_monthly_tran = []
        for row in connect.c:
            ls_monthly_tran.append(row[1])

        connect.c.close()
        
        if len(ls_monthly_tran) == 0:
            label_Monthly_Sales = tk.Label(self.root, text = "$0", width = 20, font = self.Titletext).place(x = 500, y = 300)
        else:   
            label_Monthly_Sales = tk.Label(self.root, text = "$" + str(round(sum(ls_monthly_tran), 2)), width = 20, font = self.Titletext).place(x = 500, y = 300)
        
        label_month_Date = tk.Label(self.root, text = "for {}-{}".format(self.Date.info[3:5], self.Date.info[6:]), width = 20, font = self.bodytext).place(x = 540, y = 350)

# %% [markdown]
# #### Top5_Pro_Class [Finished]

# %%
class Top5_Pro_Class:
    
    def __init__(self):
        self.root = tk.Tk()
        self.root.geometry('850x450')
        self.root.title("Top 5 Popular Products")
        self.pre_set()
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytextC = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        self.bodytext = tkFont.Font(size = 15, weight = "bold")
        
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 30)
        label_Introduction = tk.Label(self.root, text = "Top 5 Purchased Member", width = 25, font = self.bodytextC, fg = 'blue').place(x = 320, y = 70)

        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Header
        tk.Label(self.root, text = "Product Name", width = 20, font = self.bodytext).place(x = 230, y = 130)
        tk.Label(self.root, text = "Quantity", width = 20, font = self.bodytext).place(x = 500, y = 130)

        
        # No.1
        tk.Label(self.root, text = "No. 1", width = 20, font = self.bodytext).place(x = 30, y = 170)
        tk.Label(self.root, text = " " if len(self.ls_PRO_NAME) <= 0 else self.ls_PRO_NAME[0], width = 20, borderwidth = 2, relief = "solid", font = self.bodytext).place(x = 230, y = 170)
        tk.Label(self.root, text = " " if len(self.ls_PRO_QUANTITY) <= 0 else self.ls_PRO_QUANTITY[0], width = 20, borderwidth = 2, relief = "solid", font = self.bodytext).place(x = 500, y = 170)
        
        
        # No.2
        tk.Label(self.root, text = "No. 2", width = 20, font = self.bodytext).place(x = 30, y = 210)
        tk.Label(self.root, text = " " if len(self.ls_PRO_NAME) <= 1 else self.ls_PRO_NAME[1], width = 20, borderwidth = 2, relief="solid", font = self.bodytext).place(x = 230, y = 210)
        tk.Label(self.root, text = " " if len(self.ls_PRO_QUANTITY) <= 1 else self.ls_PRO_QUANTITY[1], width = 20, borderwidth = 2, relief = "solid", font = self.bodytext).place(x = 500, y = 210)
 
        # No.3
        tk.Label(self.root, text = "No. 3", width = 20, font = self.bodytext).place(x = 30, y = 250)
        tk.Label(self.root, text = " " if len(self.ls_PRO_NAME) <= 2 else self.ls_PRO_NAME[2], width = 20, borderwidth = 2, relief = "solid", font = self.bodytext).place(x = 230, y = 250)
        tk.Label(self.root, text = " " if len(self.ls_PRO_QUANTITY) <= 2 else self.ls_PRO_QUANTITY[2], width = 20, borderwidth=2, relief = "solid", font = self.bodytext).place(x = 500, y = 250)
     
        # No.4
        tk.Label(self.root, text = "No. 4", width = 20, font = self.bodytext).place(x = 30, y = 290)
        tk.Label(self.root, text = " " if len(self.ls_PRO_NAME) <= 3 else self.ls_PRO_NAME[3], width = 20, borderwidth = 2, relief = "solid", font = self.bodytext).place(x = 230, y = 290)
        tk.Label(self.root, text = " " if len(self.ls_PRO_QUANTITY) <= 3 else self.ls_PRO_QUANTITY[3], width = 20, borderwidth = 2, relief = "solid", font = self.bodytext).place(x = 500, y = 290)
        
        # No.5
        tk.Label(self.root, text = "No. 5", width = 20, font = self.bodytext).place(x = 30, y = 330)
        tk.Label(self.root, text = " " if len(self.ls_PRO_NAME) <= 4 else self.ls_PRO_NAME[4], width = 20, borderwidth = 2, relief = "solid", font = self.bodytext).place(x = 230, y = 330)
        tk.Label(self.root, text = " " if len(self.ls_PRO_QUANTITY) <= 4 else self.ls_PRO_QUANTITY[4], width = 20, borderwidth = 2, relief = "solid", font = self.bodytext).place(x = 500, y = 330)
        

        # Buttons
        But_Back = tk.Button(self.root, text = "Back to Staff DashBoard", width = 20, bg = 'black', fg = 'black', 
                            command = self.back).place(x = 345, y = 400)

        self.root.mainloop()
        
    def pre_set(self):
        connect = connection()
        
        connect.c.execute(
            """
                SELECT PRO_NAME, SUM(ODL_QUANTITY) AS TOTAL
                FROM ORDER_LINE, PRODUCT 
                WHERE ORDER_LINE.PRODUCT_PRO_ID = PRODUCT.PRO_ID
                GROUP BY PRO_NAME
                ORDER BY TOTAL DESC
                OFFSET 0 ROWS FETCH NEXT 5 ROWS ONLY
            """)
        
        self.ls_PRO_NAME = []; self.ls_PRO_QUANTITY = []
        for row in connect.c:
            self.ls_PRO_NAME.append(row[0])
            self.ls_PRO_QUANTITY.append(row[1])
            
        connect.c.close()
       
    def back(self):
        self.root.destroy()
        MAN_Dashboard_Class()

# %% [markdown]
# #### Top5_Cust_Class [Finished]

# %%
class Top5_MEM_Class:
    
    def __init__(self):
        self.root = tk.Tk()
        self.root.geometry('850x450')
        self.root.title("Top 5 Customer Sales")
        self.pre_set()
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytextC = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        self.bodytext = tkFont.Font(size = 15, weight = "bold")
        
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 30)
        label_Introduction = tk.Label(self.root, text = "Top 5 Customer Sales", width = 25, font = self.bodytextC, fg = 'blue').place(x = 320, y = 70)

        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Header
        tk.Label(self.root, text = "Customer Name", width = 20, font = self.bodytext).place(x = 225, y = 130)
        tk.Label(self.root, text = "Total Sales Amounts", width = 20, font = self.bodytext).place(x = 500, y = 130)


        # No.1
        tk.Label(self.root, text = "No. 1", width = 20, font = self.bodytext).place(x = 30, y = 170)
        tk.Label(self.root, text = " " if len(self.ls_MEM_FNAME) == 0 else self.name1st, width = 20, borderwidth = 2, relief = "solid", font = self.bodytext).place(x = 230, y = 170)
        tk.Label(self.root, text = " " if len(self.ls_TotalQ) == 0 else '${:,}'.format(self.ls_TotalQ[0]), width = 20, borderwidth = 2, relief = "solid", font = self.bodytext).place(x = 500, y = 170)
        
        
        # No.2
        tk.Label(self.root, text = "No. 2", width = 20, font = self.bodytext).place(x = 30, y = 210)
        tk.Label(self.root, text = " " if len(self.ls_MEM_FNAME) <= 1 else self.ls_MEM_FNAME[1] + ' ' + self.ls_MEM_LNAME[1], width = 20, borderwidth = 2, relief="solid", font = self.bodytext).place(x = 230, y = 210)
        tk.Label(self.root, text = " " if len(self.ls_TotalQ) <= 1 else '${:,}'.format(self.ls_TotalQ[1]), width = 20, borderwidth = 2, relief = "solid", font = self.bodytext).place(x = 500, y = 210)
 
        # No.3
        tk.Label(self.root, text = "No. 3", width = 20, font = self.bodytext).place(x = 30, y = 250)
        tk.Label(self.root, text = " " if len(self.ls_MEM_FNAME) <= 2 else self.ls_MEM_FNAME[2] + ' ' + self.ls_MEM_LNAME[2], width = 20, borderwidth = 2, relief = "solid", font = self.bodytext).place(x = 230, y = 250)
        tk.Label(self.root, text = " " if len(self.ls_TotalQ) <= 2 else '${:,}'.format(self.ls_TotalQ[2]), width = 20, borderwidth=2, relief = "solid", font = self.bodytext).place(x = 500, y = 250)
    
        # No.4
        tk.Label(self.root, text = "No. 4", width = 20, font = self.bodytext).place(x = 30, y = 290)
        tk.Label(self.root, text = " " if len(self.ls_MEM_FNAME) <= 3 else self.ls_MEM_FNAME[3] + ' ' + self.ls_MEM_LNAME[3], width = 20, borderwidth = 2, relief = "solid", font = self.bodytext).place(x = 230, y = 290)
        tk.Label(self.root, text = " " if len(self.ls_TotalQ) <= 3 else '${:,}'.format(self.ls_TotalQ[3]), width = 20, borderwidth = 2, relief = "solid", font = self.bodytext).place(x = 500, y = 290)
        
        # No.5
        tk.Label(self.root, text = "No. 5", width = 20, font = self.bodytext).place(x = 30, y = 330)
        tk.Label(self.root, text = " " if len(self.ls_MEM_FNAME) <= 4 else self.ls_MEM_FNAME[4] + ' ' + self.ls_MEM_LNAME[4], width = 20, borderwidth = 2, relief = "solid", font = self.bodytext).place(x = 230, y = 330)
        tk.Label(self.root, text = " " if len(self.ls_TotalQ) <= 4 else '${:,}'.format(self.ls_TotalQ[4]), width = 20, borderwidth = 2, relief = "solid", font = self.bodytext).place(x = 500, y = 330)
        

        # Buttons
        But_Back = tk.Button(self.root, text = "Back to Staff DashBoard", width = 20, bg = 'black', fg = 'black', 
                            command = self.back).place(x = 345, y = 400)

        self.root.mainloop()
             
    def pre_set(self):
        connect = connection()
        
        connect.c.execute(
            """
                SELECT MEM_FNAME, MEM_MNAME, MEM_LNAME, SUM(ODL_QUANTITY*ODL_TRAN_PRICE) AS TOTAL
                FROM ORDER_LINE, "MEMBER", "ORDER"
                WHERE "ORDER".ORD_ID = ORDER_LINE.ORDER_ORD_ID AND "ORDER".MEMBER_MEM_ID = "MEMBER".MEM_ID
                GROUP BY MEM_ID, MEM_LNAME, MEM_FNAME, MEM_MNAME
                ORDER BY TOTAL DESC
                OFFSET 0 ROWS FETCH NEXT 5 ROWS ONLY
            """)
        
        self.ls_MEM_FNAME = []; self.ls_MEM_LNAME = []; self.ls_MEM_MNAME = []; self.ls_TotalQ = []
        
        for row in connect.c:
            self.ls_MEM_FNAME.append(row[0])
            self.ls_MEM_MNAME.append(row[1])
            self.ls_MEM_LNAME.append(row[2])
            self.ls_TotalQ.append(row[3])
            
        connect.c.close()
        
        if len(self.ls_MEM_FNAME) >= 1:
            self.name1st = self.ls_MEM_FNAME[0] + ' ' + self.ls_MEM_LNAME[0] if isinstance(self.ls_MEM_MNAME[0], type(None)) else\
            self.ls_MEM_FNAME[0] + ' ' + self.ls_MEM_MNAME[0] + ' ' + self.ls_MEM_LNAME[0]
        
        if len(self.ls_MEM_FNAME) >= 2:
            self.name2nd = self.ls_MEM_FNAME[1] + ' ' + self.ls_MEM_LNAME[1] if isinstance(self.ls_MEM_MNAME[1], type(None)) else\
            self.ls_MEM_FNAME[1] + ' ' + self.ls_MEM_MNAME[1] + ' ' + self.ls_MEM_LNAME[1]
        
        if len(self.ls_MEM_FNAME) >= 3:
            self.name3rd = self.ls_MEM_FNAME[2] + ' ' + self.ls_MEM_LNAME[2] if isinstance(self.ls_MEM_MNAME[2], type(None)) else\
            self.ls_MEM_FNAME[2] + ' ' + self.ls_MEM_MNAME[2] + ' ' + self.ls_MEM_LNAME[2]
        
        if len(self.ls_MEM_FNAME) >= 4:
            self.name4th = self.ls_MEM_FNAME[3] + ' ' + self.ls_MEM_LNAME[3] if isinstance(self.ls_MEM_MNAME[3], type(None)) else\
            self.ls_MEM_FNAME[3] + ' ' + self.ls_MEM_MNAME[3] + ' ' + self.ls_MEM_LNAME[3]
        
        if len(self.ls_MEM_FNAME) >= 5:
            self.name5th = self.ls_MEM_FNAME[4] + ' ' + self.ls_MEM_LNAME[4] if isinstance(self.ls_MEM_MNAME[4], type(None)) else\
            self.ls_MEM_FNAME[4] + ' ' + self.ls_MEM_MNAME[4] + ' ' + self.ls_MEM_LNAME[4]
        
    def back(self):
        self.root.destroy()
        MAN_Dashboard_Class()

# %% [markdown]
# #### View Discounted Product [Finished]

# %%
class Discounted_Products_Class:
    
    def __init__(self, identity, first_row = 0):
        self.root = tk.Tk()
        self.root.geometry('850x670')
        self.root.title('Discounted Products')
        self.first_row = first_row; self.identity = identity
        self.PRO_ID_ls = []; self.PRO_NAME_ls = []; self.PRO_PRICE_ls = []
        self.pre_set()
        
        # create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        self.resulttext = tkFont.Font(family = "Courier", size = 15, weight = "normal")
                
        # declare variable
        self.name = tk.StringVar(); self.price = tk.IntVar(); self.ava = tk.IntVar()
        self.discountR = tk.IntVar()
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 800)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 650, 800, 120, fill = 'white')
        heading = canvas.create_rectangle(50, 120, 800, 170, fill = 'grey')
        
        # Logo and Page Info
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 30)
        label_Introduction = tk.Label(self.root, text = "Discounted Products", width = 20, font = self.bodytext, fg = 'blue').place(x = 340, y = 70)
        
        # Assign values to variables
        PRO_ID = tk.StringVar(); PRO_ID1 = tk.StringVar(); PRO_ID2 = tk.StringVar(); PRO_ID3 = tk.StringVar()
        PRO_ID4 = tk.StringVar(); PRO_ID5 = tk.StringVar(); PRO_name = tk.StringVar()
        
        # Layout
        tk.Label(self.root,text = 'Total Number of discounted products: '+ str(self.total_row), fg = 'orange', bg = 'gray', font = self.bodytext).place(x = 420, y = 135)
        if self.showing_rows == 0:
            tk.Label(self.root, text = 'There is no discounted product.', font = self.bodytext, fg = 'red').place(x = 140, y = 380)
        elif self.showing_rows >= 1:
           
            # Title
            tk.Label(self.root, text = 'Product Name', font = self.bodytext).place(x = 100, y = 190)
            tk.Label(self.root, text = 'Price', font = self.bodytext).place(x = 310, y  = 190)
            tk.Label(self.root, text = 'Discount Rate', font = self.bodytext).place(x = 450, y  = 190)
            
            # Display Discounted Products
            tk.Label(self.root, text = self.PRO_NAME_ls[0], font = self.resulttext).place(x = 120, y = 230)
            tk.Label(self.root, text = '$' + str(self.PRO_PRICE_ls[0]), font = self.resulttext).place(x = 307, y = 230)
            tk.Label(self.root, text = str(self.Disoucnt_R_ls[0]) + '%', font = self.resulttext).place(x = 480, y = 230)
            tk.Button(self.root, text = 'View Product Details', command = lambda: self.View_Details(self.PRO_ID_ls[0]), font = "bold", fg = 'orange', width = 15).place(x = 620, y = 230)
            
            if self.showing_rows >= 2:
                tk.Label(self.root, text = self.PRO_NAME_ls[1], font = self.resulttext).place(x = 120, y = 290)
                tk.Label(self.root, text  = '$' + str(self.PRO_PRICE_ls[1]), font = self.resulttext).place(x = 307, y = 290)
                tk.Label(self.root, text = str(self.Disoucnt_R_ls[1]) + '%', font = self.resulttext).place(x = 480, y = 290)
                tk.Button(self.root, text = 'View Product Details', command = lambda: self.View_Details(self.PRO_ID_ls[1]), font = "bold", fg = 'orange', width = 15).place(x = 620, y = 290)

                if self.showing_rows >= 3:
                    tk.Label(self.root, text = self.PRO_NAME_ls[2], font = self.resulttext).place(x = 120, y = 350)
                    tk.Label(self.root, text  = '$' + str(self.PRO_PRICE_ls[2]), font = self.resulttext).place(x = 307, y = 350)
                    tk.Label(self.root, text = str(self.Disoucnt_R_ls[2]) + '%', font = self.resulttext).place(x = 480, y = 350)
                    tk.Button(self.root, text = 'View Product Details', command = lambda: self.View_Details(self.PRO_ID_ls[2]), font = "bold", fg = 'orange', width = 15).place(x = 620, y = 350)
                    
                    if self.showing_rows >= 4:
                        tk.Label(self.root, text = self.PRO_NAME_ls[3], font = self.resulttext).place(x = 120, y = 410)
                        tk.Label(self.root, text  = '$' + str(self.PRO_PRICE_ls[3]), font = self.resulttext).place(x = 307, y = 410)
                        tk.Label(self.root, text = str(self.Disoucnt_R_ls[3]) + '%', font = self.resulttext).place(x = 480, y = 410)
                        tk.Button(self.root, text = 'View Product Details', command = lambda: self.View_Details(self.PRO_ID_ls[3]), font = "bold", fg = 'orange', width = 15).place(x = 620, y = 410)

                        if self.showing_rows == 5:
                            tk.Label(self.root, text = self.PRO_NAME_ls[4], font = self.resulttext).place(x = 120, y = 470)
                            tk.Label(self.root, text  = '$' + str(self.PRO_PRICE_ls[4]), font = self.resulttext).place(x = 307, y = 470)
                            tk.Label(self.root, text = str(self.Disoucnt_R_ls[4]) + '%', font = self.resulttext).place(x = 480, y = 470)
                            tk.Button(self.root, text = 'View Product Details', command = lambda: self.View_Details(self.PRO_ID_ls[4]), font = "bold", fg = 'orange', width = 15).place(x = 620, y = 470)                         
        
        # button
        if self.remaining_row > 0:
            tk.Button(self.root, text = 'Next page', font = "bold", fg = 'orange', command = self.next_page, width = 18).place(x = 580, y = 550)
        if self.first_row != 0:
            tk.Button(self.root, text = 'Previous page', font = "bold", fg = 'orange', command = self.previous_page, width = 18).place(x = 130, y = 550)
        tk.Button(self.root, text = 'Back to DashBoard', font = "bold", fg = 'orange', command = self.back, width = 18).place(x = 350, y = 600)
        
        self.root.mainloop()
    
    def pre_set(self):
        
        connect = connection()

        ## SQL to retrieve discounted product
        connect.c.execute(
            """
                SELECT COUNT(*) 
                FROM PRODUCT
                WHERE PRO_DISCOUNT_RATE != 0
            """)
        
        for row in connect.c:
            self.total_row = row[0]
            self.remaining_row = row[0] - self.first_row - 5
    
        # Retrieve discounted products from products
        connect.c.execute(
            """
                SELECT PRO_ID, PRO_NAME, PRO_DISCOUNT_RATE, PRO_PRICE
                FROM PRODUCT
                WHERE PRO_DISCOUNT_RATE != 0
                ORDER BY PRO_DISCOUNT_RATE DESC
                OFFSET {} ROWS FETCH NEXT 5 ROWS ONLY
            """.format(self.first_row))
            
        self.PRO_ID_ls = []; self.PRO_NAME_ls = []; self.Disoucnt_R_ls = []; self.PRO_PRICE_ls = []
        for row in connect.c:
            self.PRO_ID_ls.append(row[0])
            self.PRO_NAME_ls.append(row[1])
            self.Disoucnt_R_ls.append(row[2])
            self.PRO_PRICE_ls.append(row[3])
              
        connect.c.close()
        
        self.showing_rows = len(self.PRO_ID_ls)
                                                                                              
    def View_Details(self, PRO_ID):
        self.root.destroy()
        View_Discount_Details_Class(self.identity, PRO_ID, self.first_row)
                                                                                             
    def back(self):
        self.root.destroy()
        if self.identity == 'Manager':
            MAN_Dashboard_Class()
        else: 
            Staff_Dashboard_Class()
            
    def next_page(self):
        self.root.destroy()
        Discounted_Products_Class(self.identity, self.first_row + 5)
    
    def previous_page(self):
        self.root.destroy()
        Discounted_Products_Class(self.identity, self.first_row - 5)

# %%
class View_Discount_Details_Class:
    
    def __init__(self, identity, PRO_ID, first_row):
        self.root = tk.Tk()
        self.root.geometry('850x600')
        self.root.title('Product Details')
        self.PRO_ID = PRO_ID; self.first_row = first_row; self.identity = identity
        self.pre_set()
        
        PRO_ID = tk.StringVar()
        PRO_ID = PRO_ID
        
        # create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.detailtext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.protext = tkFont.Font(family = "Courier", size = 15, weight = "normal")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Logo and Page Info
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 30)
        label_Introduction = tk.Label(self.root, text = "Product Details", width = 20, font = self.bodytext, fg = 'blue').place(x = 340, y = 70)
    
        # Layout
        tk.Label(self.root, text = 'Product Name',font = ("Courier", 20,'bold')).place(x = 80, y = 110)
        tk.Label(self.root, text = 'Price', font = self.detailtext).place(x = 400, y = 110)
        tk.Label(self.root, text = 'Brand', font = self.detailtext).place(x = 650, y = 110)
        tk.Label(self.root, text = 'Origin', font = self.detailtext).place(x = 80, y = 230)
        tk.Label(self.root, text = 'Discount Rate', font = self.detailtext).place(x = 360, y = 230)
        tk.Label(self.root, text = 'Description', font = self.detailtext).place(x = 80, y = 350)
        tk.Label(self.root, text = 'Rating', font = self.detailtext).place(x = 650, y = 230)
        tk.Label(self.root, text = self.PRO_name, font = self.protext).place(x = 80, y = 150)
        tk.Label(self.root, text = '$' + str(self.PRO_price), font = self.protext).place(x = 400, y = 150)
        tk.Label(self.root, text = self.PRO_brand, font = self.protext).place(x = 650, y = 150)
        tk.Label(self.root, text = self.PRO_origin, font = self.protext).place(x = 80, y = 270)
        if self.PRO_discountR != 0:
            tk.Label(self.root, text = str(self.PRO_discountR) + '% off', font = self.protext, fg = 'red').place(x = 390, y = 270)
        else:
            tk.Label(self.root, text = '-', font = self.protext).place(x = 425, y = 270)
        if self.rating != 0:
            tk.Label(self.root, text = str(round(self.rating, 2)) + ' / 5', font = self.protext).place(x = 652, y = 270)
        else:
            tk.Label(self.root, text = 'N/A', font = self.protext).place(x = 670, y = 270)
        tk.Label(self.root, text = self.PRO_description, font = self.protext).place(x = 80, y = 390)
        
        # button
        tk.Button(self.root, text = 'Back',command = self.back,font = "bold", fg = 'orange', width = 18).place(x = 230, y = 520)
        tk.Button(self.root, text = 'View Comments', command = self.view_comments, \
                        font = "bold", fg = 'orange', width = 18).place(x = 490, y = 520)
        self.root.mainloop()
    
    def pre_set(self):
        
        # SQL code to retrieve all product info with corresponding PRO_ID
        connect = connection()
        
        # Retreive the total amount of Result
        connect.c.execute(
            """
                SELECT PRO_NAME, PRO_PRICE, PRO_BRAND, PRO_ORIGIN, PRO_DISCOUNT_RATE, PRO_SPECIFICATIONS
                FROM PRODUCT
                WHERE PRO_ID = '{}' 
            """.format(self.PRO_ID))
        
        for row in connect.c:
            self.PRO_name = row[0]; self.PRO_price = row[1]; self.PRO_brand = row[2]
            self.PRO_origin = row[3]; self.PRO_discountR = row[4]; self.PRO_description = row[5]
        
        connect.c.execute(
            """
                SELECT COM_RATING
                FROM COMMENTS
                WHERE PRODUCT_PRO_ID = '{}' AND COM_AVA != 0 
            """.format(self.PRO_ID))
        
        rating_ls = []
        for row in connect.c:
            rating_ls.append(int(row[0]))
            
        if len(rating_ls) != 0:
            self.rating = sum(rating_ls) / len(rating_ls)
        else: self.rating = 0
            
        connect.c.close()
        
    def back(self):
        self.root.destroy()
        Discounted_Products_Class(self.identity, self.first_row)
        
    def view_comments(self):
        self.root.destroy()
        View_Discount_Comments_Class(self.identity, self.PRO_ID, self.first_row)

# %%
# Assume each page shows at most 7 comments
class View_Discount_Comments_Class:
    
    def __init__(self, identity, PRO_ID, first_row_pro, first_row_com = 0):
        self.root = tk.Tk()
        self.root.geometry('850x1000')
        self.root.title('Comment Page')
        self.PRO_ID = PRO_ID; self.identity = identity;
        self.first_row_pro = first_row_pro; self.first_row_com = first_row_com; self.COM_COMMENT_ls = []
        self.pre_set()
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 18, weight = "bold")
        self.comtext = tkFont.Font(family = "Courier", size = 15, weight = "normal")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Logo and Page Info
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 30)
        label_Introduction = tk.Label(self.root, text = "Comments", width = 20, font = self.bodytext, fg = 'blue').place(x = 340, y = 70)
        
        # Layout
        if len(self.COM_COMMENT_ls) == 0:
            label = tk.Label(self.root, text = 'This product does not have any comments yet.'
                             ,font = self.Titletext).place(x = 180, y = 390)
        elif len(self.COM_COMMENT_ls) >= 1:
            tk.Label(self.root, text = 'Comment 1', font = self.Titletext).place(x = 70, y = 130)
            tk.Label(self.root, text = self.COM_COMMENT_ls[0] , font = self.comtext).place(x = 70, y = 160)
            if len(self.COM_COMMENT_ls) >= 2:
                tk.Label(self.root, text = 'Comment 2',font = self.Titletext).place(x = 70, y = 210)
                tk.Label(self.root, text = self.COM_COMMENT_ls[1], font = self.comtext).place(x = 70, y = 240)
                if len(self.COM_COMMENT_ls) >= 3:
                    tk.Label(self.root, text = 'Comment 3', font = self.Titletext).place(x = 70, y = 290)
                    tk.Label(self.root, text = self.COM_COMMENT_ls[2], font = self.comtext).place(x = 70, y = 320)
                    if len(self.COM_COMMENT_ls) >= 4:
                        tk.Label(self.root, text = 'Comment 4', font = self.Titletext).place(x = 70, y = 370)
                        tk.Label(self.root, text = self.COM_COMMENT_ls[3], font = self.comtext).place(x = 70, y = 400)
                        if len(self.COM_COMMENT_ls) >= 5:
                            tk.Label(self.root, text = 'Comment 5', font = self.Titletext).place(x = 70, y = 450)
                            tk.Label(self.root, text = self.COM_COMMENT_ls[4], font = self.comtext).place(x = 70, y = 480)
                            if len(self.COM_COMMENT_ls) >= 6:
                                tk.Label(self.root, text = 'Comment 6', font = self.Titletext).place(x = 70, y = 530)
                                tk.Label(self.root, text = self.COM_COMMENT_ls[5],font = self.comtext).place(x = 70, y = 560)
                                if len(self.COM_COMMENT_ls) >= 7:
                                    tk.Label(self.root, text = 'Comment 7',font = self.Titletext).place(x = 70, y = 610)
                                    tk.Label(self.root, text = self.COM_COMMENT_ls[6],font = self.comtext).place(x = 70, y = 640)
        
        
        # Buttons
        if self.remaining_row > 0:
            tk.Button(self.root, text = 'Next page', font = "bold", fg = 'orange', command = self.next_page, width = 18).place(x = 580, y = 710)
        if self.first_row_com != 0:
            tk.Button(self.root, text = 'Previous page', font = "bold", fg = 'orange', command = self.previous_page, width = 18).place(x = 130, y = 710)
        tk.Button(self.root,text = 'Back to Product Details', command = self.back, font = "bold", fg = 'orange', width = 18).place(x = 350, y = 740)
        self.root.mainloop()
    
    def pre_set(self):
        # SQL code to retrieve corresponding comments and average rating
        connect = connection()
        
        # Retreive the total amount of Result
        connect.c.execute(
            """
                SELECT COUNT(*)
                FROM COMMENTS
                WHERE PRODUCT_PRO_ID = '{}'
            """.format(self.PRO_ID))
            
        for row in connect.c:
            self.total_row = row[0]
            self.remaining_row = row[0] - self.first_row_com - 7
        
        # Retreive detail of comment
        connect.c.execute(
            """
                SELECT COM_COMMENT
                FROM COMMENTS
                WHERE PRODUCT_PRO_ID = '{}' AND COM_COMMENT IS NOT NULL
                ORDER BY ROWNUM, COM_DATE DESC
                OFFSET {} ROWS FETCH NEXT 7 ROWS ONLY
            """.format(self.PRO_ID, self.first_row_com))
        
        for row in connect.c:
            self.COM_COMMENT_ls.append(row[0])

        connect.c.close()
        
    def back(self):
        self.root.destroy()
        View_Discount_Details_Class(self.identity, self.PRO_ID, self.first_row_pro)
    
    def next_page(self):
        self.root.destroy()
        View_Discount_Comments_Class(self.identity, self.PRO_ID, self.first_row_pro, self.first_row_com + 7)
            
    def previous_page(self):
        self.root.destroy()
        View_Discount_Comments_Class(self.identity, self.PRO_ID, self.first_row_pro, self.first_row_com - 7)

# %% [markdown]
# #### Edit Order Status

# %%
class Edit_order_status_page: 
    
    def __init__(self, identity, fir_row = 0):
        self.root = tk.Tk()
        self.root.geometry('850x680')
        self.root.title("Edit Order Status Page")
        self.fir_row = fir_row; self.identity = identity

        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 650)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 106, 800, 650, fill = 'white')
        rectangle = canvas.create_rectangle(50, 106, 800, 145, fill = 'lightblue')
        rectangle = canvas.create_rectangle(50, 146, 800, 172, fill = 'grey')
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        self.warningtext = tkFont.Font(family = "Courier", size = 30, weight = "normal")
   
        # Logo and Page Info
        self.logo = Image.open(get_image('logo.jpg'))
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50, y = 0)
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 30)
        label_Introduction = tk.Label(self.root, text = "All Sales Order of Today", width = 30, font = self.bodytext, fg = 'blue').place(x = 300, y = 70)
        
        # Declare Variable
        self.pre_set()
        self.Status1 = tk.StringVar(); self.Status2 = tk.StringVar(); self.Status3 = tk.StringVar()
        self.Status4 = tk.StringVar(); self.Status5 = tk.StringVar(); self.Message = tk.StringVar()
        
        # Titles
        tk.Label(self.root, text = 'Order ID', font = self.Titletext, bg = 'grey').place(x = 100, y = 148)
        tk.Label(self.root, text = 'Member ID', font = self.Titletext, bg = 'grey').place(x = 250, y = 148)
        tk.Label(self.root, text = 'Order Date', font = self.Titletext, bg = 'grey').place(x = 450, y = 148)
        tk.Label(self.root, text = 'Order Status', font = self.Titletext, bg = 'grey').place(x = 650, y = 148)
        tk.Label(self.root, textvariable = self.Message, font = self.bodytext, fg = 'red').place(x = 350, y = 185)
        
        # Contents
        if self.showing_row == 0:
            tk.Label(self.root, text = 'There is no any Order yet', font = self.warningtext, fg = 'red').place(x = 140, y = 380)
            
        if self.showing_row > 1:
            tk.Label(self.root, text = self.ORD_ID_ls[0], font = self.bodytext).place(x = 125, y = 220)
            tk.Label(self.root, text = self.MEM_ID_ls[0], font = self.bodytext).place(x = 275, y = 220)
            tk.Label(self.root, text = self.ORD_DATE_ls[0], font = self.bodytext).place(x = 420, y = 220)
            self.Status1.set(self.ORD_STATUS_ls[0])
            self.Status_Opt1 = tk.OptionMenu(self.root, self.Status1, *self.Status_ls)
            self.Status_Opt1.config(width = 10)
            self.Status_Opt1.place(x = 650, y = 220)
            self.Status1.set(self.Status1.get())
            
            if self.showing_row > 2:
                tk.Label(self.root, text = self.ORD_ID_ls[1], font = self.bodytext).place(x = 125, y = 280)
                tk.Label(self.root, text = self.MEM_ID_ls[1], font = self.bodytext).place(x = 275, y = 280)
                tk.Label(self.root, text = self.ORD_DATE_ls[1], font = self.bodytext).place(x = 420, y = 280)
                self.Status2.set(self.ORD_STATUS_ls[1])
                self.Status_Opt2 = tk.OptionMenu(self.root, self.Status2, *self.Status_ls)
                self.Status_Opt2.config(width = 10)
                self.Status_Opt2.place(x = 650, y = 280)
                self.Status2.set(self.Status2.get())
                
                if self.showing_row > 2:
                    tk.Label(self.root, text = self.ORD_ID_ls[2], font = self.bodytext).place(x = 125, y = 360)
                    tk.Label(self.root, text = self.MEM_ID_ls[2], font = self.bodytext).place(x = 275, y = 360)
                    tk.Label(self.root, text = self.ORD_DATE_ls[2], font = self.bodytext).place(x = 420, y = 360)
                    self.Status3.set(self.ORD_STATUS_ls[2])
                    self.Status_Opt3 = tk.OptionMenu(self.root, self.Status3, *self.Status_ls)
                    self.Status_Opt3.config(width = 10)
                    self.Status_Opt3.place(x = 650, y = 360)
                    self.Status3.set(self.Status3.get())
                    
                    if self.showing_row > 3:
                        tk.Label(self.root, text = self.ORD_ID_ls[3], font = self.bodytext).place(x = 125, y = 440)
                        tk.Label(self.root, text = self.MEM_ID_ls[3], font = self.bodytext).place(x = 275, y = 440)
                        tk.Label(self.root, text = self.ORD_DATE_ls[3], font = self.bodytext).place(x = 420, y = 440)
                        self.Status4.set(self.ORD_STATUS_ls[3])
                        self.Status_Opt4 = tk.OptionMenu(self.root, self.Status4, *self.Status_ls)
                        self.Status_Opt4.config(width = 10)
                        self.Status_Opt4.place(x = 650, y = 440)
                        self.Status4.set(self.Status4.get())
                    
                        if self.showing_row > 4:
                            tk.Label(self.root, text = self.ORD_ID_ls[4], font = self.bodytext).place(x = 125, y = 520)
                            tk.Label(self.root, text = self.MEM_ID_ls[4], font = self.bodytext).place(x = 275, y = 520)
                            tk.Label(self.root, text = self.ORD_DATE_ls[4], font = self.bodytext).place(x = 420, y = 520)
                            self.Status5.set(self.ORD_STATUS_ls[4])
                            self.Status_Opt5 = tk.OptionMenu(self.root, self.Status5, *self.Status_ls)
                            self.Status_Opt5.config(width = 10)
                            self.Status_Opt5.place(x = 650, y = 520)
                            self.Status5.set(self.Status5.get())
                
        
        # Button
        if self.remaining_row > 0:
            tk.Button(self.root, text = 'Next page', font = "bold", fg = 'orange', command = self.next_page, width = 18).place(x = 580, y = 570)
        if self.fir_row != 0:
            tk.Button(self.root, text = 'Previous page', font = "bold", fg = 'orange', command = self.previous_page, width = 18).place(x = 130, y = 570)
        tk.Button(self.root, text = 'Save', font = "bold", fg = 'orange', command = self.save, width = 18).place(x = 350, y = 570)
        tk.Button(self.root, text = 'Back to DashBoard', font = "bold", fg = 'orange', command = self.back, width = 18).place(x = 350, y = 610)
        
        
        self.root.mainloop()
  
    def pre_set(self):
        # Status
        self.Status_ls = ['Preparation', 'On delivery', 'Delivered']
        # self.Status.set(Status[0])
        
        # Retrieve data from Database
        connect = connection()
    
        # Retreive the total count
        connect.c.execute(
            """
                SELECT COUNT(*)
                FROM "ORDER"
            """)
        
        for row in connect.c:
            self.remaining_row = row[0] - self.fir_row - 5
            
        # Retreive the Order Status
        connect.c.execute(
            """
                SELECT * 
                FROM "ORDER"
                ORDER BY ORD_DATE
                OFFSET {} ROWS FETCH NEXT 5 ROWS ONLY
            """.format(self.fir_row))

        # Create lists to hold the data
        self.ORD_ID_ls = []; self.ORD_DATE_ls = []; self.ORD_STATUS_ls = []; self.MEM_ID_ls = []
        
        for row in connect.c:
            
            self.ORD_ID_ls.append(row[0])
            self.ORD_DATE_ls.append(row[1])
            self.ORD_STATUS_ls.append(row[2])
            self.MEM_ID_ls.append(row[3])
            
        self.showing_row = len(self.ORD_ID_ls)
             
        connect.c.close()
        
    def previous_page(self):
        self.root.destroy()
        Edit_order_status_page(self.identity, self.fir_row - 5)
        
    def next_page(self):
        self.root.destroy()
        Edit_order_status_page(self.identity, self.fir_row + 5)
        
    def save(self):
        connect = connection()
        
        if self.showing_row >= 1:
            connect.c.execute(
                """
                    UPDATE "ORDER"
                    SET ORD_STATUS = '{}'
                    WHERE ORD_ID = '{}'
                """.format(self.Status1.get(), self.ORD_ID_ls[0]))

            if self.showing_row >= 2:
                connect.c.execute(
                    """
                        UPDATE "ORDER"
                        SET ORD_STATUS = '{}'
                        WHERE ORD_ID = '{}'
                    """.format(self.Status2.get(), self.ORD_ID_ls[1]))

                if self.showing_row >= 3:
                    connect.c.execute(
                        """
                            UPDATE "ORDER"
                            SET ORD_STATUS = '{}'
                            WHERE ORD_ID = '{}'
                        """.format(self.Status3.get(), self.ORD_ID_ls[2]))

                    if self.showing_row >= 4:
                        connect.c.execute(
                            """
                                UPDATE "ORDER"
                                SET ORD_STATUS = '{}'
                                WHERE ORD_ID = '{}'
                            """.format(self.Status4.get(), self.ORD_ID_ls[3]))

                        if self.showing_row >= 5:
                            connect.c.execute(
                                """
                                    UPDATE "ORDER"
                                    SET ORD_STATUS = '{}'
                                    WHERE ORD_ID = '{}'
                                """.format(self.Status5.get(), self.ORD_ID_ls[4]))
            
            
        connect.c.execute("commit")
        connect.c.close()
        
        self.Message.set('Successfully Saved!!!')

    def back(self):
        self.root.destroy()
        if self.identity == 'Manager': MAN_Dashboard_Class()
        else: Staff_Dashboard_Class()

# %% [markdown]
# #### Search Product Page for Sales

# %%
class Search_Product_Quantity:
    
    def __init__(self):
        self.root = tk.Tk()
        self.root.geometry('850x450')
        self.root.title("Search Product")
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 450)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 106, 800, 420, fill = 'white')
        
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Declare Variables
        self.ProName = tk.StringVar()
        self.Brand = tk.StringVar()
        self.ErrorMessage = tk.StringVar()
        
        # Company Name
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)
        label_Introduction = tk.Label(self.root, text = "Product Search", width = 30, font = self.bodytext, fg = 'blue').place(x = 290, y = 70)
        self.label_Error = tk.Label(self.root, textvariable = self.ErrorMessage,  font = self.bodytext, fg = 'red')
        self.label_Error.place(x = 300, y = 140)
        
        # Product
        label_product = tk.Label(self.root, text = 'Search By Product:', font = self.bodytext).place(x = 190, y = 190)
        entry_product = tk.Entry(self.root, textvariable = self.ProName, width = 30).place(x = 390, y = 190)
        
        # Brand
        label_brand = tk.Label(self.root, text = 'Search By Brand:', font = self.bodytext).place(x = 190, y = 240)
        entry_brand = tk.Entry(self.root, textvariable = self.Brand, width = 30).place(x = 390, y = 240)
        
        # Buttons
        But_back = tk.Button(self.root, text = 'Search', width = 25, command = self.search, font = "bold", fg = 'orange').place(x = 160, y = 350)
        But_back = tk.Button(self.root, text = 'Back to Main Page', width = 25, command = self.back, font = "bold", fg = 'orange').place(x = 450, y = 350)
        
        self.root.mainloop()
    
    def search(self):
        if self.ProName.get() == '' and isempty(self.Brand.get()) != True:
            self.root.destroy()
            Search_Product_Quantity_Result(self.Brand.get(), 'Brand')
        elif isempty(self.ProName.get()) != True and self.Brand.get() == '':
            self.root.destroy()
            Search_Product_Quantity_Result(self.ProName.get(), 'Product')
        elif isempty(self.Brand.get()) and isempty(self.ProName.get()):
            self.ErrorMessage.set('Search Keyword cannot be empty!')
            self.label_Error.place(x = 300, y = 140)
        else: 
            self.ErrorMessage.set('Please only enter one search criteria')
            self.label_Error.place(x = 260, y = 140)
            return
        
    def back(self):
        self.root.destroy()
        MAN_Dashboard_Class()

# %%
# Limit search display to 5 items per page
# Retrieve product information and allow them to add shopping cart
class Search_Product_Quantity_Result:
    
    def __init__(self, KW, method, first_row = 0):
        self.root = tk.Tk()
        self.root.geometry('850x670')
        self.root.title('Product and Quantity Result')
        self.search_kw = KW; self.method = method; self.first_row = first_row
        self.PRO_PRICE_ls = []
        self.PRO_ID_ls = []; self.PRO_NAME_ls = []; self.PRO_QUAN_ls = []; self.PRO_BRAND_ls = []
        self.pre_set()
        
        # create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        self.resulttext = tkFont.Font(family = "Courier", size = 15, weight = "normal")
        self.warningtext = tkFont.Font(family = "Courier", size = 30, weight = "normal")
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 800)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 650, 800, 120, fill = 'white')
        heading = canvas.create_rectangle(50, 120, 800, 170, fill = 'grey')
        
        # Logo and Page Info
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 30)
        label_Introduction = tk.Label(self.root, text = "Product Search Result", width = 20, font = self.bodytext, fg = 'blue').place(x = 340, y = 70)
        
        # Assign values to variables
        PRO_ID = tk.StringVar(); PRO_ID1 = tk.StringVar(); PRO_ID2 = tk.StringVar(); PRO_ID3 = tk.StringVar()
        PRO_ID4 = tk.StringVar(); PRO_ID5 = tk.StringVar(); PRO_name = tk.StringVar()
        
        # Layout
        tk.Label(self.root, text = 'The search result of keyword: '+ self.search_kw, fg = 'orange', bg = 'gray',font=self.bodytext).place(x = 65 , y = 135)
        tk.Label(self.root,text = 'Total Number of related products: '+ str(self.total_row), fg = 'orange', bg = 'gray', font = self.bodytext).place(x = 460, y = 135)
        if self.showing_rows == 0:
            if self.method == 'Brand':
                tk.Label(self.root, text = 'There is no such Brand as ' + self.search_kw, font = self.warningtext, fg = 'red').place(x = 140, y = 380)
            if self.method == 'Product':
                tk.Label(self.root, text = 'There is no such Product as ' + self.search_kw, font = self.warningtext, fg = 'red').place(x = 140, y = 380)
        elif self.showing_rows >= 1:
            
            # Title
            tk.Label(self.root, text = 'Product Name', font = self.bodytext).place(x = 100, y = 190)
            tk.Label(self.root, text = 'Price', font = self.bodytext).place(x = 310, y  = 190)
            tk.Label(self.root, text = 'Brand', font = self.bodytext).place(x = 430, y = 190)
            tk.Label(self.root, text = 'Quantity Sold', font = self.bodytext).place(x = 600, y = 190)
            

            # Product Details displayed on screen
            tk.Label(self.root, text = self.PRO_NAME_ls[0], font = self.resulttext).place(x = 120, y = 230)
            tk.Label(self.root, text = str(self.PRO_PRICE_ls[0]), font = self.resulttext).place(x = 307, y = 230)
            tk.Label(self.root, text = self.PRO_BRAND_ls[0], font = self.resulttext).place(x = 430, y = 230)
            tk.Label(self.root, text = self.PRO_QUAN_ls[0], font = self.resulttext).place(x = 650, y = 230)
            
            if self.showing_rows >= 2:
                tk.Label(self.root, text = self.PRO_NAME_ls[1], font = self.resulttext).place(x = 120, y = 290)
                tk.Label(self.root, text  = str(self.PRO_PRICE_ls[1]), font = self.resulttext).place(x = 307, y = 290)
                tk.Label(self.root, text = self.PRO_BRAND_ls[1], font = self.resulttext).place(x = 430, y = 290)
                tk.Label(self.root, text = self.PRO_QUAN_ls[1], font = self.resulttext).place(x = 650, y = 290)
                
                if self.showing_rows >= 3:
                    tk.Label(self.root, text = self.PRO_NAME_ls[2], font = self.resulttext).place(x = 120, y = 350)
                    tk.Label(self.root, text  = str(self.PRO_PRICE_ls[2]), font = self.resulttext).place(x = 307, y = 350)
                    tk.Label(self.root, text = self.PRO_BRAND_ls[2], font = self.resulttext).place(x = 430, y = 350)
                    tk.Label(self.root, text = self.PRO_QUAN_ls[2], font = self.resulttext).place(x = 650, y = 350)
                    
                    if self.showing_rows >= 4:
                        tk.Label(self.root, text = self.PRO_NAME_ls[3], font = self.resulttext).place(x = 120, y = 410)
                        tk.Label(self.root, text  = str(self.PRO_PRICE_ls[3]), font = self.resulttext).place(x = 307, y = 410)
                        tk.Label(self.root, text = self.PRO_BRAND_ls[3], font = self.resulttext).place(x = 430, y = 410)
                        tk.Label(self.root, text = self.PRO_QUAN_ls[3], font = self.resulttext).place(x = 650, y = 410)
                        
                        if self.showing_rows == 5:
                            tk.Label(self.root, text = self.PRO_NAME_ls[4], font = self.resulttext).place(x = 120, y = 470)
                            tk.Label(self.root, text  = str(self.PRO_PRICE_ls[4]), font = self.resulttext).place(x = 307, y = 470)
                            tk.Label(self.root, text = self.PRO_BRAND_ls[4], font = self.resulttext).place(x = 430, y = 470)
                            tk.Label(self.root, text = self.PRO_QUAN_ls[4], font = self.resulttext).place(x = 650, y = 470)
                            
        # button
        if self.remaining_row > 0:
            tk.Button(self.root, text = 'Next page', font = "bold", fg = 'orange', command = self.next_page, width = 18).place(x = 580, y = 550)
        if self.first_row != 0:
            tk.Button(self.root, text = 'Previous page', font = "bold", fg = 'orange', command = self.previous_page, width = 18).place(x = 130, y = 550)
        tk.Button(self.root, text = 'Back to Search', font = "bold", fg = 'orange', command = self.back, width = 18).place(x = 350, y = 600)
        
        self.root.mainloop()
    
    def pre_set(self):

        # SQL to retrieve product name, price, ava, brand, inventory, discountR, origin and description
        # Search by brand
        connect = connection()
        
        if self.method == 'Brand':
            # Retreive the total amount of Result
            connect.c.execute(
                """
                    SELECT COUNT(*)
                    FROM PRODUCT
                    WHERE upper(PRO_BRAND) LIKE '%{}%'
                """.format(self.search_kw.upper()))
            
            for row in connect.c:
                self.total_row = row[0]
                self.remaining_row = row[0] - self.first_row - 5
                
            # Retreive the total amount of Shooping Cart
            connect.c.execute(
                """
                    SELECT PRO_ID, PRO_NAME, PRO_PRICE, PRO_BRAND, PRO_DISCOUNT_RATE
                    FROM PRODUCT
                    WHERE upper(PRO_BRAND) LIKE '%{}%'
                    ORDER BY ROWNUM
                    OFFSET {} ROWS FETCH NEXT 5 ROWS ONLY
                """.format(self.search_kw.upper(), self.first_row))
        
        
        if self.method == 'Product':
            # Retreive the total amount of Result
            connect.c.execute(
                """
                    SELECT COUNT(*)
                    FROM PRODUCT
                    WHERE upper(PRO_NAME) LIKE '%{}%'
                """.format(self.search_kw.upper()))
            
            for row in connect.c:
                self.total_row = row[0]
                self.remaining_row = row[0] - self.first_row - 5
                
            # Retreive the total amount of Shooping Cart
            connect.c.execute(
                """
                     SELECT PRO_ID, PRO_NAME, PRO_PRICE, PRO_BRAND, PRO_DISCOUNT_RATE
                     FROM PRODUCT
                     WHERE upper(PRO_NAME) LIKE '%{}%'
                     ORDER BY ROWNUM
                     OFFSET {} ROWS FETCH NEXT 5 ROWS ONLY
                 """.format(self.search_kw.upper(), self.first_row))

            
        for row in connect.c:
            self.PRO_ID_ls.append(row[0])
            self.PRO_NAME_ls.append(row[1])
            self.PRO_PRICE_ls.append(round(row[2] * (1 - row[4] / 100), 2))
            self.PRO_BRAND_ls.append(row[3])
        
        self.showing_rows = len(self.PRO_ID_ls)
        
        # Retrieve the product quantity
        for i in self.PRO_ID_ls:
            connect.c.execute(
                    """
                         SELECT SUM(ODL_QUANTITY)
                         FROM ORDER_LINE
                         WHERE PRODUCT_PRO_ID = '{}'
                     """.format(i))
                
            for row in connect.c:
                if row[0] is not None:
                    self.PRO_QUAN_ls.append(row[0])
                else: self.PRO_QUAN_ls.append('0')
        
        connect.c.close()
                                                                                        
    def back(self):
        self.root.destroy()
        Search_Product_Quantity()
    
    def next_page(self):
        self.root.destroy()
        if self.method == 'Brand':
            Search_Product_Quantity_Result(self.search_kw, 'Brand', self.first_row + 5)
        else: Search_Product_Quantity_Result(self.search_kw, 'Product', self.first_row + 5)
    
    def previous_page(self):
        self.root.destroy()
        if self.method == 'Brand':
            Search_Product_Quantity_Result(self.search_kw, 'Brand', self.first_row - 5)
        else: Search_Product_Quantity_Result(self.search_kw, 'Product', self.first_row - 5)

# %% [markdown]
# #### Stockout Product Page

# %%
class Show_StockOut_Class:
    
    def __init__(self, first_row = 0):
        self.root = tk.Tk()
        self.root.geometry('850x500')
        self.root.title("Show StockOut Page")
        self.first_row = first_row
        self.pre_set()
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        self.resulttext = tkFont.Font(family = "Courier", size = 15, weight = "normal")
        self.warningtext = tkFont.Font(family = "Courier", size = 30, weight = "normal")
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 500)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 106, 800, 470, fill = 'white')
        
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Declare Variables
        
        
        # Company Name
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)
        label_Introduction = tk.Label(self.root, text = "Stock Out Product Page", font = self.bodytext, fg = 'blue').place(x = 330, y = 70)
        
        # Content
        if self.showing_rows == 0:
            tk.Label(self.root, text = 'There is no any stock-out product', font = self.warningtext, fg = 'red').place(x = 140, y = 380)
        
        elif self.showing_rows >= 1:
            
            # Title
            tk.Label(self.root, text = 'Product Name', font = self.bodytext).place(x = 150, y = 120)
            tk.Label(self.root, text = 'Brand', font = self.bodytext).place(x = 400, y  = 120)
            tk.Label(self.root, text = "Origin", font = self.bodytext).place(x = 580, y = 120)
        
            # Product Details displayed on screen
            tk.Label(self.root, text = self.PRO_NAME_ls[0], font = self.resulttext).place(x = 170, y = 160)
            tk.Label(self.root, text = self.PRO_BRAND_ls[0], font = self.resulttext).place(x = 400, y = 160)
            tk.Label(self.root, text = self.PRO_ORIGIN_ls[0], font = self.resulttext).place(x = 580, y = 160)
            
            if self.showing_rows >= 2:
                tk.Label(self.root, text = self.PRO_NAME_ls[1], font = self.resulttext).place(x = 170, y = 200)
                tk.Label(self.root, text  = self.PRO_BRAND_ls[1], font = self.resulttext).place(x = 400, y = 200)
                tk.Label(self.root, text = self.PRO_ORIGIN_ls[1], font = self.resulttext).place(x = 580, y = 200)

                if self.showing_rows >= 3:
                    tk.Label(self.root, text = self.PRO_NAME_ls[2], font = self.resulttext).place(x = 170, y = 240)
                    tk.Label(self.root, text  = self.PRO_BRAND_ls[2], font = self.resulttext).place(x = 400, y = 240)
                    tk.Label(self.root, text = self.PRO_ORIGIN_ls[2], font = self.resulttext).place(x = 580, y = 240)
      
                    if self.showing_rows >= 4:
                        tk.Label(self.root, text = self.PRO_NAME_ls[3], font = self.resulttext).place(x = 170, y = 280)
                        tk.Label(self.root, text  = self.PRO_BRAND_ls[3], font = self.resulttext).place(x = 400, y = 280)
                        tk.Label(self.root, text = self.PRO_ORIGIN_ls[3], font = self.resulttext).place(x = 580, y = 280)
                   
                        if self.showing_rows == 5:
                            tk.Label(self.root, text = self.PRO_NAME_ls[4], font = self.resulttext).place(x = 170, y = 320)
                            tk.Label(self.root, text  = self.PRO_BRAND_ls[4], font = self.resulttext).place(x = 400, y = 320)
                            tk.Label(self.root, text = self.PRO_ORIGIN_ls[4], font = self.resulttext).place(x = 580, y = 320)
                            

        # Buttons
        if self.remaining_row > 0:
            tk.Button(self.root, text = 'Next page', font = "bold", fg = 'orange', command = self.next_page, width = 18).place(x = 580, y = 380)
        if self.first_row != 0:
            tk.Button(self.root, text = 'Previous page', font = "bold", fg = 'orange', command = self.previous_page, width = 18).place(x = 130, y = 380)
        tk.Button(self.root, text = 'Back to DashBoard', font = "bold", fg = 'orange', command = self.back, width = 18).place(x = 350, y = 420)
        
        self.root.mainloop()
    
    def pre_set(self):
        
        connect = connection()
                
        connect.c.execute(
                """
                    SELECT COUNT(*)
                    FROM PRODUCT
                    WHERE PRO_INVENTORY = 0
                """)
        
        for row in connect.c:
            self.total_row = row[0]
            self.remaining_row = row[0] - self.first_row - 5
        
        connect.c.execute(
                """
                    SELECT PRO_NAME, PRO_BRAND, PRO_ORIGIN
                    FROM PRODUCT 
                    WHERE PRO_INVENTORY = 0
                    ORDER BY ROWNUM
                    OFFSET {} ROWS FETCH NEXT 5 ROWS ONLY
                """.format(self.first_row))
        
        self.PRO_NAME_ls = []; self.PRO_BRAND_ls = []; self.PRO_ORIGIN_ls = []
        
        for row in connect.c:
            self.PRO_NAME_ls.append(row[0])
            self.PRO_BRAND_ls.append(row[1])
            self.PRO_ORIGIN_ls.append(row[2])
            
        self.showing_rows = len(self.PRO_NAME_ls)
            
        connect.c.close()
        
    def back(self):
        self.root.destroy()
        MAN_Dashboard_Class()
        
    def next_page(self):
        self.root.destroy()
        Show_StockOut_Class(self.first_row + 5)
        
    def previous_page(self):
        self.root.destroy()
        Show_StockOut_Class(self.first_row - 5)

# %% [markdown]
# #### View and Hide Comment

# %%
class View_Hide_Comment_Select_Product:
    
    def __init__(self):
        self.root = tk.Tk()
        self.root.geometry('850x400')
        self.root.title('Select Comments to View and Hide')
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Declare variables
        self.PRO_ID = tk.StringVar()
        
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Layout
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 260, y = 30)
        label_Introduction = tk.Label(self.root, text = "Select Product to view comment", width = 30, font = self.bodytext, fg = 'blue').place(x = 300, y = 70)
        label_select_ID = tk.Label(self.root, text ='Select Product ID:', width=20,font=self.bodytext).place(x=155,y=202)
        tk.Button(self.root,text='Back to Dashboard', width = 16, fg = 'red',command=self.back).place(x=360,y=300)
        
        # SQL code to retrieve all Product ID 
        connect = connection()
        connect.c.execute(
            """
              SELECT PRO_ID 
              FROM PRODUCT
            """)

        # Assign product ID to list
        self.choose_PRO_ID = []
        for row in connect.c:
            self.choose_PRO_ID.append(row[0])

        connect.c.close() 
        
        # dropbutton to show all product
        droplist_PRO_ID = tk.OptionMenu(self.root, self.PRO_ID, *self.choose_PRO_ID)
        droplist_PRO_ID.config(width=15)
        self.PRO_ID.set('Select a product ID')
        droplist_PRO_ID.place(x=350,y=200)
        
        # retrieve button to retrieve number of pages
        retrievebtn = tk.Button(self.root, text = "Retrieve Comments", width = 16, fg = 'red',command=self.retrieve).place(x=530,y=200)
        
        self.root.mainloop()
        
    def retrieve(self):
        if self.PRO_ID.get() == 'Select a product ID':
            return
        self.root.destroy()
        Comment_Display(self.PRO_ID.get())
        
    def back(self):
        self.root.destroy()
        MAN_Dashboard_Class()

# %%
# assume each page displays 10 comments at most
class Comment_Display:
    
    def __init__(self,PRO_ID,currentPage=1,firstRow=0):
        self.root = tk.Tk()
        self.root.geometry('1250x1000')
        self.root.title('View and Hide Comments')
        self.PRO_ID = PRO_ID
        self.preset()
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Declare variables
        self.firstRow = firstRow;self.currentPage = currentPage;self.selectForHide_1 = tk.IntVar()
        self.selectForHide_2 = tk.IntVar();self.selectForHide_3 = tk.IntVar()
        self.selectForHide_4 = tk.IntVar();self.selectForHide_5 = tk.IntVar()
        self.selectForHide_6 = tk.IntVar();self.selectForHide_7 = tk.IntVar()
        self.selectForHide_8 = tk.IntVar();self.selectForHide_9 = tk.IntVar()
        self.selectForHide_10 = tk.IntVar()
        self.saveMessage = tk.StringVar();self.saveMessage.set('')
        
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Layout
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 480, y = 30)
        label_Introduction = tk.Label(self.root, text = "View and Hide Comment", width = 20, font = self.bodytext, fg = 'blue').place(x = 550, y = 70)
        tk.Label(self.root, text= '*Uncheck button to hide comments',font=self.bodytext,fg='red').place(x=50,y=100)
        tk.Label(self.root,textvariable=self.saveMessage,font=self.bodytext,fg='red').place(x=600,y=100)
        
        connect = connection()
        
        connect.c.execute(
            """
                SELECT COM_ID, COM_COMMENT,COM_AVA,COM_DATE
                FROM COMMENTS, PRODUCT
                WHERE COMMENTS.PRODUCT_PRO_ID = PRODUCT.PRO_ID 
                AND PRODUCT.PRO_ID = '{}'
                ORDER BY COM_DATE DESC
                OFFSET {} ROWS FETCH NEXT 10 ROWS ONLY
            """.format(self.PRO_ID,self.firstRow))
    
        
        self.commentID_list = [];self.comment_list = [];self.ava_list = [];self.date_list = []
        for row in connect.c:
            self.commentID_list.append(row[0])
            self.comment_list.append(row[1])
            self.ava_list.append(row[2]) 
            self.date_list.append(row[3])
        
        self.remainingRow = self.totalRows - self.firstRow - 10
        if self.firstRow == 0:
            self.currentPage = 1
        else: self.currentPage = math.ceil(self.totalRows/7)
        
        connect.c.close()
        
        # comment display
        if len(self.comment_list) == 0:
            label_com = tk.Label(self.root,text='These product does not have any comment yet',font=self.bodytext).place(x=310,y=250)
        elif len(self.comment_list) > 0:
            self.label_com = tk.Label(self.root, text=self.comment_list[0][0:60],font=self.bodytext,width=80,anchor='w').place(x=330,y=190)
            self.label_com = tk.Label(self.root, text=self.comment_list[0][60:120],font=self.bodytext,width=80,anchor='w').place(x=140,y=210)
            self.select_com1 = tk.Checkbutton(self.root, variable=self.selectForHide_1)
            self.date_1 = tk.Label(self.root,text=self.date_list[0],font=self.bodytext,fg='orange').place(x=140,y=190)
            if self.ava_list[0] == 1:
                self.selectForHide_1.set(1)
                self.select_com1.place(x=90,y=190)
            
            else:
                self.selectForHide_1.set(0)
                self.select_com1.place(x=90,y=190)
            
            if len(self.comment_list) > 1:
                self.label_com = tk.Label(self.root, text=self.comment_list[1][0:60],font=self.bodytext,width=80,anchor='w').place(x=330,y=240)
                self.label_com = tk.Label(self.root, text=self.comment_list[1][60:120],font=self.bodytext,width=80,anchor='w').place(x=140,y=260)
                self.select_com2 = tk.Checkbutton(self.root, variable=self.selectForHide_2)
                self.date_2 = tk.Label(self.root,text=self.date_list[1],font=self.bodytext,fg='orange').place(x=140,y=240)
                if self.ava_list[1] ==1:
                    self.selectForHide_2.set(1)
                    self.select_com2.place(x=90,y=240)
                else: 
                    self.selectForHide_2.set(0)
                    self.select_com2.place(x=90,y=240)
                
                if len(self.comment_list) > 2:
                    self.label_com = tk.Label(self.root, text=self.comment_list[2][0:60],font=self.bodytext,width=80,anchor='w').place(x=330,y=300)
                    self.label_com = tk.Label(self.root, text=self.comment_list[2][60:120],font=self.bodytext,width=80,anchor='w').place(x=140,y=320)
                    self.select_com3 = tk.Checkbutton(self.root, variable=self.selectForHide_3)
                    self.date_1 = tk.Label(self.root,text=self.date_list[0],font=self.bodytext,fg='orange').place(x=140,y=300)
                    if self.ava_list[2] ==1:
                        self.selectForHide_3.set(1)
                        self.select_com3.place(x=90,y=300)
                    else:
                        self.selectForHide_3.set(0)
                        self.select_com3.place(x=90,y=300)
                    
                    if len(self.comment_list) > 3:
                        label_com = tk.Label(self.root, text=self.comment_list[3][0:60],font=self.bodytext,width=80,anchor='w').place(x=330,y=360)
                        label_com = tk.Label(self.root, text=self.comment_list[3][60:120],font=self.bodytext,width=80,anchor='w').place(x=140,y=380)
                        self.select_com4 = tk.Checkbutton(self.root, variable=self.selectForHide_4,font=self.bodytext)
                        self.date_1 = tk.Label(self.root,text=self.date_list[0],font=self.bodytext,fg='orange').place(x=140,y=360)
                        if self.ava_list[3] ==1:
                            self.selectForHide_4.set(1)
                            self.select_com4.place(x=90,y=360)
                        else:
                            self.selectForHide_4.set(0)
                            self.select_com4.place(x=90,y=360)
                
                        if len(self.comment_list) > 4:
                            label_com = tk.Label(self.root, text=self.comment_list[4][0:60],font=self.bodytext,width=80,anchor='w').place(x=330,y=420)
                            label_com = tk.Label(self.root, text=self.comment_list[4][60:120],font=self.bodytext,width=80,anchor='w').place(x=140,y=440)
                            self.select_com5 = tk.Checkbutton(self.root, variable=self.selectForHide_5,font=self.bodytext)
                            self.date_1 = tk.Label(self.root,text=self.date_list[0],font=self.bodytext,fg='orange').place(x=140,y=420)
                            if self.ava_list[4] ==1:
                                self.selectForHide_5.set(1)
                                self.select_com5.place(x=90,y=420)
                            else:
                                self.selectForHide_5.set(0)
                                self.select_com5.place(x=90,y=420)
                            
                            if len(self.comment_list) > 5:
                                label_com = tk.Label(self.root, text=self.comment_list[5][0:60],font=self.bodytext,width=80,anchor='w').place(x=330,y=480)
                                label_com = tk.Label(self.root, text=self.comment_list[5][60:120],font=self.bodytext,width=80,anchor='w').place(x=140,y=500)
                                self.select_com6 = tk.Checkbutton(self.root, variable=self.selectForHide_6,font=self.bodytext)
                                self.date_1 = tk.Label(self.root,text=self.date_list[0],font=self.bodytext,fg='orange').place(x=140,y=480)
                                if self.ava_list[5] ==1:
                                    self.selectForHide_6.set(1)
                                    self.select_com6.place(x=90,y=480)
                                else:
                                    self.selectForHide_6.set(0)
                                    self.select_com6.place(x=90,y=480)
                                    
                                if len(self.comment_list) > 6:
                                    label_com = tk.Label(self.root, text=self.comment_list[6][0:60],font=self.bodytext,width=80,anchor='w').place(x=330,y=540)
                                    label_com = tk.Label(self.root, text=self.comment_list[6][60:120],font=self.bodytext,width=80,anchor='w').place(x=140,y=560)
                                    self.select_com7 = tk.Checkbutton(self.root, variable=self.selectForHide_7,font=self.bodytext)
                                    self.date_1 = tk.Label(self.root,text=self.date_list[0],font=self.bodytext,fg='orange').place(x=140,y=540)
                                    if self.ava_list[6] ==1:
                                        self.selectForHide_7.set(1)
                                        self.select_com7.place(x=90,y=540)
                                    else:
                                        self.selectForHide_7.set(0)
                                        self.select_com7.place(x=90,y=540)
                                    
                                    if len(self.comment_list) > 7:
                                        label_com = tk.Label(self.root, text=self.comment_list[7][0:60],font=self.bodytext,width=80,anchor='w').place(x=330,y=600)
                                        label_com = tk.Label(self.root, text=self.comment_list[7][60:120],font=self.bodytext,width=80,anchor='w').place(x=140,y=620)
                                        self.select_com8 = tk.Checkbutton(self.root, variable=self.selectForHide_8,font=self.bodytext)
                                        self.date_1 = tk.Label(self.root,text=self.date_list[0],font=self.bodytext,fg='orange').place(x=140,y=600)
                                        if self.ava_list[7] ==1:
                                            self.selectForHide_8.set(1)
                                            self.select_com8.place(x=90,y=600)
                                        else:
                                            self.selectForHide_8.set(0)
                                            self.select_com8.place(x=90,y=600)
                                        
                                        if len(self.comment_list) > 8:
                                            label_com = tk.Label(self.root, text=self.comment_list[8][0:60],font=self.bodytext,width=80,anchor='w').place(x=330,y=660)
                                            label_com = tk.Label(self.root, text=self.comment_list[8][60:120],font=self.bodytext,width=80,anchor='w').place(x=140,y=680)
                                            self.select_com9 = tk.Checkbutton(self.root, variable=self.selectForHide_9,font=self.bodytext)
                                            self.date_1 = tk.Label(self.root,text=self.date_list[0],font=self.bodytext,fg='orange').place(x=140,y=660)
                                            if self.ava_list[8] ==1:
                                                self.selectForHide_9.set(1)
                                                self.select_com9.place(x=90,y=660)
                                            else:
                                                self.selectForHide_9.set(0)
                                                self.select_com9.place(x=90,y=660)
                                                
                                            if len(self.comment_list) > 9:
                                                label_com = tk.Label(self.root, text=self.comment_list[9][0:60],font=self.bodytext,anchor='w').place(x=330,y=720)
                                                label_com = tk.Label(self.root, text=self.comment_list[9][60:120],font=self.bodytext,width=80,anchor='w').place(x=140,y=740)
                                                self.select_com10 = tk.Checkbutton(self.root, variable=self.selectForHide_10,font=self.bodytext)
                                                self.date_1 = tk.Label(self.root,text=self.date_list[9],font=self.bodytext,fg='orange').place(x=140,y=720)
                                                if self.ava_list[9] ==1:
                                                    self.selectForHide_10.set(1)
                                                    self.select_com10.place(x=90,y=720)
                                                else:
                                                    self.selectForHide_10.set(0)
                                                    self.select_com10.place(x=90,y=720)
        
        # button
        if self.currentPage != 1:
            tk.Button(self.root, text='Previous', width = 15,command = self.previousPage, font = "bold", fg = 'orange').place(x = 400, y = 760)
        if self.remainingRow > 0:
            tk.Button(self.root, text='Next', width = 15,command = self.nextPage, font = "bold", fg = 'orange').place(x = 700, y = 760)
        # button to hide selected button
        hidebtn = tk.Button(self.root, text='Save',width=7, fg = 'red',command=self.hide).place(x=700,y=130)
        # button to refresh page
        refreshbtn = tk.Button(self.root, text='Refresh',width=7, fg = 'red',command=self.refresh).place(x=800,y=130)


        
        # Other buttons
        tk.Button(self.root, text='Back', width = 15,command = self.back, font = "bold", fg = 'orange').place(x = 200, y = 760)
        
        
        self.root.mainloop()

    def nextPage(self):
        self.root.destroy()
        Comment_Display(self.PRO_ID,self.currentPage+1,self.firstRow + 10)
             
    def previousPage(self):
        self.root.destroy()
        Comment_Display(self.PRO_ID,self.currentPage-1,self.firstRow - 10)
        
    def hide(self):
        self.lsChangeAVA = [];self.lsRecoverAVA = []
        
        if self.selectForHide_1.get() == 0 and len(self.comment_list) >= 1:
            self.lsChangeAVA.append(self.commentID_list[0])
        if self.selectForHide_2.get() == 0 and len(self.comment_list) >= 2:
            self.lsChangeAVA.append(self.commentID_list[1])
        if self.selectForHide_3.get() == 0 and len(self.comment_list) >= 3:
            self.lsChangeAVA.append(self.commentID_list[2])
        if self.selectForHide_4.get() == 0 and len(self.comment_list) >= 4:
            self.lsChangeAVA.append(self.commentID_list[3])
        if self.selectForHide_5.get() == 0 and len(self.comment_list) >= 5:
            self.lsChangeAVA.append(self.commentID_list[4])
        if self.selectForHide_6.get() == 0 and len(self.comment_list) >= 6:
            self.lsChangeAVA.append(self.commentID_list[5])
        if self.selectForHide_7.get() == 0 and len(self.comment_list) >= 7:
            self.lsChangeAVA.append(self.commentID_list[6])
        if self.selectForHide_8.get() == 0 and len(self.comment_list) >= 8:
            self.lsChangeAVA.append(self.commentID_list[7])
        if self.selectForHide_9.get() == 0 and len(self.comment_list) >= 9:
            self.lsChangeAVA.append(self.commentID_list[8])
        if self.selectForHide_10.get() ==0 and len(self.comment_list) >= 10:
            self.lsChangeAVA.append(self.commentID_list[9])
        
        if self.selectForHide_1.get() == 1 and len(self.comment_list) >= 1:
            self.lsRecoverAVA.append(self.commentID_list[0])
        if self.selectForHide_2.get() == 1 and len(self.comment_list) >= 2:
            self.lsRecoverAVA.append(self.commentID_list[1])
        if self.selectForHide_3.get() == 1 and len(self.comment_list) >= 3:
            self.lsRecoverAVA.append(self.commentID_list[2])
        if self.selectForHide_4.get() == 1 and len(self.comment_list) >= 4:
            self.lsRecoverAVA.append(self.commentID_list[3])
        if self.selectForHide_5.get() == 1 and len(self.comment_list) >= 5:
            self.lsRecoverAVA.append(self.commentID_list[4])
        if self.selectForHide_6.get() == 1 and len(self.comment_list) >= 6:
            self.lsRecoverAVA.append(self.commentID_list[5])
        if self.selectForHide_7.get() == 1 and len(self.comment_list) >= 7:
            self.lsRecoverAVA.append(self.commentID_list[6])
        if self.selectForHide_8.get() == 1 and len(self.comment_list) >= 8:
            self.lsRecoverAVA.append(self.commentID_list[7])
        if self.selectForHide_9.get() == 1 and len(self.comment_list) >= 9:
            self.lsRecoverAVA.append(self.commentID_list[8])
        if self.selectForHide_10.get() == 1 and len(self.comment_list) >= 10:
            self.lsRecoverAVA.append(self.commentID_list[9])
        
        # SQL code for hiding comment  
        connect = connection()
        for i in range(len(self.lsChangeAVA)):
            connect.c.execute(
                    """
                    UPDATE COMMENTS SET COM_AVA=0 WHERE COM_ID = '{}'
                    """.format(self.lsChangeAVA[i]))
            connect.c.execute("commit")
             
        for i in range(len(self.lsRecoverAVA)):
            connect.c.execute(
                    """
                    UPDATE COMMENTS SET COM_AVA=1 WHERE COM_ID = '{}'
                    """.format(self.lsRecoverAVA[i]))
            connect.c.execute("commit")
        connect.c.close() 
        self.saveMessage.set('saved')

    def back(self):
        self.root.destroy()
        View_Hide_Comment_Select_Product()

    def refresh(self):
        self.root.destroy() 
        Comment_Display(self.PRO_ID,self.currentPage,self.firstRow)
        
    def preset(self):
        connect = connection()
        connect.c.execute("""SELECT COUNT(*)
              FROM COMMENTS, PRODUCT
              WHERE COMMENTS.PRODUCT_PRO_ID = PRODUCT.PRO_ID 
              AND PRODUCT.PRO_ID = '{}' 
              ORDER BY COM_DATE DESC""".format(self.PRO_ID))
        for row in connect.c:
            self.totalRows = row[0]

# %% [markdown]
# #### Show Sales Order Today

# %%
# assume each page shows 10 orders
class Order_of_Today:
    
    def __init__(self,firstRow = 0, AllCurrentPage = 1):
        self.root = tk.Tk()
        self.root.geometry('850x1050')
        self.root.title("Order of Today")
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 1000)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 106, 800, 700, fill = 'white')
        
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Declare Variables
        self.firstRow = firstRow
        self.currentPage = AllCurrentPage
         
        # Company Name
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)
        label_Introduction = tk.Label(self.root, text = "Order of Today", width = 30, font = self.bodytext, fg = 'blue').place(x = 290, y = 70)
        
        # SQL
        connect = connection()
        connect.c.execute("""SELECT TO_CHAR (Sysdate, 'DD-MON-YY') AS System_date_time 
                             FROM Dual """)
        self.id_list = []
        self.date_list = []
        self.status_list =[]
        self.tran_list = []
        
        connect.c.execute(
            """
                SELECT "ORDER".ORD_ID, TO_CHAR(ORD_DATE), ORD_STATUS
                FROM "ORDER"
                WHERE TO_CHAR(SYSDATE, 'DD-MM-YYYY') = TO_CHAR(ORD_DATE, 'DD-MM-YYYY')
                OFFSET {} ROWS FETCH NEXT 5 ROWS ONLY
            """.format(self.firstRow))
        for row in connect.c:
            self.date_list.append(row[1])
            self.id_list.append(row[0])
            self.status_list.append(row[2])
            
        self.totalRows = len(self.id_list)
            
        self.remainingRow = int(self.totalRows) - int(self.firstRow) - 10
        if self.firstRow == 0:
            self.currentPage = 1
        else: self.currentPage = math.ceil(self.totalRows/10)
            
        for i in range(len(self.id_list)):
            connect.c.execute(
            """
                SELECT SUM(ODL_QUANTITY*ODL_TRAN_PRICE) TOTAL_TRAN_PRICE
                FROM ORDER_LINE,"ORDER"
                WHERE ORDER_LINE.ORDER_ORD_ID = "ORDER".ORD_ID
                AND "ORDER".ORD_ID = '{}'
                AND TO_CHAR(SYSDATE, 'DD-MM-YYYY') = TO_CHAR(ORD_DATE, 'DD-MM-YYYY')
            """.format(self.id_list[i]))
            for row in connect.c:
                self.tran_list.append(row[0])

        # Layout
        tk.Label(self.root,text='Order ID',font=self.bodytext).place(x=130,y=120)
        tk.Label(self.root,text='Order Status',font=self.bodytext).place(x=310,y=120)
        tk.Label(self.root,text='Total Transaction Price',font=self.bodytext).place(x=480,y=120)
        if len(self.id_list) < 1:
            tk.Label(self.root,text='There is not any order today.',font=self.bodytext).place(x=300,y=200)
        if len(self.id_list) > 0:
            tk.Label(self.root, text=self.id_list[0],font=self.bodytext,width=10).place(x=130,y=160)
            tk.Label(self.root, text=self.status_list[0],font=self.bodytext,width=15).place(x=300,y=160)
            tk.Label(self.root, text='$ '+str(self.tran_list[0]),font=self.bodytext,width=15).place(x=500,y=160)
            tk.Button(self.root,text='View Details', font = "bold", fg = 'orange', command = self.view1, width = 12).place(x=670,y=160)
            if len(self.id_list) > 1:
                tk.Label(self.root, text=self.id_list[1],font=self.bodytext,width=10).place(x=130,y=200)
                tk.Label(self.root, text=self.status_list[1],font=self.bodytext,width=15).place(x=300,y=200)
                tk.Label(self.root, text='$ '+str(self.tran_list[1]),font=self.bodytext,width=15).place(x=500,y=200)
                tk.Button(self.root,text='View Details', font = "bold", fg = 'orange', command = self.view2, width = 12).place(x=670,y=200)
                if len(self.id_list) > 2:
                    tk.Label(self.root, text=self.id_list[2],font=self.bodytext,width=10).place(x=130,y=240)
                    tk.Label(self.root, text=self.status_list[2],font=self.bodytext,width=15).place(x=300,y=240)
                    tk.Label(self.root, text='$ '+str(self.tran_list[2]),font=self.bodytext,width=15).place(x=500,y=240)
                    tk.Button(self.root,text='View Details', font = "bold", fg = 'orange', command = self.view3, width = 12).place(x=670,y=240)
                    if len(self.id_list) > 3:
                        tk.Label(self.root, text=self.id_list[3],font=self.bodytext,width=10).place(x=130,y=280)
                        tk.Label(self.root, text=self.status_list[3],font=self.bodytext,width=15).place(x=300,y=280)
                        tk.Label(self.root, text='$ '+str(self.tran_list[3]),font=self.bodytext,width=15).place(x=500,y=280)
                        tk.Button(self.root,text='View Details', font = "bold", fg = 'orange', command = self.view4, width = 12).place(x=670,y=280)
                        if len(self.id_list) > 4:
                            tk.Label(self.root, text=self.id_list[4],font=self.bodytext,width=10).place(x=130,y=320)
                            tk.Label(self.root, text=self.status_list[4],font=self.bodytext,width=15).place(x=300,y=320)
                            tk.Label(self.root, text='$ '+str(self.tran_list[4]),font=self.bodytext,width=15).place(x=500,y=320)
                            tk.Button(self.root,text='View Details', font = "bold", fg = 'orange', command = self.view5, width = 12).place(x=670,y=320)
                            if len(self.id_list) > 5:
                                tk.Label(self.root, text=self.id_list[5],font=self.bodytext,width=10).place(x=130,y=360)
                                tk.Label(self.root, text=self.status_list[5],font=self.bodytext,width=15).place(x=300,y=360)
                                tk.Label(self.root, text='$ '+str(self.tran_list[5]),font=self.bodytext,width=15).place(x=500,y=360)
                                tk.Button(self.root,text='View Details', font = "bold", fg = 'orange', command = self.view6, width = 12).place(x=650,y=360)
                                if len(self.id_list) > 6:
                                    tk.Label(self.root, text=self.id_list[6],font=self.bodytext,width=10).place(x=130,y=400)
                                    tk.Label(self.root, text=self.status_list[6],font=self.bodytext,width=15).place(x=300,y=400)
                                    tk.Label(self.root, text='$ '+str(self.tran_list[6]),font=self.bodytext,width=15).place(x=500,y=400)
                                    tk.Button(self.root,text='View Details', font = "bold", fg = 'orange', command = self.view7, width = 12).place(x=670,y=400)
                                    if len(self.id_list) > 7:
                                        tk.Label(self.root, text=self.id_list[7],font=self.bodytext,width=10).place(x=130,y=440)
                                        tk.Label(self.root, text=self.status_list[7],font=self.bodytext,width=15).place(x=300,y=440)
                                        tk.Label(self.root, text='$ '+str(self.tran_list[7]),font=self.bodytext,width=15).place(x=500,y=440)
                                        tk.Button(self.root,text='View Details', font = "bold", fg = 'orange', command = self.view8, width = 12).place(x=670,y=440)
                                        if len(self.id_list) > 8:
                                            tk.Label(self.root, text=self.id_list[8],font=self.bodytext,width=10).place(x=130,y=480)
                                            tk.Label(self.root, text=self.status_list[8],font=self.bodytext,width=15).place(x=300,y=480)
                                            tk.Label(self.root, text='$ '+str(self.tran_list[8]),font=self.bodytext,width=15).place(x=500,y=480)
                                            tk.Button(self.root,text='View Details', font = "bold", fg = 'orange', command = self.view9, width = 12).place(x=670,y=480)
                                            if len(self.id_list) > 9:
                                                tk.Label(self.root, text=self.id_list[9],font=self.bodytext,width=10).place(x=130,y=280)
                                                tk.Label(self.root, text=self.status_list[9],font=self.bodytext,width=15).place(x=300,y=280)
                                                tk.Label(self.root, text='$ '+str(self.tran_list[9]),font=self.bodytext,width=15).place(x=500,y=280)
                                                tk.Button(self.root,text='View Details', font = "bold", fg = 'orange', command = self.view10, width = 12).place(x=670,y=280)


        # Button
        if self.remainingRow > 0:
            tk.Button(self.root, text = 'Next page', font = "bold", fg = 'orange', command = self.nextPage, width = 18).place(x = 580, y = 650)
        if self.firstRow != 0:
            tk.Button(self.root, text = 'Previous page', font = "bold", fg = 'orange', command = self.previousPage, width = 18).place(x = 130, y = 650)
        tk.Button(self.root, text = 'Back to Manager Dashboard', font = "bold", fg = 'orange', command = self.back, width = 25).place(x = 310, y = 735)
        
        self.root.mainloop()
        
    def view1(self):
        self.root.destroy()
        Man_View_Order(self.id_list[0],self.firstRow,self.currentPage)
        
    def view2(self):
        self.root.destroy()
        Man_View_Order(self.id_list[1],self.firstRow,self.currentPage)
        
    def view3(self):
        self.root.destroy()
        Man_View_Order(self.id_list[2],self.firstRow,self.currentPage)
        
    def view4(self):
        self.root.destroy()
        Man_View_Order(self.id_list[3],self.firstRow,self.currentPage)
        
    def view5(self):
        self.root.destroy()
        Man_View_Order(self.id_list[4],self.firstRow,self.currentPage)
        
    def view6(self):
        self.root.destroy()
        Man_View_Order(self.id_list[5],self.currentPage,self.firstRow)
        
    def view7(self):
        self.root.destroy()
        Man_View_Order(self.id_list[6],self.currentPage,self.firstRow)
        
    def view8(self):
        self.root.destroy()
        Man_View_Order(self.id_list[7],self.currentPage,self.firstRow)
        
    def view9(self):
        self.root.destroy()
        Man_View_Order(self.id_list[8],self.currentPage,self.firstRow)
        
    def view10(self):
        self.root.destroy()
        Man_View_Order(self.id_list[9],self.currentPage,self.firstRow)
        
    def nextPage(self):
        self.root.destroy()
        Order_of_Today(self.firstRow + 10,self.currentPage+1)
        
    def previousPage(self):
        self.root.destroy()
        Order_of_Today(self.firstRow - 10,self.currentPage-1)
        
    def back(self):
        self.root.destroy()
        MAN_Dashboard_Class()

# %%
class Man_View_Order:
    
    def __init__(self, orderID,AllFirstRow, AllCurrentPage, firstRow=0,currentPage=1):
        self.root = tk.Tk()
        self.root.geometry('850x1050')
        self.root.title("Order of Today")
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # declare variable
        self.AllCurrentPage = AllCurrentPage
        self.AllFirstRow = AllFirstRow
        self.firstRow = firstRow
        self.currentPage = currentPage
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 1000)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 106, 800, 700, fill = 'white')
        
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Company Name
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)
        label_Introduction = tk.Label(self.root, text = "Order Details", width = 30, font = self.bodytext, fg = 'blue').place(x = 300, y = 70)

        
        # Declare Variables
        self.orderID = orderID
        
        # SQL to retrieve order details
        self.lsQuantity = []
        self.lsTranPrice = []
        self.lsProName = [];self.lsOdlID = []
        connect = connection()
        
        # find total orderline
        connect.c.execute("""SELECT COUNT(ODL_ID) FROM ORDER_LINE WHERE ORDER_ORD_ID = '{}'
        """.format(self.orderID))
        for row in connect.c:
            self.totalRows = row[0]
        
        connect.c.execute(
            """
                SELECT ODL_QUANTITY,ODL_TRAN_PRICE,PRO_NAME,ODL_ID
                FROM ORDER_LINE,PRODUCT
                WHERE ORDER_LINE.PRODUCT_PRO_ID = PRODUCT.PRO_ID
                AND ORDER_ORD_ID = '{}'
                OFFSET {} ROWS FETCH NEXT 10 ROWS ONLY
            """.format(self.orderID,self.firstRow))
        for row in connect.c:
            self.lsQuantity.append(str(row[0]))
            self.lsTranPrice.append(row[1])
            self.lsProName.append(row[2])
            self.lsOdlID.append(row[3])
        
        self.remainingRow = int(self.totalRows) - int(self.firstRow) - 10
        if self.firstRow == 0:
            self.currentPage = 1
        else: self.currentPage = math.ceil(self.totalRows/10)
         
        # display order line details
        tk.Label(self.root,text='Order Line ID',font=self.bodytext).place(x=100,y=140)
        tk.Label(self.root,text='Product Name',font=self.bodytext).place(x=270,y=140)
        tk.Label(self.root,text='Quantity',font=self.bodytext).place(x=450,y=140)
        tk.Label(self.root,text='Transaction Price',font=self.bodytext).place(x=590,y=140)
        
        if len(self.lsQuantity) > 0:
            tk.Label(self.root,text=self.lsOdlID[0],font=self.bodytext).place(x=130,y=170)
            tk.Label(self.root,text=self.lsProName[0],font=self.bodytext).place(x=280,y=170)
            tk.Label(self.root,text=self.lsQuantity[0],font=self.bodytext).place(x=470,y=170)
            tk.Label(self.root,text='$'+str(self.lsTranPrice[0])+' per unit',font=self.bodytext).place(x=600,y=170)
            if len(self.lsQuantity) >1:
                tk.Label(self.root,text=self.lsOdlID[1],font=self.bodytext).place(x=130,y=220)
                tk.Label(self.root,text=self.lsProName[1],font=self.bodytext).place(x=280,y=220)
                tk.Label(self.root,text=self.lsQuantity[1],font=self.bodytext).place(x=470,y=220)
                tk.Label(self.root,text='$'+str(self.lsTranPrice[1])+' per unit',font=self.bodytext).place(x=600,y=220)
                if len(self.lsQuantity) >2:
                    tk.Label(self.root,text=self.lsOdlID[2],font=self.bodytext).place(x=130,y=270)
                    tk.Label(self.root,text=self.lsProName[2],font=self.bodytext).place(x=280,y=270)
                    tk.Label(self.root,text=self.lsQuantity[2],font=self.bodytext).place(x=470,y=270)
                    tk.Label(self.root,text='$'+str(self.lsTranPrice[2])+' per unit',font=self.bodytext).place(x=600,y=270)
                    if len(self.lsQuantity) >3:
                        tk.Label(self.root,text=self.lsOdlID[3],font=self.bodytext).place(x=130,y=320)
                        tk.Label(self.root,text=self.lsProName[3],font=self.bodytext).place(x=280,y=320)
                        tk.Label(self.root,text=self.lsQuantity[3],font=self.bodytext).place(x=470,y=320)
                        tk.Label(self.root,text='$'+str(self.lsTranPrice[3])+' per unit',font=self.bodytext).place(x=600,y=320)
                        if len(self.lsQuantity) >4:
                            tk.Label(self.root,text=self.lsOdlID[4],font=self.bodytext).place(x=130,y=370)
                            tk.Label(self.root,text=self.lsProName[4],font=self.bodytext).place(x=280,y=370)
                            tk.Label(self.root,text=self.lsQuantity[4],font=self.bodytext).place(x=470,y=370)
                            tk.Label(self.root,text='$'+str(self.lsTranPrice[4])+' per unit',font=self.bodytext).place(x=600,y=370)
                            if len(self.lsQuantity) >5:
                                tk.Label(self.root,text=self.lsOdlID[5],font=self.bodytext).place(x=130,y=420)
                                tk.Label(self.root,text=self.lsProName[5],font=self.bodytext).place(x=280,y=420)
                                tk.Label(self.root,text=self.lsQuantity[5],font=self.bodytext).place(x=470,y=420)
                                tk.Label(self.root,text='$'+str(self.lsTranPrice[5])+' per unit',font=self.bodytext).place(x=600,y=420)
                                if len(self.lsQuantity) >6:
                                    tk.Label(self.root,text=self.lsOdlID[6],font=self.bodytext).place(x=130,y=370)
                                    tk.Label(self.root,text=self.lsProName[6],font=self.bodytext).place(x=280,y=370)
                                    tk.Label(self.root,text=self.lsQuantity[6],font=self.bodytext).place(x=470,y=370)
                                    tk.Label(self.root,text='$'+str(self.lsTranPrice[6])+' per unit',font=self.bodytext).place(x=600,y=370)
                                    if len(self.lsQuantity) >7:
                                        tk.Label(self.root,text=self.lsOdlID[7],font=self.bodytext).place(x=130,y=420)
                                        tk.Label(self.root,text=self.lsProName[7],font=self.bodytext).place(x=280,y=420)
                                        tk.Label(self.root,text=self.lsQuantity[7],font=self.bodytext).place(x=470,y=420)
                                        tk.Label(self.root,text='$'+str(self.lsTranPrice[7])+' per unit',font=self.bodytext).place(x=600,y=420)
                                        if len(self.lsQuantity) >8:
                                            tk.Label(self.root,text=self.lsOdlID[8],font=self.bodytext).place(x=130,y=470)
                                            tk.Label(self.root,text=self.lsProName[8],font=self.bodytext).place(x=280,y=470)
                                            tk.Label(self.root,text=self.lsQuantity[8],font=self.bodytext).place(x=470,y=470)
                                            tk.Label(self.root,text='$'+str(self.lsTranPrice[8])+' per unit',font=self.bodytext).place(x=600,y=470)
                                            if len(self.lsQuantity) >9:
                                                tk.Label(self.root,text=self.lsOdlID[9],font=self.bodytext).place(x=130,y=520)
                                                tk.Label(self.root,text=self.lsProName[9],font=self.bodytext).place(x=280,y=520)
                                                tk.Label(self.root,text=self.lsQuantity[9],font=self.bodytext).place(x=470,y=520)
                                                tk.Label(self.root,text='$'+str(self.lsTranPrice[9])+' per unit',font=self.bodytext).place(x=600,y=520)
                                                
                                         
        # button
        if self.currentPage != 1:
            tk.Button(self.root, text='Previous', width = 15,command = self.previousPage, font = "bold", fg = 'orange').place(x = 200, y = 660)
        if self.remainingRow > 0:
            tk.Button(self.root, text='Next', width = 15,command = self.nextPage, font = "bold", fg = 'orange').place(x = 500, y = 660)
        tk.Button(self.root,text='Back',width=15,command=self.back,font = "bold", fg = 'orange').place(x=350,y=730)

        
        self.root.mainloop()
        
    def previousPage(self):
        self.root.destroy()
        Man_View_Order(self.orderID,self.firstRow-10,self.currentPage+1)
        
    def nextPage(self):
        self.root.destroy()
        Man_View_Order(self.orderID,self.firstRow+10,self.currentPage-1)
        
    def back(self):
        self.root.destroy()
        Order_of_Today(self.AllFirstRow,self.AllCurrentPage)

# %% [markdown]
# #### View Order By Status

# %%
class View_By_Status_All:
    
    def __init__(self):
        self.root = tk.Tk()
        self.root.geometry('850x450')
        self.root.title("Choose Status to View Orders")
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Company Name
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)
        label_Introduction = tk.Label(self.root, text = "Order of Today", width = 30, font = self.bodytext, fg = 'blue').place(x = 300, y = 70)

        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Declare Variables
        self.choose_status = tk.StringVar()
        self.Error_Message = tk.StringVar()
        
        # Layout
        tk.Label(self.root,text='Choose a status to view orders:',font=self.bodytext).place(x=180,y=200)
        self.statusList = ['Preparation','On delivery','Delivered']
        self.droplist = tk.OptionMenu(self.root, self.choose_status, *self.statusList)
        self.droplist.config(width = 15)
        self.choose_status.set('Select Status') 
        self.droplist.place(x = 490, y = 200)
        tk.Label(self.root, textvariable = self.Error_Message, font=self.bodytext, fg = 'red').place(x=340,y=240)
        
        # button
        tk.Button(self.root,text='View Orders',command=self.retrieve, font = "bold", fg = 'orange',width=15).place(x=370,y=300)
        tk.Button(self.root,text='Back to Dashboard',command=self.back, font = "bold", fg = 'orange',width=15).place(x=370,y=340)
        
        self.root.mainloop()
        
    def retrieve(self):
        self.status = self.choose_status.get()
        
        if self.status == 'Select Status':
            self.Error_Message.set('Please select a status')
            return
        self.root.destroy()
        View_Order(self.status)
        
    def back(self):
        self.root.destroy()
        MAN_Dashboard_Class()

# %%
class View_Order:
    
    def __init__(self,status):
        self.root = tk.Tk()
        self.root.geometry('850x350')
        self.root.title("Choose Status to View Orders")
        
        # Declare Variables
        self.status = status
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Company Name
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)
        label_Introduction = tk.Label(self.root, text = "Order ", width = 30, font = self.bodytext, fg = 'blue').place(x = 300, y = 70)

        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # SQL retrieve orders with specific 
        connect = connection()
        connect.c.execute(
            """
                SELECT COUNT(*) FROM "ORDER" WHERE ORD_STATUS = '{}'
            """
        .format(self.status))
        for row in connect.c:
            self.noOfOrder = row[0]
        
        # layout
        tk.Label(self.root,text='Number of Order with Status '+str(self.status),font=self.bodytext).place(x=250,y=130)
        tk.Label(self.root,text=self.noOfOrder,font=self.bodytext).place(x=420,y=200)
        tk.Button(self.root,text='Back',command=self.back, font = "bold", fg = 'orange',width=15).place(x=370,y=250)
        
        self.root.mainloop()
        
    def back(self):
        self.root.destroy()
        View_By_Status_All()

# %% [markdown]
# ### Member

# %% [markdown]
# #### Member Login Page

# %%
class MEM_Login_Class:
    
    def __init__(self):
        self.root = tk.Tk()
        self.root.geometry('850x450')
        self.root.title("Login Page")
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 450)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 106, 800, 420, fill = 'white')
        line = canvas.create_line(425, 146, 425, 380)
        
        # Declare Variables
        self.UserName = tk.StringVar(); self.ErrorMessage = tk.StringVar(); self.ErrorMessage.set("")
        self.PWD = tk.StringVar()
    
        
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)

        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Titles
        label_Login = tk.Label(self.root, text = "Login", font = self.Titletext).place(x = 200, y = 130)
        label_Register = tk.Label(self.root, text = "DON'T HAVE ACCOUNT?", font = self.Titletext).place(x = 500, y = 130)

        # UserName
        label_UserName = tk.Label(self.root, text = "UserName:", font = self.bodytext).place(x = 90,y = 190)
        entry_UserName = tk.Entry(self.root, textvariable = self.UserName)
        entry_UserName.place(x = 190, y = 190) 
        
        # Password
        label_PWD = tk.Label(self.root, text = "Password:", font = self.bodytext).place(x = 90,y = 240)
        entry_PWD = tk.Entry(self.root, textvariable = self.PWD)
        entry_PWD.place(x = 190, y = 240) 
        
        # Error Message
        tk.Label(self.root, textvariable = self.ErrorMessage, fg='red',font="bold").place(x=130,y=320)
        
        # Register Information
        label_Register_lin1 = tk.Label(self.root, text = "Create your SUPER account", font = self.bodytext).place(x = 500, y = 190)
        label_Register_lin2 = tk.Label(self.root, text = "and enjoy exclusive online", font = self.bodytext).place(x = 500, y = 230)
        label_Register_lin3 = tk.Label(self.root, text = "benefits from us!", font = self.bodytext).place(x = 500, y = 270)
        
        # Button
        But_forget_pwd = tk.Button(self.root, text = "Forget Password", font = ("bold", 10), bg = 'gray',
                                width = 15, command = self.forget_pwd).place(x = 90, y = 290)
        But_login = tk.Button(self.root, text = "Login", font = "bold", fg = 'orange', width = 20,
                                command = self.login).place(x = 150, y = 350)
        But_register = tk.Button(self.root, text = "Register", font = "bold", fg = 'orange', width = 20,
                                command = self.register).place(x = 530, y = 350)

    
        self.root.mainloop()
        
    def forget_pwd(self):
        self.root.destroy()
        Forget_PWD_Class('Member')
        
    def login(self):
        self.UName_Entry = self.UserName.get()
        self.PWD_Entry = self.PWD.get()
        
        # Check whetehr is empty
        
        connect = connection()
        
        connect.c.execute("""
            SELECT MEM_USERNAME FROM MEMBER
        """)
        
        self.ls_UName = []
        for row in connect.c:
            self.ls_UName.append(row[0])
        
        # Eroor Case 3: didn't enter username
        if isempty(self.UName_Entry) is True:
            self.ErrorMessage.set("Please enter Username.")
            return
        
        # Error Case 1: No match username
        if (self.UName_Entry not in self.ls_UName):
            self.ErrorMessage.set("No such Username is found.")
            return
        
    
        connect.c.execute(
            """
                SELECT MEM_ID, MEM_PWD 
                FROM MEMBER 
                WHERE MEM_USERNAME = '{}'
            """.format(self.UName_Entry))

        for row in connect.c:
            self.retrievePWD = row[1]
            self.MEM_ID = row[0]
        
        # Error Case 2: PWD and username doesn't match
        if (self.PWD_Entry != self.retrievePWD):
            self.ErrorMessage.set("The Password does not match with the UserName")
            return
        
        # Eroor Case 3: didn't enter password
        if isempty(self.PWD_Entry) is True:
            self.ErrorMessage.set("Please enter Password.")
            return

        self.root.destroy()
        Main_Page_Class(self.MEM_ID)
        
    def register(self):
        self.root.destroy()
        MEM_Register_Class()

# %% [markdown]
# #### Member Registration Page

# %%
class MEM_Register_Class:
    
    def __init__(self):
        self.root = tk.Tk()
        self.root.geometry('850x450')
        self.root.title('Registration Page')
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        self.errortext = tkFont.Font(size = 13, weight = "bold")
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 450)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 106, 800, 420, fill = 'white')

        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Declare Variables
        self.FName = tk.StringVar()
        self.MName = tk.StringVar()
        self.LName = tk.StringVar()
        self.UserName = tk.StringVar()
        self.PWD = tk.StringVar()
        self.Confirmed_PWD = tk.StringVar()
        self.GENDER = tk.StringVar()
        self.EMAIL = tk.StringVar()
        self.MOBILE = tk.StringVar()
        self.ADD_Line_1 = tk.StringVar()
        self.ADD_Line_2 = tk.StringVar()
        self.ADD_Country = tk.StringVar()
        self.ErrorMessage = tk.StringVar(); self.ErrorMessage.set('')
        
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)
        label_Introduction = tk.Label(self.root, text = "Member Registration", width = 20, font = self.bodytext, fg = 'blue').place(x = 350, y = 70)
        
        # Title
        label_Register = tk.Label(self.root, text = "Register",width = 20, font = self.Titletext).place(x = 300, y = 110)
        
        # First Name
        label_FName = tk.Label(self.root, text = "First Name*").place(x = 55, y = 142)
        entry_FName = tk.Entry(self.root, textvariable = self.FName, width = 15).place(x = 140, y = 140)
        
        # Middle Name
        label_MName = tk.Label(self.root, text = "Middle Name").place(x = 300, y = 142)
        entry_MName = tk.Entry(self.root, textvariable = self.MName,width = 15).place(x = 400, y = 140)
        
        # Last Name
        label_LName = tk.Label(self.root, text = "Last Name*").place(x = 570, y = 142)
        entry_LName = tk.Entry(self.root, textvariable = self.LName,width = 15).place(x = 650, y = 140)
        
        # UserName
        label_UserName = tk.Label(self.root, text = "Username*").place(x = 55, y = 180)
        entry_UserName = tk.Entry(self.root, textvariable = self.UserName,width = 35).place(x = 130, y = 180)
        
        # Gender
        label_GENDER = tk.Label(self.root, text='Gender*').place(x = 540,y = 180)
        gender = ['Male', 'Female']
        self.GENDER.set(gender[0])
        gender = tk.OptionMenu(self.root, self.GENDER, *gender)
        gender.config(width = 15)
        gender.place(x = 600, y = 180)
        
        # Password
        label_PWD = tk.Label(self.root, text = "Password*").place(x = 55, y = 222)
        entry_PWD = tk.Entry(self.root, show='*', textvariable = self.PWD,width = 25).place(x = 130, y = 222)
        
        # Confirmed Password
        label_Confirmed_PWD = tk.Label(self.root, text = "Confirmed Password*").place(x = 400, y = 222)
        entry_Confirmed_PWD = tk.Entry(self.root, show='*', textvariable = self.Confirmed_PWD,width = 25).place(x = 555, y = 222)
        
        # Email
        label_EMAIL = tk.Label(self.root, text = "Email*").place(x = 55, y = 262)
        entry_EMAIL = tk.Entry(self.root, textvariable = self.EMAIL,width = 25).place(x = 130, y = 262)
        
        # Mobile
        label_MOBILE = tk.Label(self.root, text = "Mobile*").place(x = 420, y = 262)
        entry_MOBILE = tk.Entry(self.root, textvariable = self.MOBILE,width = 25).place(x = 480, y = 262)
        
        # Address Line 1
        label_ADD_Line_1 = tk.Label(self.root, text = "Address (Line 1)*").place(x = 55, y = 302)
        entry_ADD_Line_1 = tk.Entry(self.root, textvariable = self.ADD_Line_1,width = 25).place(x = 180, y = 302)
        
        # Address Line 2
        label_ADD_Line_2 = tk.Label(self.root, text = "Address (Line 2)*").place(x = 430, y = 302)
        entry_ADD_Line_2 = tk.Entry(self.root, textvariable = self.ADD_Line_2,width = 25).place(x = 550, y = 302)
        
        # Country 
        countries_details = countries # imported from countries.py
        country = []
        for i in countries_details:
            country.append(i['name'])
        label_ADD_Country = tk.Label(self.root, text = "Country*").place(x = 55, y = 342)
        self.ADD_Country.set(country[0])
        country = tk.OptionMenu(self.root, self.ADD_Country, * country)
        country.config(width = 33)
        country.place(x = 130, y = 342)
        
        # Error 
        errorMessage = tk.Label(self.root, textvariable = self.ErrorMessage, font = self.errortext, fg = 'red').place(x = 460, y = 345)
        
        # Buttons
        But_submit = tk.Button(self.root, text = "Register", font = "bold", fg = 'orange', width = 20,
                                command = self.insert_member).place(x = 140, y = 380)
        But_login = tk.Button(self.root, text = "Back to Login Page", font = "bold", fg = 'orange', width = 20,
                                command = self.back).place(x = 500, y = 380)
        
        self.root.mainloop()
        
    def insert_member(self):
        # TODO
        # Message box saying successful registration
        self.FName_info = self.FName.get()
        self.MName_info = self.MName.get()
        self.LName_info = self.LName.get()
        self.UserName_info = self.UserName.get()
        self.PWD_info = self.PWD.get()
        self.Confirmed_PWD_info = self.Confirmed_PWD.get()
        self.GENDER_info = self.GENDER.get()
        self.EMAIL_info = self.EMAIL.get()
        self.MOBILE_info = self.MOBILE.get()
        self.ADD_Line_1_info = self.ADD_Line_1.get()
        self.ADD_Line_2_info = self.ADD_Line_2.get()
        self.ADD_Country_info = self.ADD_Country.get()
        
        # check if username clash
        self.existUNameList = []
        connect =connection()
        connect.c.execute("""SELECT MEM_USERNAME FROM MEMBER""")
        for row in connect.c:
            self.existUNameList.append(row[0])
        connect.c.close()
        if self.UserName_info in self.existUNameList:
            self.ErrorMessage.set('This username has been taken.')
            return
        
        # Check is empty
        if isempty(self.FName_info, self.LName_info, self.UserName_info, self.PWD_info, self.Confirmed_PWD_info, 
                    self.GENDER_info, self.EMAIL_info, self.MOBILE_info, self.ADD_Line_1_info,
                    self.ADD_Line_2_info, self.ADD_Country_info) == True: 
            self.ErrorMessage.set('Entries with "*" cannot be left blank.')
            return
        
        # Check invalid inputs
        if self.PWD_info != self.Confirmed_PWD_info: 
            self.ErrorMessage.set("Your confirmed password doesn't match with password.")
            return
        if '@' not in self.EMAIL_info or '.' not in self.EMAIL_info: 
            self.ErrorMessage.set('Invalid Email.')
            return
        
        # Check invalid length
        if Varchar_len_check(self.FName_info,30) == False: 
            self.ErrorMessage.set('First Name cannot exceed 30 characters')
            return
        if Varchar_len_check(self.MName_info,30) == False: 
            self.ErrorMessage.set('Middle Name cannot exceed 30 characters')
            return
        if Varchar_len_check(self.LName_info,30) == False: 
            self.ErrorMessage.set('Last Name cannot exceed 30 characters')
            return
        if Varchar_len_check(self.UserName_info,30) == False:
            self.ErrorMessage.set('Username cannot exceed 30 characters')
            return
        if Varchar_len_check(self.PWD_info,16) == False:
            self.ErrorMessage.set('Password cannot exceed 16 characters')
            return
        if Varchar_len_check(self.EMAIL_info,30) == False:
            self.ErrorMessage.set('Email cannot exceed 30 characters')
            return
        if Varchar_len_check(self.MOBILE_info,15) == False:
            self.ErrorMessage.set('Mobile cannot exceed 15 digits')
            return
        try:
            self.MOBILE_info = int(self.MOBILE_info)
        except:
            self.ErrorMessage.set('The Mobile must be an integer')
            return
        if Varchar_len_check(self.ADD_Line_1_info,100) == False:
            self.ErrorMessage.set('Address Line 1 cannot exceed 100 characters')
            return
        if Varchar_len_check(self.ADD_Line_2_info,50) == False:
            self.ErrorMessage.set('Address Line 2 cannot exceed 50 characters')
            return

        
        # Clear all previous input
        self.FName.set('')
        self.MName.set('')
        self.LName.set('')
        self.UserName.set('')
        self.PWD.set('')
        self.Confirmed_PWD.set('')
        self.EMAIL.set('')
        self.MOBILE.set('')
        self.ADD_Line_1.set('')
        self.ADD_Line_2.set('')
        self.ErrorMessage.set('')
        
        # Calculate the Member ID    
        connect = connection()
        
        connect.c.execute(
            """
              SELECT MEM_ID 
              FROM MEMBER
            """)

        # Generate the new 
        ls_ID = []
        for row in connect.c:
            ls_ID.append(int(row[0]))
        for i in range(len(ls_ID) + 1):
            if i not in ls_ID:
                Mem_ID = str(i)
                break
        # Convert gender into number
        if self.GENDER.get() == 'Female':
            self.GENDER_info = 1
        else:
            self.GENDER_info = 0
        
        # convert MName to empty string if omitted
        if len(self.MName_info) == 0:
            self.MName = ''

        connect.c.execute(
            """
              INSERT INTO MEMBER 
              VALUES ('{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}')
            """.format(Mem_ID, self.FName_info, self.MName_info, self.LName_info, self.EMAIL_info, self.UserName_info,
                       self.PWD_info, self.MOBILE_info, self.ADD_Line_1_info, self.ADD_Line_2_info, 
                       self.ADD_Country_info, self.GENDER_info))
            
        connect.c.execute("commit")
        connect.c.close()
        
        if self.MName_info == '': 
            welcome_email(self.FName_info, self.LName_info, self.PWD_info, self.UserName_info, self.EMAIL_info)
        else: 
            welcome_email(self.FName_info, self.LName_info, self.PWD_info, self.UserName_info, self.EMAIL_info, Mname = self.MName_info)
        
        self.root.destroy()
        MEM_Login_Class()
        
    def back(self):
        self.root.destroy()
        MEM_Login_Class()

# %% [markdown]
# #### Forget Password Page [Finished]

# %%
class Forget_PWD_Class:
    
    def __init__(self, identity):
        self.root = tk.Tk()
        self.root.geometry('850x450')
        self.root.title("Forget Password")
        self.identity = identity
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "normal")
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 450)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 106, 800, 420, fill = 'white')
        
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Declare Variables
        self.EMAIL = tk.StringVar()
        self.ErrorMessage = tk.StringVar();self.ErrorMessage.set("")
        
        # Company Name
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)
        
        # Title and Descriptions
        label_forget = tk.Label(self.root, text = "Forget Password", font = self.Titletext).place(x = 320, y = 130)
        label_verification = tk.Label(self.root, text = "Email Verification", font = self.bodytext).place(x = 60, y = 180)
        label_line = tk.Label(self.root, text = "Please enter your registered email. You will receive a email to retrieve password", font = self.bodytext).place(x = 60, y = 220)
        
        # Email Entry Box
        entry_email = tk.Entry(self.root, textvariable = self.EMAIL, width = '80').place(x = 60,y = 260)
        
        # ErrorMessageEmpty
        errorMessage = tk.Label(self.root, textvariable=self.ErrorMessage,font= self.bodytext, fg = 'red').place(x=60,y=290)
        
        # Buttons
        But_submit = tk.Button(self.root, text = 'Submit', command = self.send_email, font = "bold", fg = 'orange', width = 20).place(x = 320, y = 330)
        But_return = tk.Button(self.root, text = 'Back to Login Page', command = self.back, font = "bold", fg = 'orange', width = 20).place(x = 320, y = 360)
        
        self.root.mainloop()
        
    def back(self):
        self.root.destroy()
        if self.identity == 'Staff': Staff_Login_Class()    
        elif self.identity =='Member': 
            MEM_Login_Class()
    
    def send_email(self):
        
        self.EMAIL_info = self.EMAIL.get()
        # Check invalid inputs
        if '@' not in self.EMAIL_info or self.EMAIL_info.count('@') > 1:
            self.ErrorMessage.set("This is not a valid email.")
            return
        
        elif len(self.EMAIL_info) > 30:
            self.ErrorMessage.set("Your email cannot be more than 30 characters.")
            return
        

        # TODO -> By identity
        connect = connection()
        
        ls_EMAIL = []
        # Retrieve all Email from MEM Database
        if self.identity == 'Member':
            connect.c.execute(
                """
                  SELECT MEM_EMAIL
                  FROM MEMBER
                """)
        else:
            connect.c.execute(
                """
                  SELECT STAFF_EMAIL
                  FROM STAFF
                """)
            
        # Put Email into ls_EMAIL
        for row in connect.c:
            ls_EMAIL.append(row[0])
            
        if self.EMAIL_info not in ls_EMAIL:
            self.ErrorMessage.set('We cannot recognize this email, please enter another one.')
            return 

        # Retrieve the password
        if self.identity == 'Member':
            connect.c.execute(
                """
                   Select MEM_PWD, MEM_FNAME, MEM_MNAME, MEM_LNAME, MEM_EMAIL
                   FROM MEMBER
                   WHERE MEM_EMAIL = '{}'
                """.format(self.EMAIL_info))
        else:
            connect.c.execute(
                """
                   Select STAFF_PWD, STAFF_FNAME, STAFF_MNAME, STAFF_LNAME, STAFF_EMAIL
                   FROM STAFF
                   WHERE STAFF_EMAIL = '{}'
                """.format(self.EMAIL_info))
        
        # Assign the password to a variable
        for row in connect.c:
            self.PWD = row[0]
            self.Fname = row[1]
            self.Mname = row[2]
            self.Lname = row[3]
            self.email = row[4]
        
        connect.c.close()
        
        # Clear all previous input
        self.EMAIL.set('')
        
        if self.Mname == None: 
            password_email(self.Fname, self.Lname, self.PWD, self.email)
        else: 
            password_email(self.Fname, self.Lname, self.PWD, self.email, Mname = self.Mname)
            
        self.root.destroy()
        EMAIL_Verification_Class(self.identity, self.PWD)

# %% [markdown]
# #### Email Verfication Page [Finished]

# %%
class EMAIL_Verification_Class:
    def __init__(self, identity, PWD):
        self.root = tk.Tk()
        self.root.geometry('850x450')
        self.root.title("Email Verification Page")
        self.identity = identity
        self.PWD = PWD
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "normal")
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 450)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 106, 800, 420, fill = 'white')
        
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50, y = 0)
        
        # Company Name
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)

        # Descriptions
        label_retrieve = tk.Label(self.root, text = 'Your password has been sent to your registered email already',font = self.bodytext).place(x = 100, y = 180)
        label_retrieve_2 = tk.Label(self.root, text = 'and your password is ' + self.PWD , font = self.bodytext).place(x = 100, y = 210)
        
        # Buttons
        But_confirm = tk.Button(self.root,text = 'Confirm', command = self.back, font = "bold", fg = 'orange', width = 20).place(x = 180,y = 360)
        But_resend = tk.Button(self.root, text = 'Enter New Email', command = self.verification, font = "bold", fg = 'orange', width = 20).place(x = 500,y = 360)
        
        self.root.mainloop()
        
    def back(self):
        self.root.destroy()
        if self.identity == 'Member': MEM_Login_Class()
        else: Staff_Login_Class()
    
    def verification(self):
        self.root.destroy()
        if self.identity == 'Member': Forget_PWD_Class('Member')
        else: Forget_PWD_Class('Staff')

# %% [markdown]
# #### Main Page after login [Finished]

# %%
class Main_Page_Class:
    def __init__(self, MEM_ID):
        self.root = tk.Tk()
        self.root.geometry('850x450')
        self.root.title("Main Page")
        self.MEM_ID = MEM_ID
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 450)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 106, 800, 420, fill = 'white')
        
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Declare Variables
        self.UserName = tk.StringVar()
        self.PWD = tk.StringVar()
        
        # Company Name
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)
        
        # Buttons
        But_edit_info = tk.Button(self.root, text = 'View and Edit Personal Information' , width = 25, command=self.edit_info, font = "bold", fg = 'orange').place(x = 150,y = 180)
        But_search = tk.Button(self.root, text = 'Search Products or Brands', width = 25, command = self.search, font = "bold", fg = 'orange').place(x = 470,y = 180)
        But_history = tk.Button(self.root, text = 'View Previous Order', width = 25, command = self.history, font = "bold", fg = 'orange').place(x = 150,y = 230)
        But_cart = tk.Button(self.root, text = 'View Shopping Cart', width = 25, command = self.shct, font = "bold", fg = 'orange').place(x = 470,y = 230)
        But_logout = tk.Button(self.root, text = 'Logout', width = 25,command = self.logout, font = "bold", fg = 'orange').place(x = 310,y = 360)

        self.root.mainloop()
        
    def edit_info(self):
        self.root.destroy()
        Edit_Personal_Information_Class(self.MEM_ID)
    
    def search(self):
        self.root.destroy()
        Search_Class(self.MEM_ID)
        
    def shct(self):
        self.root.destroy()
        Shopping_Cart_Class(self.MEM_ID, [], 0)
      
    def history(self):
        self.root.destroy()
        All_History(self.MEM_ID)
    
    def logout(self):
        self.root.destroy()
        MEM_Login_Class()

# %% [markdown]
# #### Searching Page [Finished]

# %%
class Search_Class:
    def __init__(self, MEM_ID):
        self.root = tk.Tk()
        self.root.geometry('850x450')
        self.root.title("Search Page")
        self.MEM_ID = MEM_ID
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 450)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 106, 800, 420, fill = 'white')
        
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Declare Variables
        self.ProName = tk.StringVar()
        self.Brand = tk.StringVar()
        
        # Company Name
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)
        
        #Description
        label_description = tk.Label(self.root, text = 'You can only search either by product or brand', font = self.bodytext, fg = 'red').place(x = 210, y = 140)
        
        # Product
        label_product = tk.Label(self.root, text = 'Search By Product:', font = self.bodytext).place(x = 190, y = 190)
        entry_product = tk.Entry(self.root, textvariable = self.ProName, width = 30).place(x = 390, y = 190)
        
        # Brand
        label_brand = tk.Label(self.root, text = 'Search By Brand:', font = self.bodytext).place(x = 190, y = 240)
        entry_brand = tk.Entry(self.root, textvariable = self.Brand, width = 30).place(x = 390, y = 240)
        
        # Buttons
        But_back = tk.Button(self.root, text = 'Search', width = 25, command = self.search, font = "bold", fg = 'orange').place(x = 160, y = 350)
        But_back = tk.Button(self.root, text = 'Back to Main Page', width = 25, command = self.back, font = "bold", fg = 'orange').place(x = 450, y = 350)
        
        self.root.mainloop()
    
    def search(self):
        # TODO -> Pass the value to the next page
        # If statement [Either one + both two has + neither two has]
        if self.ProName.get() == '' and isempty(self.Brand.get()) != True:
            self.root.destroy()
            Search_Result_Class(self.MEM_ID, self.Brand.get(), 'Brand')
        elif isempty(self.ProName.get()) != True and self.Brand.get() == '':
            self.root.destroy()
            Search_Result_Class(self.MEM_ID, self.ProName.get(), 'Product')
        else: return
        
    def back(self):
        self.root.destroy()
        Main_Page_Class(self.MEM_ID)

# %% [markdown]
# #### Search Result Page [Finished]

# %%
# Limit search display to 5 items per page
# Retrieve product information and allow them to add shopping cart
class Search_Result_Class:
    def __init__(self, MEM_ID, KW, method, first_row = 0):
        self.root = tk.Tk()
        self.root.geometry('850x670')
        self.root.title('Search Result')
        self.MEM_ID = MEM_ID; self.search_kw = KW; self.method = method; self.first_row = first_row
        self.PRO_ID_ls = []; self.PRO_NAME_ls = []; self.PRO_PRICE_ls = []; self.PRO_BRAND_ls = []
        self.pre_set()
        
        # create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        self.resulttext = tkFont.Font(family = "Courier", size = 15, weight = "normal")
        self.warningtext = tkFont.Font(family = "Courier", size = 30, weight = "normal")
        
        # declare variable
        self.name = tk.StringVar(); self.price = tk.IntVar(); self.ava = tk.IntVar()
        self.brand = tk.StringVar(); self.discountR = tk.IntVar(); self.inventory = tk.IntVar()
        self.origin = tk.StringVar(); self.description = tk.StringVar()
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 800)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 650, 800, 120, fill = 'white')
        heading = canvas.create_rectangle(50, 120, 800, 170, fill = 'grey')
        
        # Logo and Page Info
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 30)
        label_Introduction = tk.Label(self.root, text = "Product Search Result", width = 20, font = self.bodytext, fg = 'blue').place(x = 340, y = 70)
        
        # Assign values to variables
        PRO_ID = tk.StringVar(); PRO_ID1 = tk.StringVar(); PRO_ID2 = tk.StringVar(); PRO_ID3 = tk.StringVar()
        PRO_ID4 = tk.StringVar(); PRO_ID5 = tk.StringVar(); PRO_name = tk.StringVar()
        
        # Layout
        tk.Label(self.root, text = 'The search result of keyword: '+ self.search_kw, fg = 'orange', bg = 'gray',font=self.bodytext).place(x = 65 , y = 135)
        tk.Label(self.root,text = 'Total Number of related products: '+ str(self.total_row), fg = 'orange', bg = 'gray', font = self.bodytext).place(x = 460, y = 135)
        if self.showing_rows == 0:
            if self.method == 'Brand':
                tk.Label(self.root, text = 'There is no such Brand as ' + self.search_kw, font = self.warningtext, fg = 'red').place(x = 140, y = 380)
            if self.method == 'Product':
                tk.Label(self.root, text = 'There is no such Product as ' + self.search_kw, font = self.warningtext, fg = 'red').place(x = 140, y = 380)
        elif self.showing_rows >= 1:
            # Title
            tk.Label(self.root, text = 'Product Name', font = self.bodytext).place(x = 100, y = 190)
            tk.Label(self.root, text = 'Price', font = self.bodytext).place(x = 310, y  = 190)
            tk.Label(self.root, text = 'Brand', font = self.bodytext).place(x = 430, y = 190)
            # Product Details displayed on screen
            tk.Label(self.root, text = self.PRO_NAME_ls[0], font = self.resulttext).place(x = 120, y = 230)
            tk.Label(self.root, text = '$' + str(self.PRO_PRICE_ls[0]), font = self.resulttext).place(x = 307, y = 230)
            tk.Label(self.root, text = self.PRO_BRAND_ls[0], font = self.resulttext).place(x = 430, y = 230)
            tk.Button(self.root, text = 'View Product Details', command = lambda: self.View_Details(self.PRO_ID_ls[0]), font = "bold", fg = 'orange', width = 15).place(x = 540, y = 230)
            tk.Button(self.root, text = 'Add to Cart', command = lambda: self.Add_Product_to_Cart(self.PRO_ID_ls[0]), font = "bold", fg = 'orange', width = 10).place(x = 690, y = 230)
            
            if self.showing_rows >= 2:
                tk.Label(self.root, text = self.PRO_NAME_ls[1], font = self.resulttext).place(x = 120, y = 290)
                tk.Label(self.root, text  = '$' + str(self.PRO_PRICE_ls[1]), font = self.resulttext).place(x = 307, y = 290)
                tk.Label(self.root, text = self.PRO_BRAND_ls[1], font = self.resulttext).place(x = 430, y = 290)
                tk.Button(self.root, text = 'View Product Details', command = lambda: self.View_Details(self.PRO_ID_ls[1]), font = "bold", fg = 'orange', width = 15).place(x = 540, y = 290)
                tk.Button(self.root, text = 'Add to Cart', command = lambda: self.Add_Product_to_Cart(self.PRO_ID_ls[1]), font = "bold", fg = 'orange', width = 10).place(x = 690, y = 290)
                
                if self.showing_rows >= 3:
                    tk.Label(self.root, text = self.PRO_NAME_ls[2], font = self.resulttext).place(x = 120, y = 350)
                    tk.Label(self.root, text  = '$' + str(self.PRO_PRICE_ls[2]), font = self.resulttext).place(x = 307, y = 350)
                    tk.Label(self.root, text = self.PRO_BRAND_ls[2], font = self.resulttext).place(x = 430, y = 350)
                    tk.Button(self.root, text = 'View Product Details', command = lambda: self.View_Details(self.PRO_ID_ls[2]), font = "bold", fg = 'orange', width = 15).place(x = 540, y = 350)
                    tk.Button(self.root, text = 'Add to Cart', command = lambda: self.Add_Product_to_Cart(self.PRO_ID_ls[2]), font = "bold", fg = 'orange', width = 10).place(x = 690, y = 350)
                    
                    if self.showing_rows >= 4:
                        tk.Label(self.root, text = self.PRO_NAME_ls[3], font = self.resulttext).place(x = 120, y = 410)
                        tk.Label(self.root, text  = '$' + str(self.PRO_PRICE_ls[3]), font = self.resulttext).place(x = 307, y = 410)
                        tk.Label(self.root, text = self.PRO_BRAND_ls[3], font = self.resulttext).place(x = 430, y = 410)
                        tk.Button(self.root, text = 'View Product Details', command = lambda: self.View_Details(self.PRO_ID_ls[3]), font = "bold", fg = 'orange', width = 15).place(x = 540, y = 410)
                        tk.Button(self.root, text = 'Add to Cart', command = lambda: self.Add_Product_to_Cart(self.PRO_ID_ls[3]), font = "bold", fg = 'orange', width = 10).place(x = 690, y = 410)

                        if self.showing_rows == 5:
                            tk.Label(self.root, text = self.PRO_NAME_ls[4], font = self.resulttext).place(x = 120, y = 470)
                            tk.Label(self.root, text  = '$' + str(self.PRO_PRICE_ls[4]), font = self.resulttext).place(x = 307, y = 470)
                            tk.Label(self.root, text = self.PRO_BRAND_ls[4], font = self.resulttext).place(x = 430, y = 470)
                            tk.Button(self.root, text = 'View Product Details', command = lambda: self.View_Details(self.PRO_ID_ls[4]), font = "bold", fg = 'orange', width = 15).place(x = 540, y = 470)
                            tk.Button(self.root, text = 'Add to Cart', command = lambda: self.Add_Product_to_Cart(self.PRO_ID_ls[4]), font = "bold", fg = 'orange', width = 10).place(x = 690, y = 470)                         
        
        # button
        if self.remaining_row > 0:
            tk.Button(self.root, text = 'Next page', font = "bold", fg = 'orange', command = self.next_page, width = 18).place(x = 580, y = 550)
        if self.first_row != 0:
            tk.Button(self.root, text = 'Previous page', font = "bold", fg = 'orange', command = self.previous_page, width = 18).place(x = 130, y = 550)
        tk.Button(self.root, text = 'Back to Search', font = "bold", fg = 'orange', command = self.back, width = 18).place(x = 350, y = 600)
        
        self.root.mainloop()
    
    def pre_set(self):
        connect = connection()

        ## SQL to retrieve product name, price, ava, brand, inventory, discountR, origin and description
        ## search by brand
        connect = connection()
        
        if self.method == 'Brand':
            # Retreive the total amount of Result
            connect.c.execute(
                """
                    SELECT COUNT(*)
                    FROM PRODUCT
                    WHERE upper(PRO_BRAND) LIKE '%{}%' AND PRO_AVA != 0
                """.format(self.search_kw.upper()))
            
            for row in connect.c:
                self.total_row = row[0]
                self.remaining_row = row[0] - self.first_row - 5
                
            # Retreive the total amount of Shooping Cart
            connect.c.execute(
                """
                    SELECT PRO_ID, PRO_NAME, PRO_PRICE, PRO_BRAND, PRO_DISCOUNT_RATE
                    FROM PRODUCT
                    WHERE upper(PRO_BRAND) LIKE '%{}%' AND PRO_AVA != 0
                    ORDER BY ROWNUM
                    OFFSET {} ROWS FETCH NEXT 5 ROWS ONLY
                """.format(self.search_kw.upper(), self.first_row))
        
        
        if self.method == 'Product':
            # Retreive the total amount of Result
            connect.c.execute(
                """
                    SELECT COUNT(*)
                    FROM PRODUCT
                    WHERE upper(PRO_NAME) LIKE '%{}%' AND PRO_AVA != 0
                """.format(self.search_kw.upper()))
            
            for row in connect.c:
                self.total_row = row[0]
                self.remaining_row = row[0] - self.first_row - 5
                
            # Retreive the total amount of Shooping Cart
            connect.c.execute(
                """
                    SELECT PRO_ID, PRO_NAME, PRO_PRICE, PRO_BRAND, PRO_DISCOUNT_RATE
                    FROM PRODUCT
                    WHERE upper(PRO_NAME) LIKE '%{}%' AND PRO_AVA != 0
                    ORDER BY ROWNUM
                    OFFSET {} ROWS FETCH NEXT 5 ROWS ONLY
                """.format(self.search_kw.upper(), self.first_row))

            
        for row in connect.c:
            self.PRO_ID_ls.append(row[0])
            self.PRO_NAME_ls.append(row[1])
            self.PRO_PRICE_ls.append(round(row[2] * (1 - row[4] / 100), 2))
            self.PRO_BRAND_ls.append(row[3])
        
        connect.c.close()
        
        self.showing_rows = len(self.PRO_ID_ls)
  
    def Add_Product_to_Cart(self, PRO_ID):
        self.root.destroy()
        Insert_SPCT_Information_Class(self.MEM_ID, PRO_ID, self.search_kw, self.method, self.first_row)
                                                                                              
    def View_Details(self, PRO_ID):
        self.root.destroy()
        View_Details_Class(self.MEM_ID, PRO_ID, self.search_kw, self.method, self.first_row)
                                                                                             
    def back(self):
        self.root.destroy()
        Search_Class(self.MEM_ID)
    
    def next_page(self):
        self.root.destroy()
        if self.method == 'Brand':
            Search_Result_Class(self.MEM_ID, self.search_kw, 'Brand', self.first_row + 5)
        else: Search_Result_Class(self.MEM_ID, self.search_kw, 'Product', self.first_row + 5)
    
    def previous_page(self):
        self.root.destroy()
        if self.method == 'Brand':
            Search_Result_Class(self.MEM_ID, self.search_kw, 'Brand', self.first_row - 5)
        else: Search_Result_Class(self.MEM_ID, self.search_kw, 'Product', self.first_row - 5)

# %%
class View_Details_Class:
    
    def __init__(self, MEM_ID, PRO_ID, KW, method, first_row):
        self.root = tk.Tk()
        self.root.geometry('850x600')
        self.root.title('Product Details')
        self.MEM_ID = MEM_ID; self.PRO_ID = PRO_ID; self.key_word = KW; self.method = method
        self.first_row = first_row;
        self.pre_set()
        
        PRO_ID = tk.StringVar()
        PRO_ID = PRO_ID
        
        # create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.detailtext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.protext = tkFont.Font(family = "Courier", size = 15, weight = "normal")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Logo and Page Info
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 30)
        label_Introduction = tk.Label(self.root, text = "Product Details", width = 20, font = self.bodytext, fg = 'blue').place(x = 340, y = 70)
    
        # Layout
        tk.Label(self.root, text = 'Product Name',font = ("Courier", 20,'bold')).place(x = 80, y = 110)
        tk.Label(self.root, text = 'Price', font = self.detailtext).place(x = 400, y = 110)
        tk.Label(self.root, text = 'Brand', font = self.detailtext).place(x = 650, y = 110)
        tk.Label(self.root, text = 'Origin', font = self.detailtext).place(x = 80, y = 230)
        tk.Label(self.root, text = 'Discount Rate', font = self.detailtext).place(x = 360, y = 230)
        tk.Label(self.root, text = 'Description', font = self.detailtext).place(x = 80, y = 350)
        tk.Label(self.root, text = 'Rating', font = self.detailtext).place(x = 650, y = 230)
        tk.Label(self.root, text = self.PRO_name, font = self.protext).place(x = 80, y = 150)
        tk.Label(self.root, text = '$' + str(self.PRO_price), font = self.protext).place(x = 400, y = 150)
        tk.Label(self.root, text = self.PRO_brand, font = self.protext).place(x = 650, y = 150)
        tk.Label(self.root, text = self.PRO_origin, font = self.protext).place(x = 80, y = 270)
        if self.PRO_discountR != 0:
            tk.Label(self.root, text = str(self.PRO_discountR) + '% off', font = self.protext, fg = 'red').place(x = 390, y = 270)
        else:
            tk.Label(self.root, text = '-', font = self.protext).place(x = 425, y = 270)
        if self.rating != 0:
            tk.Label(self.root, text = str(round(self.rating, 2)) + ' / 5', font = self.protext).place(x = 652, y = 270)
        else:
            tk.Label(self.root, text = 'N/A', font = self.protext).place(x = 670, y = 270)
        tk.Label(self.root, text = self.PRO_description, font = self.protext).place(x = 80, y = 390)
        
        # button
        tk.Button(self.root, text = 'Back',command = self.back,font = "bold", fg = 'orange', width = 18).place(x = 230, y = 520)
        tk.Button(self.root, text = 'View Comments', command = self.view_comments, \
                        font = "bold", fg = 'orange', width = 18).place(x = 490, y = 520)
        self.root.mainloop()
    
    def pre_set(self):
        
        # SQL code to retrieve all product info with corresponding PRO_ID
        connect = connection()
        
        # Retreive the total amount of Result
        connect.c.execute(
            """
                SELECT PRO_NAME, PRO_PRICE, PRO_BRAND, PRO_ORIGIN, PRO_DISCOUNT_RATE, PRO_SPECIFICATIONS
                FROM PRODUCT
                WHERE PRO_ID = '{}' 
            """.format(self.PRO_ID))
        
        for row in connect.c:
            self.PRO_name = row[0]
            self.PRO_price = row[1]
            self.PRO_brand = row[2]
            self.PRO_origin = row[3]
            self.PRO_discountR = row[4]
            self.PRO_description = row[5]
        
        connect.c.execute(
            """
                SELECT COM_RATING
                FROM COMMENTS
                WHERE PRODUCT_PRO_ID = '{}' AND COM_AVA != 0 
            """.format(self.PRO_ID))
        
        rating_ls = []
        for row in connect.c:
            rating_ls.append(int(row[0]))
            
        if len(rating_ls) != 0:
            self.rating = sum(rating_ls) / len(rating_ls)
        else: self.rating = 0
            
        connect.c.close()
        
    def back(self):
        self.root.destroy()
        Search_Result_Class(self.MEM_ID, self.key_word, self.method, self.first_row)
        
    def view_comments(self):
        self.root.destroy()
        View_Comments_Class(self.MEM_ID, self.PRO_ID, self.key_word, self.method, self.first_row)

# %%
# Assume each page shows at most 7 comments
class View_Comments_Class:
    def __init__(self, MEM_ID, PRO_ID, KW, method, first_row_pro, first_row_com = 0):
        self.root = tk.Tk()
        self.root.geometry('850x1000')
        self.root.title('Comment Page')
        self.MEM_ID = MEM_ID; self.PRO_ID = PRO_ID; self.key_word = KW; self.method = method
        self.first_row_pro = first_row_pro; self.first_row_com = first_row_com; self.COM_COMMENT_ls = []
        self.pre_set()
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 18, weight = "bold")
        self.comtext = tkFont.Font(family = "Courier", size = 15, weight = "normal")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Logo and Page Info
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 30)
        label_Introduction = tk.Label(self.root, text = "Comments", width = 20, font = self.bodytext, fg = 'blue').place(x = 340, y = 70)
        
        # Layout
        if len(self.COM_COMMENT_ls) == 0:
            label = tk.Label(self.root, text = 'This product does not have any comments yet.'
                             ,font = self.Titletext).place(x = 180, y = 390)
        elif len(self.COM_COMMENT_ls) >= 1:
            tk.Label(self.root, text = 'Comment 1', font = self.Titletext).place(x = 70, y = 130)
            tk.Label(self.root, text = self.COM_COMMENT_ls[0] , font = self.comtext).place(x = 70, y = 160)
            if len(self.COM_COMMENT_ls) >= 2:
                tk.Label(self.root, text = 'Comment 2',font = self.Titletext).place(x = 70, y = 210)
                tk.Label(self.root, text = self.COM_COMMENT_ls[1], font = self.comtext).place(x = 70, y = 240)
                if len(self.COM_COMMENT_ls) >= 3:
                    tk.Label(self.root, text = 'Comment 3', font = self.Titletext).place(x = 70, y = 290)
                    tk.Label(self.root, text = self.COM_COMMENT_ls[2], font = self.comtext).place(x = 70, y = 320)
                    if len(self.COM_COMMENT_ls) >= 4:
                        tk.Label(self.root, text = 'Comment 4', font = self.Titletext).place(x = 70, y = 370)
                        tk.Label(self.root, text = self.COM_COMMENT_ls[3], font = self.comtext).place(x = 70, y = 400)
                        if len(self.COM_COMMENT_ls) >= 5:
                            tk.Label(self.root, text = 'Comment 5', font = self.Titletext).place(x = 70, y = 450)
                            tk.Label(self.root, text = self.COM_COMMENT_ls[4], font = self.comtext).place(x = 70, y = 480)
                            if len(self.COM_COMMENT_ls) >= 6:
                                tk.Label(self.root, text = 'Comment 6', font = self.Titletext).place(x = 70, y = 530)
                                tk.Label(self.root, text = self.COM_COMMENT_ls[5],font = self.comtext).place(x = 70, y = 560)
                                if len(self.COM_COMMENT_ls) >= 7:
                                    tk.Label(self.root, text = 'Comment 7',font = self.Titletext).place(x = 70, y = 610)
                                    tk.Label(self.root, text = self.COM_COMMENT_ls[6],font = self.comtext).place(x = 70, y = 640)
        
        
        # Buttons
        if self.remaining_row > 0:
            tk.Button(self.root, text = 'Next page', font = "bold", fg = 'orange', command = self.next_page, width = 18).place(x = 580, y = 710)
        if self.first_row_com != 0:
            tk.Button(self.root, text = 'Previous page', font = "bold", fg = 'orange', command = self.previous_page, width = 18).place(x = 130, y = 710)
        tk.Button(self.root,text = 'Back to Product Details', command = self.back, font = "bold", fg = 'orange', width = 18).place(x = 350, y = 740)
        self.root.mainloop()
    
    def pre_set(self):
        # SQL code to retrieve corresponding comments and average rating
        connect = connection()
        
        # Retreive the total amount of Result
        connect.c.execute(
            """
                SELECT COUNT(*)
                FROM COMMENTS
                WHERE PRODUCT_PRO_ID = '{}' AND COM_AVA != 0
            """.format(self.PRO_ID))
            
        for row in connect.c:
            self.total_row = row[0]
            self.remaining_row = row[0] - self.first_row_com - 7
        
        # Retreive detail of comment
        connect.c.execute(
            """
                SELECT COM_COMMENT
                FROM COMMENTS
                WHERE PRODUCT_PRO_ID = '{}' AND COM_AVA = 1 AND COM_COMMENT IS NOT NULL
                ORDER BY ROWNUM, COM_DATE DESC
                OFFSET {} ROWS FETCH NEXT 7 ROWS ONLY
            """.format(self.PRO_ID, self.first_row_com))
        
        for row in connect.c:
            self.COM_COMMENT_ls.append(row[0])

        connect.c.close()
        
    def back(self):
        self.root.destroy()
        View_Details_Class(self.MEM_ID, self.PRO_ID, self.key_word, self.method, self.first_row_pro)
    
    def next_page(self):
        self.root.destroy()
        View_Comments_Class(self.MEM_ID, self.PRO_ID, self.key_word, self.method, self.first_row_pro, self.first_row_com + 7)
            
    def previous_page(self):
        self.root.destroy()
        View_Comments_Class(self.MEM_ID, self.PRO_ID, self.key_word, self.method, self.first_row_pro, self.first_row_com - 7)

# %%
class Insert_SPCT_Information_Class:
    def __init__(self, MEM_ID, PRO_ID, KW, method, first_row):
        # TODO -> Get the value and retrieve relative information
        self.root = tk.Tk()
        self.root.geometry('700x300')
        self.root.title("Insert Details")
        self.MEM_ID = MEM_ID; self.PRO_ID = PRO_ID; self.first_row = first_row
        self.key_word = KW; self.method = method;self.errorMessage=tk.StringVar();self.errorMessage.set('')

        # create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 17, weight = "bold")
        self.resulttext = tkFont.Font(family = "Courier", size = 15, weight = "normal")
        self.warningtext = tkFont.Font(family = "Courier", size = 30, weight = "normal")
        
        # declare variable
        self.Amount = tk.StringVar(); self.Amount.set(0)
        
        # error message label
        tk.Label(self.root,textvariable=self.errorMessage,font=self.bodytext,fg='red').place(x=50,y=100)
        
        tk.Label(self.root, text = "Please enter the amount you want to insert:", font = self.bodytext).place(x = 80, y = 60)
        tk.Entry(self.root, textvariable = self.Amount, width = 30).place(x = 160, y = 130)
        
        self.but_insert = tk.Button(self.root, text = 'insert', font = "bold", fg = 'orange', command = self.insert, width = 18)
        self.but_insert.place(x = 220, y = 185)
        tk.Button(self.root, text = 'back', font = "bold", fg = 'orange', command = self.back, width = 18).place(x = 220, y = 220)
        
        self.root.mainloop()
        
    def back(self):
        self.root.destroy()
        Search_Result_Class(self.MEM_ID, self.key_word, self.method, self.first_row)
    
    def insert(self):
        try:
            self.Amount_info = int(self.Amount.get())
        except: 
            self.errorMessage.set('Please enter an integer for amount.')
            return
        if Numeric_len_check(self.Amount_info, 5) != True:
            self.errorMessage.set('Insert amount cannot be more than or equal to 1 Million.')
            return
        elif self.Amount_info <= 0: 
            self.errorMessage.set('Insert amount cannot be less than or equal 0.')
            return
        # Insert Data into Database
        connect = connection()
        
        today = datetime.datetime.today()
        # Retrieve value from Shopping Cart
        connect.c.execute(
            """
              SELECT SPCT_ID 
              FROM SHOPPING_CART
            """)

        ls_ID = []
        for row in connect.c:
            ls_ID.append(int(row[0]))
        for i in range(len(ls_ID) + 1):
            if i not in ls_ID:
                SPCT_ID = i
                break
                
        connect.c.execute(
            """
                INSERT INTO SHOPPING_CART
                VALUES ('{}', TO_DATE('{}-{}-{}', 'DD-MM-YYYY'), {}, '{}', '{}')
            """.format(str(SPCT_ID), today.day, today.month, today.year, self.Amount_info, self.MEM_ID, self.PRO_ID))
        
        
        connect.c.execute("commit")      
        connect.c.close()
        
        tk.Label(self.root, text = "Congratulations!!! The record has successfully insert!",\
                 font = self.resulttext, fg = 'red').place(x = 50, y = 270)
        
        self.but_insert.destroy()

# %% [markdown]
# #### Order Detail History Page (Finished)

# %%
# assume each page shows 7 items
class All_History:
    
    def __init__(self, MEM_ID, firstRow = 0, currentPage = 1):
        self.root = tk.Tk()
        self.root.geometry('1000x850')
        self.root.title('All History')
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Assign values to variables
        self.firstRow = firstRow
        self.MEM_ID = MEM_ID
        self.currentPage = currentPage
        
        # Create canvas
        canvas = tk.Canvas(self.root, width = 1000, height = 850)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(30, 120, 970, 150, fill = 'grey')
        
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Layout
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 330, y = 30)
        label_Introduction = tk.Label(self.root, text = "All Order History", width = 20, font = self.bodytext, fg = 'blue').place(x = 400, y = 70)
        
        label_ORD_ID = tk.Label(self.root, text='Order ID',font=self.bodytext,bg='grey').place(x=85,y=124)
        label_ORD_ID = tk.Label(self.root, text='Order Date',font=self.bodytext,bg='grey').place(x=275,y=124)
        label_ORD_ID = tk.Label(self.root, text='Order Status',font=self.bodytext,bg='grey').place(x=445,y=124)
        label_ORD_ID = tk.Label(self.root, text='Transaction Price',font=self.bodytext,bg='grey').place(x=615,y=124)
        
        # Assign ORD_ID, ORD_DATE, ORD_STATUS, ODL_TRAN_PRICE to list
        self.lsOrderID = []
        self.lsOrderDate = []
        self.lsOrderStatus = []
        self.lsOrderTranPrice = []
        
        # SQL to retrieve all order information
        connect = connection()
        connect.c.execute(
            """
              SELECT ORD_ID, TO_CHAR(ORD_DATE,'dd/mm/yyyy'), ORD_STATUS
              FROM "ORDER", MEMBER
              WHERE MEMBER.MEM_ID = "ORDER".MEMBER_MEM_ID
              AND MEMBER.MEM_ID = {}
              ORDER BY ORD_DATE DESC
              OFFSET {} ROWS FETCH NEXT 7 ROWS ONLY
            """.format(self.MEM_ID,self.firstRow))
        
        # Assign values to list
        for row in connect.c:
            self.lsOrderID.append(row[0])
            self.lsOrderDate.append(row[1])
            self.lsOrderStatus.append(row[2])
        
        # SQL to retreive number of rows
        connect.c.execute(
            """
              SELECT COUNT(*)
              FROM "ORDER", MEMBER
              WHERE MEMBER.MEM_ID = "ORDER".MEMBER_MEM_ID
              AND MEMBER.MEM_ID = {}
            """.format(self.MEM_ID))
        
        for row in connect.c:
            self.totalRow = row[0]   
        
        self.remainingRow = int(self.totalRow) - int(self.firstRow) - 7
        if self.firstRow == 0:
            self.currentPage = 1
        else: self.currentPage = math.ceil(self.totalRow / 7)
                
        # retrieve total transaction price and save in list
        self.lsOrderTranPrice = []
        for i in range(len(self.lsOrderID)):
            connect.c.execute(
            """
                SELECT SUM(ODL_QUANTITY*ODL_TRAN_PRICE) TOTAL_TRANSACTION_PRICE
                FROM ORDER_LINE, "ORDER"
                WHERE "ORDER".ORD_ID = ORDER_LINE.ORDER_ORD_ID
                AND "ORDER".ORD_ID = {}
            """.format(self.lsOrderID[i]))
            for row in connect.c:
                self.lsOrderTranPrice.append(row[0])

        # Display results
        if len(self.lsOrderID) == 0:
            label = tk.Label(self.root, text = 'You do not have any order history yet. Go make your first purchase!',font=self.bodytext).place(x=130,y=200)
        
        if len(self.lsOrderID) > 0:
            tk.Label(self.root, text=self.lsOrderID[0]).place(x=100,y=170)
            tk.Label(self.root, text=self.lsOrderDate[0]).place(x=280,y=170)
            tk.Label(self.root, text=self.lsOrderStatus[0]).place(x=460,y=170)
            tk.Label(self.root, text='$'+str(self.lsOrderTranPrice[0])).place(x=660,y=170)
            tk.Button(self.root, text='View Order Details', width = 15, fg = 'red',command=self.viewDetails_1).place(x=800,y=170)
            self.orderID = self.lsOrderID[0]
            
            if len(self.lsOrderID) > 1:
                tk.Label(self.root, text=self.lsOrderID[1]).place(x=100,y=240)
                tk.Label(self.root, text=self.lsOrderDate[1]).place(x=280,y=240)
                tk.Label(self.root, text=self.lsOrderStatus[1]).place(x=460,y=240)
                tk.Label(self.root, text='$'+str(self.lsOrderTranPrice[1])).place(x=660,y=240)
                self.orderID = self.lsOrderID[1]
                tk.Button(self.root, text='View Order Details', width = 15, fg = 'red',command=self.viewDetails_2).place(x=800,y=240)
                
                if len(self.lsOrderID) > 2:
                    orderID1 = tk.Label(self.root, text=self.lsOrderID[2]).place(x=100,y=310)
                    orderDate1 = tk.Label(self.root, text=self.lsOrderDate[2]).place(x=280,y=310)
                    orderStatus1 = tk.Label(self.root, text=self.lsOrderStatus[2]).place(x=460,y=310)
                    orderTranPrice1 = tk.Label(self.root, text='$'+str(self.lsOrderTranPrice[2])).place(x=660,y=310)
                    self.orderID = self.lsOrderID[2]
                    viewDetails = tk.Button(self.root, text='View Order Details', width = 15, fg = 'red',command=self.viewDetails_3).place(x=800,y=310)
                    
                    if len(self.lsOrderID) > 3:
                        orderID1 = tk.Label(self.root, text=self.lsOrderID[3]).place(x=100,y=380)
                        orderDate1 = tk.Label(self.root, text=self.lsOrderDate[3]).place(x=280,y=380)
                        orderStatus1 = tk.Label(self.root, text=self.lsOrderStatus[3]).place(x=460,y=380)
                        orderTranPrice1 = tk.Label(self.root, text='$'+str(self.lsOrderTranPrice[3])).place(x=660,y=380)
                        self.orderID = self.lsOrderID[3]
                        viewDetails = tk.Button(self.root, text='View Order Details', width = 15, fg = 'red',command=self.viewDetails_4).place(x=800,y=380)
                        
                        if len(self.lsOrderID) > 4:
                            orderID1 = tk.Label(self.root, text=self.lsOrderID[4]).place(x=100,y=450)
                            orderDate1 = tk.Label(self.root, text=self.lsOrderDate[4]).place(x=280,y=450)
                            orderStatus1 = tk.Label(self.root, text=self.lsOrderStatus[4]).place(x=460,y=450)
                            orderTranPrice1 = tk.Label(self.root, text='$'+str(self.lsOrderTranPrice[4])).place(x=660,y=450)
                            self.orderID = self.lsOrderID[4]
                            viewDetails = tk.Button(self.root, text='View Order Details', width = 15, fg = 'red',command=self.viewDetails_5).place(x=800,y=450)
                            
                            if len(self.lsOrderID) > 5:
                                orderID1 = tk.Label(self.root, text=self.lsOrderID[5]).place(x=100,y=520)
                                orderDate1 = tk.Label(self.root, text=self.lsOrderDate[5]).place(x=280,y=520)
                                orderStatus1 = tk.Label(self.root, text=self.lsOrderStatus[5]).place(x=460,y=520)
                                orderTranPrice1 = tk.Label(self.root, text='$'+str(self.lsOrderTranPrice[5])).place(x=660,y=520)
                                self.orderID = self.lsOrderID[5]
                                viewDetails = tk.Button(self.root, text='View Order Details', width = 15, fg = 'red',command=self.viewDetails_6).place(x=800,y=520)
                                
                                if len(self.lsOrderID) > 6:
                                    orderID1 = tk.Label(self.root, text=self.lsOrderID[6]).place(x=100,y=590)
                                    orderDate1 = tk.Label(self.root, text=self.lsOrderDate[6]).place(x=280,y=590)
                                    orderStatus1 = tk.Label(self.root, text=self.lsOrderStatus[6]).place(x=460,y=590)
                                    orderTranPrice1 = tk.Label(self.root, text='$'+str(self.lsOrderTranPrice[6])).place(x=660,y=590)
                                    self.orderID = self.lsOrderID[6]
                                    viewDetails = tk.Button(self.root, text='View Order Details', width = 15, fg = 'red',command=self.viewDetails_7).place(x=800,y=590)
                            
       # Button
        if self.remainingRow > 0:
            tk.Button(self.root, text = 'Next page', font = "bold", fg = 'orange', command = self.nextPage, width = 18).place(x = 700, y = 680)
        if self.firstRow != 0:
            tk.Button(self.root, text = 'Previous page', font = "bold", fg = 'orange', command = self.previousPage, width = 18).place(x = 200, y = 680)
        tk.Button(self.root, text = 'Back to Main Page', font = "bold", fg = 'orange', command = self.back, width = 18).place(x = 450, y = 740)
        
        
        self.root.mainloop()
        
    def viewDetails_1(self):
        self.root.destroy()
        Order_Detail_History_Class(self.MEM_ID,self.lsOrderID[0],self.firstRow,self.currentPage)
        
    def viewDetails_2(self):
        self.root.destroy()
        Order_Detail_History_Class(self.MEM_ID,self.lsOrderID[1],self.firstRow,self.currentPage)
        
    def viewDetails_3(self):
        self.root.destroy()
        Order_Detail_History_Class(self.MEM_ID,self.lsOrderID[2],self.firstRow,self.currentPage)
        
    def viewDetails_4(self):
        self.root.destroy()
        Order_Detail_History_Class(self.MEM_ID,self.lsOrderID[3],self.firstRow,self.currentPage)
        
    def viewDetails_5(self):
        self.root.destroy()
        Order_Detail_History_Class(self.MEM_ID,self.lsOrderID[4],self.firstRow,self.currentPage)
        
    def viewDetails_6(self):
        self.root.destroy()
        Order_Detail_History_Class(self.MEM_ID,self.lsOrderID[5],self.firstRow,self.currentPage)
    
    def viewDetails_7(self):
        self.root.destroy()
        Order_Detail_History_Class(self.MEM_ID,self.lsOrderID[6],self.firstRow,self.currentPage)
    
    def nextPage(self):
        self.root.destroy()
        All_History(self.MEM_ID,self.firstRow + 7,self.currentPage+1)
    
    def previousPage(self):
        self.root.destroy()
        All_History(self.MEM_ID,self.firstRow - 7,self.currentPage-1)
    
    def back(self):
        self.root.destroy()
        Main_Page_Class(self.MEM_ID)

# %%
# assume each page shows 7 items
class Order_Detail_History_Class:
    
    def __init__(self, MEM_ID,orderID,AllFirstRow,AllCurrentPage,firstRow=0,currentPage=1):
        self.root = tk.Tk()
        self.root.geometry('850x850')
        self.root.title("Previous Order Page")
        self.MEM_ID = MEM_ID
        self.orderID = orderID
        self.AllFirstRow = AllFirstRow
        self.firstRow = firstRow
        self.AllCurrentPage = AllCurrentPage
        self.currentPage = currentPage
        self.add1 =tk.IntVar();self.add2 =tk.IntVar();self.add3 =tk.IntVar();self.add4 =tk.IntVar();
        self.add5 =tk.IntVar();self.add6 =tk.IntVar();self.add7 =tk.IntVar();
        self.Add = tk.IntVar()
        self.errorMessage = tk.StringVar();
        self.errorMessage.set("")

        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "normal")
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 800)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 106, 800, 760, fill = 'white')
        rectangle = canvas.create_rectangle(50, 106, 800, 145, fill = 'lightblue')
        rectangle = canvas.create_rectangle(50, 226, 800, 200, fill = 'grey')
        
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Company Name
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)
        
        # Error Message
        noProChosen = tk.Label(self.root, textvariable=self.errorMessage, fg='red', font=self.bodytext)
        noProChosen.place(x=250,y=720)
        
        # Layout 
        tk.Label(self.root, text = 'Order History', font = self.Titletext, bg = 'lightblue').place(x = 90, y = 115)
        tk.Label(self.root, text = 'Order ID:',font = self.bodytext).place(x=90,y=160)
        tk.Label(self.root, text = self.orderID,font=self.bodytext).place(x=190,y=160)
        
        # SQL to retrieve number of order item
        connect = connection()
        connect.c.execute(
            """
              SELECT COUNT({})
              FROM ORDER_LINE,PRODUCT, "ORDER", MEMBER
              WHERE ORDER_LINE.PRODUCT_PRO_ID = PRODUCT.PRO_ID
              AND "ORDER".MEMBER_MEM_ID = MEMBER.MEM_ID
              AND MEM_ID = {}
              AND "ORDER".ORD_ID = ORDER_LINE.ORDER_ORD_ID
              AND "ORDER".ORD_ID = {}
            """.format(self.orderID,self.MEM_ID,self.orderID))
        
        for row in connect.c:
            self.totalRow = row[0]
        
        # Assign number of items to variable
        self.remainingRow = row[0] - self.firstRow - 7
        
        # Assign PRO_NAME, ODL_TRAN_PRICE, ODL_QUANTITY, SUBTOTAL to list
        self.lsProName = []
        self.lsTranPrice = []
        self.lsQuantity = []
        self.lsSubtotal = []
        self.lsProID = []
        
        # SQL to retreive all order item, unit price, quantity and subtotal
        connect.c.execute(
            """
              SELECT PRO_ID, PRO_NAME, ODL_TRAN_PRICE, ODL_QUANTITY, (ODL_TRAN_PRICE*ODL_QUANTITY) AS SUBTOTAL
              FROM ORDER_LINE,PRODUCT, "ORDER"
              WHERE ORDER_LINE.PRODUCT_PRO_ID = PRODUCT.PRO_ID
              AND "ORDER".ORD_ID = ORDER_LINE.ORDER_ORD_ID
              AND "ORDER".ORD_ID = {}
              ORDER BY ORD_DATE DESC
              OFFSET {} ROWS FETCH NEXT 7 ROWS ONLY
            """.format(self.orderID,self.firstRow))

        # Assign values to list
        for row in connect.c:
            self.lsProName.append(row[1])
            self.lsTranPrice.append(row[2])
            self.lsQuantity.append(row[3])
            self.lsSubtotal.append(row[4])  
            self.lsProID.append(row[0])
        
        tk.Label(self.root, text = 'Product Name', font = self.Titletext, bg = 'grey').place(x = 70, y = 201)
        tk.Label(self.root, text = 'Unit Price', font = self.Titletext, bg = 'grey').place(x = 350, y = 201)
        tk.Label(self.root, text = 'Quantity', font = self.Titletext, bg = 'grey').place(x = 530, y = 201)
        tk.Label(self.root, text = 'Subtotal', font = self.Titletext, bg = 'grey').place(x = 680, y = 201)
        
        # Display items on screen
        if len(self.lsProName) < 1:
            tk.Label(self.root, text = 'You do not have any order history yet!', fg = 'red', font=self.CNametext).place(x=150,y=450)
        
        elif len(self.lsProName) > 0:
            tk.Label(self.root,text='*To add comment, please check the a radio button near subtotal',fg='red', font = self.bodytext).place(x=150,y=690)
            tk.Label(self.root, text=self.lsProName[0],font=self.bodytext).place(x=90,y=250)
            tk.Label(self.root, text='$'+str(self.lsTranPrice[0]),font=self.bodytext).place(x=370,y=250)
            tk.Label(self.root, text=self.lsQuantity[0],font=self.bodytext).place(x=550,y=250)
            tk.Label(self.root, text='$'+str(self.lsSubtotal[0]),font=self.bodytext).place(x=670,y=250)
            tk.Radiobutton(self.root,variable=self.Add,value = 1).place(x=770,y=250)
            
            if len(self.lsProName) > 1: 
                tk.Label(self.root, text=self.lsProName[1],font=self.bodytext).place(x=90,y=320)
                tk.Label(self.root, text='$'+str(self.lsTranPrice[1]),font=self.bodytext).place(x=370,y=320)
                tk.Label(self.root, text=self.lsQuantity[1],font=self.bodytext).place(x=550,y=320)
                tk.Label(self.root, text='$'+str(self.lsSubtotal[1]),font=self.bodytext).place(x=670,y=320)
                tk.Radiobutton(self.root,variable=self.Add,value = 2).place(x=770,y=320)
                
                if len(self.lsProName) > 2:
                    tk.Label(self.root, text=self.lsProName[2],font=self.bodytext).place(x=90,y=390)
                    tk.Label(self.root, text='$'+str(self.lsTranPrice[2]),font=self.bodytext).place(x=370,y=390)
                    tk.Label(self.root, text=self.lsQuantity[2],font=self.bodytext).place(x=550,y=390)
                    tk.Label(self.root, text='$'+str(self.lsSubtotal[2]),font=self.bodytext).place(x=670,y=390)
                    tk.Radiobutton(self.root,variable=self.Add,value = 3).place(x=770,y=390)
                    
                    if len(self.lsProName) > 3:
                        tk.Label(self.root, text=self.lsProName[3],font=self.bodytext).place(x=90,y=460)
                        tk.Label(self.root, text='$'+str(self.lsTranPrice[3]),font=self.bodytext).place(x=370,y=460)
                        tk.Label(self.root, text=self.lsQuantity[3],font=self.bodytext).place(x=550,y=460)
                        tk.Label(self.root, text='$'+str(self.lsSubtotal[3]),font=self.bodytext).place(x=670,y=460)
                        tk.Radiobutton(self.root,variable=self.Add,value = 4).place(x=770,y=460)
                        
                        if len(self.lsProName) > 4:
                            tk.Label(self.root, text=self.lsProName[4],font=self.bodytext).place(x=90,y=530)
                            tk.Label(self.root, text='$'+str(self.lsTranPrice[4]),font=self.bodytext).place(x=370,y=530)
                            tk.Label(self.root, text=self.lsQuantity[4],font=self.bodytext).place(x=550,y=530)
                            tk.Label(self.root, text='$'+str(self.lsSubtotal[4]),font=self.bodytext).place(x=670,y=530)
                            tk.Radiobutton(self.root,variable=self.Add,value = 5).place(x=770,y=530)
                            
                            if len(self.lsProName) > 5:
                                tk.Label(self.root, text=self.lsProName[5],font=self.bodytext).place(x=90,y=600)
                                tk.Label(self.root, text='$'+str(self.lsTranPrice[5]),font=self.bodytext).place(x=370,y=600)
                                tk.Label(self.root, text=self.lsQuantity[5],font=self.bodytext).place(x=550,y=600)
                                tk.Label(self.root, text='$'+str(self.lsSubtotal[5]),font=self.bodytext).place(x=670,y=600)
                                tk.Radiobutton(self.root,variable=self.Add,value = 6).place(x=770,y=600)
                                
                                if len(self.lsProName) > 6:
                                    tk.Label(self.root, text=self.lsProName[6],font=self.bodytext).place(x=90,y=670)
                                    tk.Label(self.root, text='$'+str(self.lsTranPrice[6]),font=self.bodytext).place(x=370,y=670)
                                    tk.Label(self.root, text=self.lsQuantity[6],font=self.bodytext).place(x=550,y=670)
                                    tk.Label(self.root, text='$'+str(self.lsSubtotal[6]),font=self.bodytext).place(x=670,y=670)
                                    tk.Radiobutton(self.root,variable=self.Add,value = 7).place(x=770,y=670)
        
        # Button
        if self.currentPage != 1:
            tk.Button(self.root, text='Previous', width = 15,command = self.previous, font = "bold", fg = 'orange').place(x = 200, y = 720)
        if self.remainingRow > 0:
            tk.Button(self.root, text='Next', width = 15,command = self.Next, font = "bold", fg = 'orange').place(x = 550, y = 720)
        if currentPage == 1:
            tk.Button(self.root, text = 'Back to Main Page', width = 15,command = self.back, font = "bold", fg = 'orange').place(x = 250, y = 770)
        if len(self.lsProName) > 0:
            tk.Button(self.root,text='Add Comments', width = 15,command = self.addComments, font = "bold", fg = 'orange').place(x=500,y=770)
        self.root.mainloop()  
    
    def previous(self):
        self.root.destroy()
        Order_Detail_History_Class(self.MEM_ID,self.orderID,self.AllFirstRow,self.AllCurrentPage,self.firstRow - 7,self.currentPage-1)
        
    def Next(self):
        self.root.destroy()
        Order_Detail_History_Class(self.MEM_ID,self.orderID,self.AllFirstRow,self.AllCurrentPage,self.firstRow + 7,self.currentPage+1)
        
    def addComments(self):
        
        if self.Add.get() == 1:
            self.root.destroy()
            Add_Comment_Class(self.MEM_ID,self.orderID,self.AllFirstRow,self.AllCurrentPage,self.firstRow,self.currentPage,self.lsProName[0],self.lsProID[0])
        if self.Add.get() == 2:
            self.root.destroy()
            Add_Comment_Class(self.MEM_ID,self.orderID,self.AllFirstRow,self.AllCurrentPage,self.firstRow,self.currentPage,self.lsProName[1],self.lsProID[1])
        if self.Add.get() == 3:
            self.root.destroy()
            Add_Comment_Class(self.MEM_ID,self.orderID,self.AllFirstRow,self.AllCurrentPage,self.firstRow,self.currentPage,self.lsProName[2],self.lsProID[2])
        if self.Add.get() == 4:
            self.root.destroy()
            Add_Comment_Class(self.MEM_ID,self.orderID,self.AllFirstRow,self.AllCurrentPage,self.firstRow,self.currentPage,self.lsProName[3],self.lsProID[3])
        if self.Add.get() == 5:
            self.root.destroy()
            Add_Comment_Class(self.MEM_ID,self.orderID,self.AllFirstRow,self.AllCurrentPage,self.firstRow,self.currentPage,self.lsProName[4],self.lsProID[4])
        if self.Add.get() == 6:
            self.root.destroy()
            Add_Comment_Class(self.MEM_ID,self.orderID,self.AllFirstRow,self.AllCurrentPage,self.firstRow,self.currentPage,self.lsProName[5],self.lsProID[5])
        if self.Add.get() == 7:
            self.root.destroy()
            Add_Comment_Class(self.MEM_ID,self.orderID,self.AllFirstRow,self.AllCurrentPage,self.firstRow,self.currentPage,self.lsProName[6],self.lsProID[6])
        else:
            self.errorMessage.set("You didn't choose any product to comment.")
            return

    def back(self):
        self.root.destroy()
        All_History(self.MEM_ID,self.AllFirstRow,self.AllCurrentPage)

# %%
# Add comment page
class Add_Comment_Class:
    
    def __init__(self, MEM_ID, orderID, AllFirstRow, AllCurrentPage,DetailFirstRow,DetailCurrentPage, proName, proID): 
        self.root = tk.Tk()
        self.root.geometry('850x500')
        self.root.title("Add Comment Page")

        # Declare Variables
        self.ProName = tk.StringVar()
        self.Comment = tk.StringVar()
        self.rating = tk.StringVar()
        self.Name = tk.StringVar()
        self.resultMessage = tk.StringVar()
        self.resultMessage.set("")

        self.MEM_ID = MEM_ID;self.orderID = orderID
        self.AllFirstRow = AllFirstRow
        self.AllCurrentPage = AllCurrentPage
        self.DetailCurrentPage = DetailCurrentPage
        self.DetailFirstRow = DetailFirstRow
        self.proName = proName;self.proID = proID;self.MEM_ID = MEM_ID
        self.Name.set(self.proName)
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 450)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 106, 800, 420, fill = 'white')
        
        # result/error message
        self.lbl_resultMessage = tk.Label(self.root,textvariable=self.resultMessage,fg='red',font=self.bodytext)

        
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)

        # Company Name
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)
        label_Introduction = tk.Label(self.root, text = "Add Comment", width = 20, font = self.bodytext, fg = 'blue').place(x = 350, y = 70)
        
        # Product 
        label_product = tk.Label(self.root, text = 'Product:', font = self.bodytext).place(x = 190, y = 150)
        label_product = tk.Label(self.root, textvariable = self.Name, width = 30)
        label_product.place(x = 390, y = 150)
                
        # Rating
        label_comment = tk.Label(self.root, text = 'Rating (5 is highest) :', font = self.bodytext).place(x = 190, y = 200)
        drop_rating = tk.OptionMenu(self.root, self.rating, "5","4","3","2","1").place(x = 390, y = 200)
        self.rating.set("5")
        
        # Comment
        label_comment = tk.Label(self.root, text = 'Comment:', font = self.bodytext).place(x = 190, y = 250)
        entry_brand = tk.Entry(self.root, textvariable = self.Comment, width = 30).place(x = 390, y = 250)

        # Buttons
        But_back = tk.Button(self.root, text = 'Submit', width = 25, command = self.Submit, font = "bold", fg = 'orange').place(x = 160, y = 350)
        But_back = tk.Button(self.root, text = 'Back', width = 25, command = self.back, font = "bold", fg = 'orange').place(x = 450, y = 350)
        
        self.root.mainloop()
    
    def Submit(self):
        self.ComID = ''
        if len(self.Comment.get()) > 60:
            self.resultMessage.set('Your comment should not exceed 60 characters.')
            self.lbl_resultMessage.place(x = 240,y = 300)
            return
        
        #
        self.lsComID = []
        connect = connection()
        connect.c.execute("SELECT COM_ID FROM COMMENTS ORDER BY COM_ID DESC")
        for row in connect.c:
            self.lsComID.append(int(row[0]))
        for i in range(len(self.lsComID)):
            self.ComID = str(i+1)
            
        connect.c.execute("SELECT TO_CHAR(Sysdate) FROM Dual")
        
        
        for row in connect.c:
            self.sysdate = row[0]
        if len(self.Comment.get()) == 0:
            self.resultMessage.set('No comment has been input')
            self.lbl_resultMessage.place(x = 300,y = 300)
            return
        else: 
            self.AVA='1'
            # try to retrieve comment made by particular member for particular product
            connect.c.execute("""SELECT COUNT(COM_COMMENT) FROM COMMENTS 
                                     WHERE PRODUCT_PRO_ID = '{}'
                                     AND MEMBER_MEM_ID = '{}'"""
                                     .format(self.proID,self.MEM_ID))
            for row in connect.c:
                self.exitcom = row[0]
            self.resultMessage.set('Comment has been made')
            self.lbl_resultMessage.place(x = 310,y = 300)
            self.COM = self.Comment.get()

            if self.exitcom != 0:
                connect.c.execute("""UPDATE COMMENTS SET COM_COMMENT = '{}', COM_RATING = '{}',COM_DATE = '{}'
                                     WHERE PRODUCT_PRO_ID = '{}'
                                     AND MEMBER_MEM_ID = '{}'"""
                                    .format(self.Comment.get(),self.rating.get(),self.sysdate,self.proID,self.MEM_ID))
                connect.c.execute("commit")
                self.Comment.set("")
            else:
                connect.c.execute(
                    """
                        INSERT INTO COMMENTS VALUES ('{}','{}','{}','{}','{}','{}','{}')
                    """.format(self.ComID,self.rating.get(),self.AVA,self.Comment.get(),self.sysdate,self.proID,self.MEM_ID))
                    
                connect.c.execute("commit")
                self.resultMessage.set('Comment has been made')
                self.Comment.set("")

    def back(self):
        self.root.destroy()
        Order_Detail_History_Class(self.MEM_ID,self.orderID,self.AllFirstRow,self.AllCurrentPage,self.DetailFirstRow,self.DetailCurrentPage)

# %% [markdown]
# #### Personal Information Page (Finished)

# %%
class Edit_Personal_Information_Class:
    
    def __init__(self, MEM_ID):
        self.root = tk.Tk()
        self.root.geometry('1250x650')
        self.root.title('Account Information Page')
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 1200, height = 650)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 106, 1200, 600, fill = 'white')

        # Declare Variables
        self.MEM_ID = MEM_ID
        self.getFName = tk.StringVar()
        self.FName = tk.StringVar()
        self.getMName = tk.StringVar()
        self.MName = tk.StringVar()
        self.getLName = tk.StringVar()
        self.LName = tk.StringVar()
        self.getUserName = tk.StringVar()
        self.UserName = tk.StringVar()
        self.getPWD = tk.StringVar()
        self.PWD = tk.StringVar()
        self.Confirmed_PWD = tk.StringVar()
        self.getGENDER = tk.StringVar()
        self.gender = tk.StringVar()
        self.GENDER = tk.StringVar()
        self.getEMAIL = tk.StringVar()
        self.EMAIL = tk.StringVar()
        self.getMOBILE = tk.StringVar()
        self.MOBILE = tk.StringVar()
        self.ADD_Line_1 = tk.StringVar()
        self.getADD_LINE1 = tk.StringVar()
        self.ADD_Line_2 = tk.StringVar()
        self.getADD_LINE2 = tk.StringVar()
        self.getADD_Country = tk.StringVar()
        self.ADD_Country = tk.StringVar()
        self.retrieve_information()
        self.ErrorMessage = tk.StringVar();self.ErrorMessage.set("")
        
        # Company Name
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 460, y = 40)
        label_Introduction = tk.Label(self.root, text = "Edit Personal Information", font = self.bodytext, fg = 'blue').place(x = 500, y = 75)
            
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)

        # Title
        label_forget = tk.Label(self.root, text = "Account Information",width = 20, font = self.Titletext).place(x = 490, y = 110)
        
        # First Name
        label_FName = tk.Label(self.root, text = "First Name*").place(x = 105, y = 152)
        entry_FName = tk.Entry(self.root, textvariable = self.FName,width = 15).place(x = 185, y = 150)
        self.FName.set(self.getFName)
 
        # Middle Name
        label_MName = tk.Label(self.root, text = "Middle Name").place(x = 390, y = 152)
        entry_MName = tk.Entry(self.root, textvariable = self.MName,width = 15).place(x = 485, y = 150)
        if self.getMName == None:
            self.MName.set('')
        else: self.MName.set(self.getMName)
        
        # Last Name
        label_LName = tk.Label(self.root, text = "Last Name*").place(x = 685, y = 152)
        entry_LName = tk.Entry(self.root, textvariable = self.LName,width = 15).place(x = 765, y = 150)
        self.LName.set(self.getLName)

        # UserName
        label_UserName = tk.Label(self.root, text = "Username*").place(x = 105, y = 222)
        entry_UserName = tk.Entry(self.root, textvariable = self.UserName,width = 35).place(x = 185, y = 220)
        self.UserName.set(self.getUserName)

        # Gender
        label_GENDER = tk.Label(self.root, text='Gender').place(x=540,y=220)
        gender = ['Male', 'Female']
        if self.getGENDER == 1:
            gender = tk.OptionMenu(self.root, self.GENDER, *gender)
            self.GENDER.set('Female')
            gender.config(width = 15)
            gender.place(x = 600, y = 220)
        else:
            gender = tk.OptionMenu(self.root, self.GENDER, *gender)
            self.GENDER.set('Male')
            gender.config(width = 15)
            gender.place(x = 600, y = 220)
        
        # Password
        label_PWD = tk.Label(self.root, text = "Password*").place(x = 105, y = 290)
        entry_PWD = tk.Entry(self.root, textvariable = self.PWD,width = 25)
        entry_PWD.place(x = 185, y = 292)
        self.PWD.set(self.getPWD)

        # Confirmed Password
        label_Confirmed_PWD = tk.Label(self.root, text = "Confirmed Password*").place(x = 525, y = 292)
        entry_Confirmed_PWD = tk.Entry(self.root, textvariable = self.Confirmed_PWD,width = 25).place(x = 675, y = 290)
        self.Confirmed_PWD.set(self.getPWD)
        
        # Email
        label_EMAIL = tk.Label(self.root, text = "Email*").place(x = 105, y = 362)
        entry_EMAIL = tk.Entry(self.root, textvariable = self.EMAIL,width = 25).place(x = 185, y = 360)
        self.EMAIL.set(self.getEMAIL)


        # Mobile
        label_MOBILE = tk.Label(self.root, text = "Mobile*").place(x = 610, y = 362)
        entry_MOBILE = tk.Entry(self.root, textvariable = self.MOBILE,width = 25).place(x = 675, y = 360)
        self.MOBILE.set(self.getMOBILE)

        # Address Line 1
        label_ADD_Line_1 = tk.Label(self.root, text="Address (Line 1)*").place(x = 105, y = 432)
        entry_ADD_Line_1 = tk.Entry(self.root, textvariable = self.ADD_Line_1,width = 25).place(x = 230, y = 430)
        self.ADD_Line_1.set(self.getADD_LINE1)

        
        # Address Line 2
        label_ADD_Line_2 = tk.Label(self.root, text="Address (Line 2)*").place(x = 555, y = 432)
        entry_ADD_Line_2 = tk.Entry(self.root, textvariable = self.ADD_Line_2,width = 25).place(x = 675, y = 430)
        self.ADD_Line_2.set(self.getADD_LINE2)

        # Country 
        countries_details = countries
        country = []
        for i in countries_details:
            country.append(i['name'])
            
        label_ADD_Country = tk.Label(self.root, text='Country').place(x = 105, y = 502)
        country = tk.OptionMenu(self.root, self.ADD_Country, *country)
        self.ADD_Country.set(self.getADD_Country)
        country.config(width = 35)
        country.place(x = 200, y = 500)
        
        # ErrorMessageEmpty
        errorMessage = tk.Label(self.root, textvariable=self.ErrorMessage,font= self.bodytext, fg = 'red').place(x=620,y=500)
        
        # Buttons
        But_submit = tk.Button(self.root, text = "Back to Main Page", font = "bold", fg = 'orange', width = 20,
                                command = self.cancel).place(x = 360, y = 560)
        But_login = tk.Button(self.root, text = "Update", font = "bold", fg = 'orange', width = 20,
                                command = self.update).place(x = 650, y = 560)
        
        self.root.mainloop()
        
    
    def retrieve_information(self):
        connect = connection()
        connect.c.execute(
            """
                SELECT * FROM MEMBER WHERE MEM_ID = '{}'
            """.format(self.MEM_ID))
        for row in connect.c:
            self.getFName = row[1]
            self.getMName = row[2]
            self.getLName = row[3]
            self.getEMAIL = row[4]
            self.getUserName = row[5]
            self.getPWD = row[6]
            self.getMOBILE = row[7]
            self.getADD_LINE1 = row[8]
            self.getADD_LINE2 = row[9]
            self.getADD_Country = row[10]
            self.getGENDER = row[11]
            
        connect.c.close()
        
        return self.getFName,self.getMName,self.getLName,self.getEMAIL,self.getUserName,self.getPWD,self.getMOBILE,self.getADD_LINE1,self.getADD_LINE2,self.getADD_Country,self.getGENDER
    
    def cancel(self):
        self.root.destroy()
        Main_Page_Class(self.MEM_ID)
    
    def update(self):
        # Assign Variables
        self.FName_info = self.FName.get()
        self.MName_info = self.MName.get()
        self.LName_info = self.LName.get()
        self.UserName_info = self.UserName.get()
        self.PWD_info = self.PWD.get()
        self.Confirmed_PWD_info = self.Confirmed_PWD.get()
        # Convert textVariable to Male or Female
        if self.GENDER.get() == 'Female':
            self.GENDER_info = 1
        else: self.GENDER_info = 0
        self.EMAIL_info = self.EMAIL.get()
        self.MOBILE_info = self.MOBILE.get()
        self.ADD_Line_1_info = self.ADD_Line_1.get()
        self.ADD_Line_2_info = self.ADD_Line_2.get()
        self.ADD_Country_info = self.ADD_Country.get()
        self.idList = [];self.emailList=[]
          

        # check empty entry
        if (len(self.FName_info) == 0 or len(self.LName_info) == 0 or len(self.PWD_info) == 0 or self.EMAIL_info == 0 or len(self.MOBILE_info) == 0 or\
            len(self.ADD_Line_1_info) == 0 or len(self.ADD_Line_2_info) == 0):
            self.ErrorMessage.set('Entries with "*" should not be left blank.')
            return
        
        # Check invalid inputs
        if len(self.FName_info) > 30:
            self.ErrorMessage.set('Your first name cannot exceed 30 characters.')
            return
        if len(self.MName_info) > 30:
            self.ErrorMessage.set('Your middle name cannot exceed 30 characters.')
            return
        if len(self.LName_info) > 30:
            self.ErrorMessage.set('Your last name cannot exceed 30 characters.')
            return
        if len(self.UserName_info) >30:
            self.ErrorMessage.set('Your username cannot exceed 30 characters.')
            return
        if len(self.PWD_info) > 16: 
            self.ErrorMessage.set('Your password cannot exceed 16 characters.')
            return
        if self.PWD_info != self.Confirmed_PWD_info:
            self.ErrorMessage.set("Your password and confirmed password doesn't match.")
            return
        if ('@' not in self.EMAIL_info or self.EMAIL_info.count('@')>1):
            self.ErrorMessage.set("This is not a valid email.")
            return
        if len(self.EMAIL_info) > 30:
            self.ErrorMessage.set("Your email cannot exceed 30 characters.")
            return
        if len(self.MOBILE_info) > 15:
            self.ErrorMessage.set("Your mobile phone number cannot exceed 15 digits.")
            return
        if len(self.ADD_Line_1_info) > 100:
            self.ErrorMessage.set("Your first line of address cannot exceed 100 characters.")
            return
        if len(self.ADD_Line_2_info) > 50:
            self.ErrorMessage.set("Your second line of address cannot exceed 50 characters.")
            return
        
        
        # check if duplicate username
        # first store existing username in variable
        connect = connection()
        connect.c.execute("""SELECT MEM_USERNAME FROM MEMBER WHERE MEM_ID = '{}'""".format(self.MEM_ID))
        for row in connect.c:
            self.existID = row[0]
        connect.c.close()
        
        # compare existing username the same or not
        if self.existID != self.UserName_info:
            
            # sql to retireve all username
            connect = connection()
            connect.c.execute("""SELECT MEM_USERNAME FROM MEMBER""")
            for row in connect.c:
                self.idList.append(row[0])
            connect.c.close()
        # check if new username clash with others
        if self.UserName_info in self.idList:
            self.ErrorMessage.set('This username has been taken.')
            return
        
         # check if duplicate email
        # first store existing email in variable
        connect = connection()
        connect.c.execute("""SELECT MEM_EMAIL FROM MEMBER WHERE MEM_ID = '{}'""".format(self.MEM_ID))
        for row in connect.c:
            self.existEmail = row[0]
        connect.c.close()
        
        # compare existing email the same or not
        if self.existEmail != self.EMAIL_info:
            # sql to retireve all email
            connect = connection()
            connect.c.execute("""SELECT MEM_EMAIL FROM MEMBER""")
            for row in connect.c:
                self.emailList.append(row[0])
            connect.c.close()
        # check if new username clash with others
        if self.EMAIL_info in self.emailList:
            self.ErrorMessage.set('This email has been taken.')
            return
        
        
        
        # check whether string in mobile
        try:
            isinstance(int(self.MOBILE_info),int)
        except:
            self.ErrorMessage.set('Your mobile input is not valid.')
            return
        
        # SQL to update information
        connect = connection()
        connect.c.execute(
            """
                UPDATE MEMBER SET MEM_FNAME = '{}',MEM_MNAME = '{}',MEM_LNAME = '{}',MEM_EMAIL = '{}',
                MEM_USERNAME = '{}',MEM_PWD = '{}',MEM_MOBILE = '{}',MEM_ADD_LINE1 = '{}',MEM_ADD_LINE2 = '{}',
                MEM_ADD_COUNTRY = '{}',MEM_GENDER = '{}'
                WHERE MEM_ID = '{}'
            """.format(self.FName_info,self.MName_info,self.LName_info,self.EMAIL_info,self.UserName_info,self.PWD_info,
                      self.MOBILE_info,self.ADD_Line_1_info,self.ADD_Line_2_info,self.ADD_Country_info,self.GENDER_info,self.MEM_ID))
        connect.c.execute("commit")
        connect.c.close()

        # Clear all previous input
        self.FName.set('')
        self.MName.set('')
        self.LName.set('')
        self.UserName.set('')
        self.PWD.set('')
        self.Confirmed_PWD.set('')
        self.EMAIL.set('')
        self.MOBILE.set('')
        self.ADD_Line_1.set('')
        self.ADD_Line_2.set('')
        
        self.root.destroy()
        Update_Class(self.MEM_ID)

# %% [markdown]
# #### Update Personal Information Success Page [Finished]

# %%
class Update_Class:
    
    def __init__(self, MEM_ID):
        self.root1 = tk.Tk()
        self.root1.geometry('600x250')
        self.root1.title('Successful Update of Information')
        self.MEM_ID = MEM_ID

        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")

        label_CName = tk.Label(self.root1, text = "Super Clean", width = 20, font = self.CNametext).place(x = 150, y = 40)
        label1 = tk.Label(self.root1, text = 'Successful Update of Account Information', font = self.bodytext).place(x = 120, y = 90)
        but_back = tk.Button(self.root1,text = 'Confirm', font = "bold", fg = 'orange', width = 20,
                                command = self.back).place(x = 220, y = 160)

        self.root1.mainloop()

    def back(self):
        # Pass Customer ID
        self.root1.destroy()
        Main_Page_Class(self.MEM_ID)

# %% [markdown]
# #### Shopping Cart Page [Finished]

# %%
## Assume each page only display 5 items
class Shopping_Cart_Class:
    def __init__(self, MEM_ID, Selected_ls, first_row = 0):
        self.root = tk.Tk()
        self.root.geometry('850x690')
        self.root.title('Shopping Cart')
        self.MEM_ID = MEM_ID
        self.first_row = first_row
        self.item_ls = []; self.price_ls = []; self.quantity_ls = []; self.SPCT_ID_ls = []
        self.selected_ls = Selected_ls; self.PRO_inventory_ls = []; self.discount_ls = []
        self.pre_set()
        
        # declare variables
        self.selected1 = tk.IntVar(); self.selected2 = tk.IntVar(); self.selected3 = tk.IntVar()
        self.selected4 = tk.IntVar(); self.selected5 = tk.IntVar()
        self.removed1 = tk.IntVar(); self.removed2 = tk.IntVar(); self.removed3 = tk.IntVar()
        self.removed4 = tk.IntVar(); self.removed5 = tk.IntVar()
        self.PRO1Q = tk.StringVar(); self.PRO2Q = tk.StringVar(); self.PRO3Q = tk.StringVar()
        self.PRO4Q = tk.StringVar(); self.PRO5Q = tk.StringVar()
        self.PRO1ST = tk.StringVar(); self.PRO2ST = tk.StringVar(); self.PRO3ST = tk.StringVar()
        self.PRO4ST = tk.StringVar(); self.PRO5ST = tk.StringVar()
        self.PRO1ST_W = tk.StringVar(); self.PRO2ST_W = tk.StringVar(); self.PRO3ST_W = tk.StringVar();
        self.PRO4ST_W = tk.StringVar(); self.PRO5ST_W = tk.StringVar()
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        self.tinytext = tkFont.Font(family = "Courier", size = 12, weight = "bold")
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 800)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 650, 800, 120, fill = 'white')
        heading = canvas.create_rectangle(50, 120, 800, 148, fill = 'grey')
        
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Company Name
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)
        label_Introduction = tk.Label(self.root, text = "Shopping Cart", width = 20, font = self.bodytext, fg = 'blue').place(x = 340, y = 70)
        
        # Content
        label_item = tk.Label(self.root, text='Items',font=self.bodytext,bg='grey').place(x = 120, y = 124)
        label_price = tk.Label(self.root, text='Unit Price',font=self.bodytext,bg='grey').place(x = 260, y = 124)
        label_quantity = tk.Label(self.root, text='Quantity',font=self.bodytext,bg='grey').place(x = 400, y = 124)
        label_subtotal = tk.Label(self.root, text='Subtotal',font=self.bodytext,bg='grey').place(x = 550, y = 124)
        label_order = tk.Label(self.root, text='Select',font=self.bodytext,bg='grey').place(x = 680, y = 124)
        
        # display item list
        list_quantity = [1,2,3,5,4]

        # display the item name and price
        y_item = 180
        for i in range(5):
            if len(self.item_ls) >= i + 1:
                tk.Label(self.root, text = self.item_ls[i], width =15, font = self.bodytext).place(x = 80, y = y_item + 70 * i)
                tk.Label(self.root, text = round(self.price_ls[i] * (1 - self.discount_ls[i] / 100), 2), width = 8, font = self.bodytext).place(x = 270, y = y_item + 70 * i)

        # entry box of quantity and subtotal
        if len(self.price_ls) >= 1:
            self.entry_PRO1 = tk.Entry(self.root, textvariable = self.PRO1Q, width = 10)
            self.entry_PRO1.place(x = 395, y = 175)
            self.PRO1Q.set(int(self.quantity_ls[0]))
            self.PRO1ST_info = self.quantity_ls[0] * self.price_ls[0] * (1 - self.discount_ls[0] / 100)
            self.PRO1Q.trace_add('write', lambda *args: self.assign_Q(self.PRO1Q.get(), 1))
            self.label_PRO1ST = tk.Label(self.root, textvariable = self.PRO1ST, font = self.bodytext)
            self.label_PRO1ST.place(x = 560, y = 180)
            self.PRO1ST.set('$' + str(round(self.PRO1ST_info, 2)))
            self.label_PRO1ST_W = tk.Label(self.root, textvariable = self.PRO1ST_W, font = self.tinytext, fg = 'red')
            self.label_PRO1ST_W.place(x = 370, y = 210)
            self.PRO1ST_W.set('')
            if self.discount_ls[0] != 0:
                tk.Label(self.root, text = 'Enjoy ' + str(self.discount_ls[0]) + '% Discount', font = self.tinytext, fg = 'red').place(x = 580, y = 210)
            if len(self.price_ls) >= 2:
                self.entry_PRO2 = tk.Entry(self.root, textvariable = self.PRO2Q, width = 10)
                self.entry_PRO2.place(x = 395, y = 245)
                self.PRO2Q.set(self.quantity_ls[1])
                self.PRO2ST_info = self.quantity_ls[1] * self.price_ls[1] * (1 - self.discount_ls[1] / 100)
                self.PRO2Q.trace_add('write', lambda *args: self.assign_Q(self.PRO2Q.get(), 2))
                self.label_PRO2ST = tk.Label(self.root, textvariable = self.PRO2ST, font = self.bodytext)
                self.label_PRO2ST.place(x = 560, y = 250)
                self.PRO2ST.set('$' + str(round(self.PRO2ST_info, 2)))
                self.label_PRO2ST_W = tk.Label(self.root, textvariable = self.PRO2ST_W, font = self.tinytext, fg = 'red')
                self.label_PRO2ST_W.place(x = 370, y = 280)
                self.PRO2ST_W.set('')
                if self.discount_ls[1] != 0:
                    tk.Label(self.root, text = 'Enjoy ' + str(self.discount_ls[1]) + '% Discount', font = self.tinytext, fg = 'red').place(x = 580, y = 280)
                if len(self.price_ls) >= 3:
                    self.entry_PRO3 = tk.Entry(self.root, textvariable = self.PRO3Q, width = 10)
                    self.entry_PRO3.place(x = 395, y = 315)
                    self.PRO3Q.set(self.quantity_ls[2])
                    self.PRO3ST_info = self.quantity_ls[2] * self.price_ls[2] * (1 - self.discount_ls[2] / 100)
                    self.PRO3Q.trace_add('write', lambda *args: self.assign_Q(self.PRO3Q.get(), 3))
                    self.label_PRO3ST = tk.Label(self.root, textvariable = self.PRO3ST, font = self.bodytext)
                    self.label_PRO3ST.place(x = 560, y = 320)
                    self.PRO3ST.set('$' + str(round(self.PRO3ST_info, 2)))
                    self.label_PRO3ST_W = tk.Label(self.root, textvariable = self.PRO3ST_W, font = self.tinytext, fg = 'red')
                    self.label_PRO3ST_W.place(x = 370, y = 350)
                    self.PRO3ST_W.set('')
                    if self.discount_ls[2] != 0:
                        tk.Label(self.root, text = 'Enjoy ' + str(self.discount_ls[2]) + '% Discount', font = self.tinytext, fg = 'red').place(x = 580, y = 350)
                    if len(self.price_ls) >= 4:
                        self.entry_PRO4 = tk.Entry(self.root, textvariable = self.PRO4Q, width = 10)
                        self.entry_PRO4.place(x = 395, y = 385)
                        self.PRO4Q.set(self.quantity_ls[3])
                        self.PRO4ST_info = self.quantity_ls[3] * self.price_ls[3] * (1 - self.discount_ls[3] / 100)
                        self.PRO4Q.trace_add('write', lambda *args: self.assign_Q(self.PRO4Q.get(), 4))
                        self.label_PRO4ST = tk.Label(self.root, textvariable = self.PRO4ST, font = self.bodytext)
                        self.label_PRO4ST.place(x = 560, y = 390)
                        self.PRO4ST.set('$' + str(round(self.PRO4ST_info, 2)))
                        self.label_PRO4ST_W = tk.Label(self.root, textvariable = self.PRO4ST_W, font = self.tinytext, fg = 'red')
                        self.label_PRO4ST_W.place(x = 370, y = 420)
                        self.PRO4ST_W.set('')
                        if self.discount_ls[3] != 0:
                            tk.Label(self.root, text = 'Enjoy ' + str(self.discount_ls[3]) + '% Discount', font = self.tinytext, fg = 'red').place(x = 580, y = 420)
                        if len(self.price_ls) == 5:
                            self.entry_PRO5 = tk.Entry(self.root, textvariable = self.PRO5Q, width = 10)
                            self.entry_PRO5.place(x = 395, y = 455)
                            self.PRO5Q.set(self.quantity_ls[4])
                            self.PRO5ST_info = self.quantity_ls[4] * self.price_ls[4] * (1 - self.discount_ls[4] / 100)
                            self.PRO5Q.trace_add('write', lambda *args: self.assign_Q(self.PRO5Q.get(), 5))
                            self.label_PRO5ST = tk.Label(self.root, textvariable = self.PRO5ST, font = self.bodytext)
                            self.label_PRO5ST.place(x = 560, y = 460)
                            self.PRO5ST.set('$' + str(round(self.PRO5ST_info, 2)))
                            self.label_PRO5ST_W = tk.Label(self.root, textvariable = self.PRO5ST_W, font = self.tinytext, fg = 'red')
                            self.label_PRO5ST_W.place(x = 370, y = 490)
                            self.PRO5ST_W.set('')
                            if self.discount_ls[4] != 0:
                                tk.Label(self.root, text = 'Enjoy ' + str(self.discount_ls[4]) + '% Discount', font = self.tinytext, fg = 'red').place(x = 580, y = 490)
                
                
        # Checkbutton for selection for checkout       
        if len(self.price_ls) >= 1:
            self.check_PRO1 = tk.Checkbutton(self.root, variable = self.selected1)
            self.check_PRO1.place(x = 705 ,y = 180)
            if self.SPCT_ID_ls[0] in self.selected_ls: self.selected1.set(1)
            if self.PRO_inventory_ls[0] == 0:
                self.entry_PRO1.config(state = 'disabled')
                self.check_PRO1.configure(state = tk.DISABLED)
                self.PRO1ST_W.set('No Inventory available yet')
            else:
                if self.quantity_ls[0] > self.PRO_inventory_ls[0]: 
                    self.check_PRO1.configure(state = tk.DISABLED)
                    self.PRO1ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[0]))
            self.selected1.trace_add('write', lambda *args: self.assign_C(self.selected1.get(), 1))

                
            if len(self.price_ls) >= 2:    
                self.check_PRO2 = tk.Checkbutton(self.root, variable = self.selected2)
                self.check_PRO2.place(x = 705, y = 250)
                if self.SPCT_ID_ls[1] in self.selected_ls: self.selected2.set(1)
                if self.PRO_inventory_ls[1] == 0:
                    self.entry_PRO2.config(state = 'disabled')
                    self.check_PRO2.configure(state = tk.DISABLED)
                    self.PRO2ST_W.set('No Inventory available yet')   
                else:
                    if self.quantity_ls[1] > self.PRO_inventory_ls[1]: 
                        self.check_PRO2.configure(state = tk.DISABLED)
                        self.PRO2ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[1]))
                self.selected2.trace_add('write', lambda *args: self.assign_C(self.selected2.get(), 2))

                    
                if len(self.price_ls) >= 3:
                    self.check_PRO3 = tk.Checkbutton(self.root, variable = self.selected3)
                    self.check_PRO3.place(x = 706, y = 320)
                    if self.SPCT_ID_ls[2] in self.selected_ls: self.selected3.set(1)
                    if self.PRO_inventory_ls[2] == 0:
                        self.entry_PRO3.config(state = 'disabled')
                        self.check_PRO3.configure(state = tk.DISABLED)
                        self.PRO3ST_W.set('No Inventory available yet')  
                    else:
                        if self.quantity_ls[2] > self.PRO_inventory_ls[2]: 
                            self.check_PRO3.configure(state = tk.DISABLED)
                            self.PRO3ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[2]))
                    self.selected3.trace_add('write', lambda *args: self.assign_C(self.selected3.get(), 3))
                    
                    if len(self.price_ls) >= 4:
                        self.check_PRO4 = tk.Checkbutton(self.root, variable = self.selected4)
                        self.check_PRO4.place(x = 705, y = 390)
                        if self.SPCT_ID_ls[3] in self.selected_ls: self.selected4.set(1)
                        if self.PRO_inventory_ls[3] == 0:
                            self.entry_PRO4.config(state = 'disabled')
                            self.check_PRO4.configure(state = tk.DISABLED)
                            self.PRO4ST_W.set('No Inventory available yet')  
                        else:
                            if self.quantity_ls[3] > self.PRO_inventory_ls[3]: 
                                self.check_PRO4.configure(state = tk.DISABLED)
                                self.PRO4ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[3]))
                        self.selected4.trace_add('write', lambda *args: self.assign_C(self.selected4.get(), 4))
                        
                        if len(self.price_ls) == 5:
                            self.check_PRO5 = tk.Checkbutton(self.root, variable = self.selected5)
                            self.check_PRO5.place(x = 705, y = 460)
                            if self.SPCT_ID_ls[4] in self.selected_ls: self.selected5.set(1)
                            if self.PRO_inventory_ls[4] == 0:
                                self.entry_PRO5.config(state = 'disabled')
                                self.check_PRO5.configure(state = tk.DISABLED)
                                self.PRO5ST_W.set('No Inventory available yet') 
                            else:
                                if self.quantity_ls[4] > self.PRO_inventory_ls[4]: 
                                    self.check_PRO5.configure(state = tk.DISABLED)
                                    self.PRO5ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[4]))
                            self.selected5.trace_add('write', lambda *args: self.assign_C(self.selected5.get(), 5))
                    
        
        # Buttons
        if len(self.item_ls) != 0:
            But_checkout = tk.Button(self.root, text='Checkout', font = "bold", fg = 'orange', width = 18, command = self.checkout).place(x = 120,y = 600)
            But_delete = tk.Button(self.root, text='Delete', width = 18, command = self.delete, font="bold", fg = 'orange').place(x = 560,y = 600)
        
        But_back = tk.Button(self.root, text = 'Back to Main Page', width = 18,command=self.back, font = "bold", fg = 'orange').place(x = 340,y = 600)
        
        if self.remaining_row > 0:
            But_next = tk.Button(self.root, text = 'Next Page', width = 18, command = self.next_page, font = "bold", fg = 'orange').place(x = 560, y = 550)
        
        if self.first_row != 0:
            But_next = tk.Button(self.root, text = 'Previous Page', width = 18, command = self.previous_page, font = "bold", fg = 'orange').place(x = 120, y = 550)
        
        self.root.mainloop()
    
    def pre_set(self):
        connect = connection()
         
        # Retreive the total amount of Shooping Cart
        connect.c.execute(
            """
                SELECT COUNT(*)
                FROM PRODUCT, SHOPPING_CART
                WHERE SHOPPING_CART.PRODUCT_PRO_ID = PRODUCT.PRO_ID AND MEMBER_MEM_ID = '{}' AND PRO_AVA != 0
            """.format(self.MEM_ID, self.first_row))
        
        for row in connect.c:
            self.remaining_row = row[0] - self.first_row - 5

            
        # Retrieve Needed Shopping Cart Data
        connect.c.execute(
            """
                SELECT PRO_NAME, PRO_PRICE, PRO_DISCOUNT_RATE, SPCT_QUANTITY, SPCT_ID, PRO_INVENTORY
                FROM PRODUCT, SHOPPING_CART
                WHERE SHOPPING_CART.PRODUCT_PRO_ID = PRODUCT.PRO_ID AND MEMBER_MEM_ID = '{}' AND PRO_AVA != 0
                ORDER BY ROWNUM
                OFFSET {} ROWS FETCH NEXT 5 ROWS ONLY
            """.format(self.MEM_ID, self.first_row))

        for row in connect.c:
            self.item_ls.append(row[0])
            self.price_ls.append(row[1])
            self.discount_ls.append(row[2])
            self.quantity_ls.append(row[3])
            self.SPCT_ID_ls.append(row[4])
            self.PRO_inventory_ls.append(row[5])
        
        connect.c.close() 
    
    def assign_C(self, sv, PRO):
        if sv == 1:
            self.selected_ls.append(self.SPCT_ID_ls[PRO - 1])
        else:
            self.selected_ls.remove(self.SPCT_ID_ls[PRO - 1])
        
    def assign_Q(self, sv, PRO): # Retrieve the dropdown list value in Product Selection
        if PRO == 1:
            try: 
                self.PRO1Q_info = int(sv)
            except: 
                if self.selected1.get() == 1: self.check_PRO1.deselect()
                self.check_PRO1.configure(state = tk.DISABLED)
                self.PRO1ST_W.set('Please input an integer')
                return # Return non-int input
            if self.PRO1Q_info < 0:
                if self.selected1.get() == 1: self.check_PRO1.deselect()
                self.check_PRO1.configure(state = tk.DISABLED)
                self.PRO1ST_W.set('Quantity cannot be negative')
                return
            if self.PRO1Q_info == 0:
                if self.selected1.get() == 1: self.check_PRO1.deselect()
                self.check_PRO1.configure(state = tk.DISABLED)
                self.PRO1ST_W.set('Quantity cannot be zero')
                return
            if self.PRO1Q_info > self.PRO_inventory_ls[0]:
                self.PRO1ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[0]))
                if self.selected1.get() == 1: self.check_PRO1.deselect()
                self.check_PRO1.configure(state = tk.DISABLED)
                return
            else: 
                self.PRO1ST_W.set('')
                self.check_PRO1.configure(state = tk.NORMAL)
            self.PRO1ST_info = self.PRO1Q_info * self.price_ls[0] * (1 - self.discount_ls[0] / 100)
            self.PRO1ST.set('$' + str(round(self.PRO1ST_info, 2)))
            self.update_ProQ = self.PRO1Q_info
        if PRO == 2:
            try: 
                self.PRO2Q_info = int(sv)
            except: 
                if self.selected2.get() == 1: self.check_PRO2.deselect()
                self.check_PRO2.configure(state = tk.DISABLED)
                self.PRO2ST_W.set('Please input an integer')
                return # Return non-int input
            if self.PRO2Q_info < 0:
                if self.selected2.get() == 1: self.check_PRO2.deselect()
                self.check_PRO2.configure(state = tk.DISABLED)
                self.PRO2ST_W.set('Quantity cannot be negative')
                return
            if self.PRO2Q_info == 0:
                if self.selected2.get() == 1: self.check_PRO2.deselect()
                self.check_PRO2.configure(state = tk.DISABLED)
                self.PRO2ST_W.set('Quantity cannot be zero')
                return
            if self.PRO2Q_info > self.PRO_inventory_ls[1]:
                self.PRO2ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[1]))
                if self.selected2.get() == 1: self.check_PRO2.deselect()
                self.check_PRO2.configure(state = tk.DISABLED)
                return
            else: 
                self.PRO2ST_W.set('')
                self.check_PRO2.configure(state = tk.NORMAL)
            self.PRO2ST_info = self.PRO2Q_info * self.price_ls[1] * (1 - self.discount_ls[1] / 100)
            self.PRO2ST.set('$' + str(round(self.PRO2ST_info, 2)))
            self.update_ProQ = self.PRO2Q_info
        if PRO == 3:
            try: 
                self.PRO3Q_info = int(sv)
            except: 
                if self.selected3.get() == 1: self.check_PRO3.deselect()
                self.check_PRO3.configure(state = tk.DISABLED)
                self.PRO3ST_W.set('Please input an integer')
                return # Return non-int input
            if self.PRO3Q_info < 0:
                if self.selected3.get() == 1: self.check_PRO3.deselect()
                self.check_PRO3.configure(state = tk.DISABLED)
                self.PRO3ST_W.set('Quantity cannot be negative')
                return
            if self.PRO3Q_info == 0:
                if self.selected3.get() == 1: self.check_PRO3.deselect()
                self.check_PRO3.configure(state = tk.DISABLED)
                self.PRO3ST_W.set('Quantity cannot be zero')
                return
            if self.PRO3Q_info > self.PRO_inventory_ls[2]:
                self.PRO3ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[2]))
                if self.selected3.get() == 1: self.check_PRO3.deselect()
                self.check_PRO3.configure(state = tk.DISABLED)
                return
            else: 
                self.PRO3ST_W.set('')
                self.check_PRO3.configure(state = tk.NORMAL)
            self.PRO3ST_info = self.PRO3Q_info * self.price_ls[2] * (1 - self.discount_ls[2] / 100)
            self.PRO3ST.set('$'+ str(round(self.PRO3ST_info, 2)))
            self.update_ProQ = self.PRO3Q_info
        if PRO == 4:
            try: 
                self.PRO4Q_info = int(sv)
            except: 
                if self.selected4.get() == 1: self.check_PRO4.deselect()
                self.check_PRO4.configure(state = tk.DISABLED)
                self.PRO4ST_W.set('Please input an integer')
                return # Return non-int input
            if self.PRO4Q_info < 0:
                if self.selected4.get() == 1: self.check_PRO4.deselect()
                self.check_PRO4.configure(state = tk.DISABLED)
                self.PRO4ST_W.set('Quantity cannot be negative')
                return
            if self.PRO4Q_info == 0:
                if self.selected4.get() == 1: self.check_PRO4.deselect()
                self.check_PRO4.configure(state = tk.DISABLED)
                self.PRO4ST_W.set('Quantity cannot be zero')
                return
            if self.PRO4Q_info > self.PRO_inventory_ls[3]:
                self.PRO4ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[3]))
                if self.selected4.get() == 1: self.check_PRO4.deselect()
                self.check_PRO4.configure(state = tk.DISABLED)
                return
            else: 
                self.PRO4ST_W.set('')
                self.check_PRO4.configure(state = tk.NORMAL)
            self.PRO4ST_info = self.PRO4Q_info * self.price_ls[3] * (1 - self.discount_ls[3] / 100)
            self.PRO4ST.set('$'+ str(round(self.PRO4ST_info, 2)))
            self.update_ProQ = self.PRO4Q_info
        if PRO == 5:
            try: 
                self.PRO5Q_info = int(sv)
            except: 
                if self.selected5.get() == 1: self.check_PRO5.deselect()
                self.check_PRO5.configure(state = tk.DISABLED)
                self.PRO5ST_W.set('Please input an integer')
                return # Return non-int input
            if self.PRO5Q_info < 0: 
                if self.selected5.get() == 1: self.check_PRO5.deselect()
                self.check_PRO5.configure(state = tk.DISABLED)
                self.PRO5ST_W.set('Quantity cannot be negative')
                return
            if self.PRO5Q_info == 0: 
                if self.selected5.get() == 1: self.check_PRO5.deselect()
                self.check_PRO5.configure(state = tk.DISABLED)
                self.PRO5ST_W.set('Quantity cannot be zero')
                return
            if self.PRO5Q_info > self.PRO_inventory_ls[4]:
                self.PRO5ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[4]))
                if self.selected5.get() == 1: self.check_PRO5.deselect()
                self.check_PRO5.configure(state = tk.DISABLED)
                return
            else: 
                self.PRO5ST_W.set('')
                self.check_PRO5.configure(state = tk.NORMAL)
            self.PRO5ST_info = self.PRO5Q_info * self.price_ls[4] * (1 - self.discount_ls[4] / 100)
            self.PRO5ST.set('$'+ str(round(self.PRO5ST_info, 2)))
            self.update_ProQ = self.PRO5Q_info
        
        connect = connection()
        
        connect.c.execute(
            """
                UPDATE (SELECT *
                        FROM PRODUCT, SHOPPING_CART
                        WHERE SHOPPING_CART.PRODUCT_PRO_ID = PRODUCT.PRO_ID AND MEMBER_MEM_ID = '{}')
                SET SPCT_QUANTITY = {}
                WHERE SPCT_ID = '{}'
            """.format(self.MEM_ID, self.update_ProQ, self.SPCT_ID_ls[PRO - 1]))
        
        connect.c.execute("commit")
        connect.c.close()
    
    def checkout(self):
        self.root.destroy()
        if len(self.selected_ls) == 0:
            Shopping_Cart_Warning_Class(self.MEM_ID)
        else: Checkout_Class(self.MEM_ID, self.selected_ls)
    
    def back(self):
        self.root.destroy()
        Main_Page_Class(self.MEM_ID)
        
    def delete(self):
        if len(self.selected_ls) == 0:
            self.root.destroy()
            Shopping_Cart_Warning_Class(self.MEM_ID)
            
        else:   
            connect = connection()
            
            for i in self.selected_ls:
                connect.c.execute(
                    """
                        DELETE FROM SHOPPING_CART
                        WHERE SPCT_ID = '{}'
                    """.format(i))
                
            connect.c.execute("commit")
            connect.c.close()
    
            self.selected_ls = []
            self.root.destroy()
            Shopping_Cart_Class(self.MEM_ID, [], 0)
    
    def previous_page(self):
        self.root.destroy()
        Shopping_Cart_Class(self.MEM_ID, self.selected_ls, self.first_row - 5)
        
    def next_page(self):
        self.root.destroy()
        Shopping_Cart_Class(self.MEM_ID, self.selected_ls, self.first_row + 5)

# %%
## Assume each page only display 5 items
class Shopping_Cart_Class:
    def __init__(self, MEM_ID, Selected_ls, first_row = 0):
        self.root = tk.Tk()
        self.root.geometry('850x690')
        self.root.title('Shopping Cart')
        self.MEM_ID = MEM_ID
        self.first_row = first_row
        self.item_ls = []; self.price_ls = []; self.quantity_ls = []; self.SPCT_ID_ls = []
        self.selected_ls = Selected_ls; self.PRO_inventory_ls = []; self.discount_ls = []
        self.pre_set()
        
        # declare variables
        self.selected1 = tk.IntVar(); self.selected2 = tk.IntVar(); self.selected3 = tk.IntVar()
        self.selected4 = tk.IntVar(); self.selected5 = tk.IntVar()
        self.removed1 = tk.IntVar(); self.removed2 = tk.IntVar(); self.removed3 = tk.IntVar()
        self.removed4 = tk.IntVar(); self.removed5 = tk.IntVar()
        self.PRO1Q = tk.StringVar(); self.PRO2Q = tk.StringVar(); self.PRO3Q = tk.StringVar()
        self.PRO4Q = tk.StringVar(); self.PRO5Q = tk.StringVar()
        self.PRO1ST = tk.StringVar(); self.PRO2ST = tk.StringVar(); self.PRO3ST = tk.StringVar()
        self.PRO4ST = tk.StringVar(); self.PRO5ST = tk.StringVar()
        self.PRO1ST_W = tk.StringVar(); self.PRO2ST_W = tk.StringVar(); self.PRO3ST_W = tk.StringVar();
        self.PRO4ST_W = tk.StringVar(); self.PRO5ST_W = tk.StringVar()
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        self.tinytext = tkFont.Font(family = "Courier", size = 12, weight = "bold")
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 800)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 650, 800, 120, fill = 'white')
        heading = canvas.create_rectangle(50, 120, 800, 148, fill = 'grey')
        
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Company Name
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)
        label_Introduction = tk.Label(self.root, text = "Shopping Cart", width = 20, font = self.bodytext, fg = 'blue').place(x = 340, y = 70)
        
        # Content
        label_item = tk.Label(self.root, text='Items',font=self.bodytext,bg='grey').place(x = 120, y = 124)
        label_price = tk.Label(self.root, text='Unit Price',font=self.bodytext,bg='grey').place(x = 260, y = 124)
        label_quantity = tk.Label(self.root, text='Quantity',font=self.bodytext,bg='grey').place(x = 400, y = 124)
        label_subtotal = tk.Label(self.root, text='Subtotal',font=self.bodytext,bg='grey').place(x = 550, y = 124)
        label_order = tk.Label(self.root, text='Select',font=self.bodytext,bg='grey').place(x = 680, y = 124)
        
        # display item list
        list_quantity = [1,2,3,5,4]

        # display the item name and price
        y_item = 180
        for i in range(5):
            if len(self.item_ls) >= i + 1:
                tk.Label(self.root, text = self.item_ls[i], width =15, font = self.bodytext).place(x = 80, y = y_item + 70 * i)
                tk.Label(self.root, text = round(self.price_ls[i] * (1 - self.discount_ls[i] / 100), 2), width = 8, font = self.bodytext).place(x = 270, y = y_item + 70 * i)

        # entry box of quantity and subtotal
        if len(self.price_ls) >= 1:
            self.entry_PRO1 = tk.Entry(self.root, textvariable = self.PRO1Q, width = 10)
            self.entry_PRO1.place(x = 395, y = 175)
            self.PRO1Q.set(int(self.quantity_ls[0]))
            self.PRO1ST_info = self.quantity_ls[0] * self.price_ls[0] * (1 - self.discount_ls[0] / 100)
            self.PRO1Q.trace_add('write', lambda *args: self.assign_Q(self.PRO1Q.get(), 1))
            self.label_PRO1ST = tk.Label(self.root, textvariable = self.PRO1ST, font = self.bodytext)
            self.label_PRO1ST.place(x = 560, y = 180)
            self.PRO1ST.set('$' + str(round(self.PRO1ST_info, 2)))
            self.label_PRO1ST_W = tk.Label(self.root, textvariable = self.PRO1ST_W, font = self.tinytext, fg = 'red')
            self.label_PRO1ST_W.place(x = 370, y = 210)
            self.PRO1ST_W.set('')
            if self.discount_ls[0] != 0:
                tk.Label(self.root, text = 'Enjoy ' + str(self.discount_ls[0]) + '% Discount', font = self.tinytext, fg = 'red').place(x = 580, y = 210)
            if len(self.price_ls) >= 2:
                self.entry_PRO2 = tk.Entry(self.root, textvariable = self.PRO2Q, width = 10)
                self.entry_PRO2.place(x = 395, y = 245)
                self.PRO2Q.set(self.quantity_ls[1])
                self.PRO2ST_info = self.quantity_ls[1] * self.price_ls[1] * (1 - self.discount_ls[1] / 100)
                self.PRO2Q.trace_add('write', lambda *args: self.assign_Q(self.PRO2Q.get(), 2))
                self.label_PRO2ST = tk.Label(self.root, textvariable = self.PRO2ST, font = self.bodytext)
                self.label_PRO2ST.place(x = 560, y = 250)
                self.PRO2ST.set('$' + str(round(self.PRO2ST_info, 2)))
                self.label_PRO2ST_W = tk.Label(self.root, textvariable = self.PRO2ST_W, font = self.tinytext, fg = 'red')
                self.label_PRO2ST_W.place(x = 370, y = 280)
                self.PRO2ST_W.set('')
                if self.discount_ls[1] != 0:
                    tk.Label(self.root, text = 'Enjoy ' + str(self.discount_ls[1]) + '% Discount', font = self.tinytext, fg = 'red').place(x = 580, y = 280)
                if len(self.price_ls) >= 3:
                    self.entry_PRO3 = tk.Entry(self.root, textvariable = self.PRO3Q, width = 10)
                    self.entry_PRO3.place(x = 395, y = 315)
                    self.PRO3Q.set(self.quantity_ls[2])
                    self.PRO3ST_info = self.quantity_ls[2] * self.price_ls[2] * (1 - self.discount_ls[2] / 100)
                    self.PRO3Q.trace_add('write', lambda *args: self.assign_Q(self.PRO3Q.get(), 3))
                    self.label_PRO3ST = tk.Label(self.root, textvariable = self.PRO3ST, font = self.bodytext)
                    self.label_PRO3ST.place(x = 560, y = 320)
                    self.PRO3ST.set('$' + str(round(self.PRO3ST_info, 2)))
                    self.label_PRO3ST_W = tk.Label(self.root, textvariable = self.PRO3ST_W, font = self.tinytext, fg = 'red')
                    self.label_PRO3ST_W.place(x = 370, y = 350)
                    self.PRO3ST_W.set('')
                    if self.discount_ls[2] != 0:
                        tk.Label(self.root, text = 'Enjoy ' + str(self.discount_ls[2]) + '% Discount', font = self.tinytext, fg = 'red').place(x = 580, y = 350)
                    if len(self.price_ls) >= 4:
                        self.entry_PRO4 = tk.Entry(self.root, textvariable = self.PRO4Q, width = 10)
                        self.entry_PRO4.place(x = 395, y = 385)
                        self.PRO4Q.set(self.quantity_ls[3])
                        self.PRO4ST_info = self.quantity_ls[3] * self.price_ls[3] * (1 - self.discount_ls[3] / 100)
                        self.PRO4Q.trace_add('write', lambda *args: self.assign_Q(self.PRO4Q.get(), 4))
                        self.label_PRO4ST = tk.Label(self.root, textvariable = self.PRO4ST, font = self.bodytext)
                        self.label_PRO4ST.place(x = 560, y = 390)
                        self.PRO4ST.set('$' + str(round(self.PRO4ST_info, 2)))
                        self.label_PRO4ST_W = tk.Label(self.root, textvariable = self.PRO4ST_W, font = self.tinytext, fg = 'red')
                        self.label_PRO4ST_W.place(x = 370, y = 420)
                        self.PRO4ST_W.set('')
                        if self.discount_ls[3] != 0:
                            tk.Label(self.root, text = 'Enjoy ' + str(self.discount_ls[3]) + '% Discount', font = self.tinytext, fg = 'red').place(x = 580, y = 420)
                        if len(self.price_ls) == 5:
                            self.entry_PRO5 = tk.Entry(self.root, textvariable = self.PRO5Q, width = 10)
                            self.entry_PRO5.place(x = 395, y = 455)
                            self.PRO5Q.set(self.quantity_ls[4])
                            self.PRO5ST_info = self.quantity_ls[4] * self.price_ls[4] * (1 - self.discount_ls[4] / 100)
                            self.PRO5Q.trace_add('write', lambda *args: self.assign_Q(self.PRO5Q.get(), 5))
                            self.label_PRO5ST = tk.Label(self.root, textvariable = self.PRO5ST, font = self.bodytext)
                            self.label_PRO5ST.place(x = 560, y = 460)
                            self.PRO5ST.set('$' + str(round(self.PRO5ST_info, 2)))
                            self.label_PRO5ST_W = tk.Label(self.root, textvariable = self.PRO5ST_W, font = self.tinytext, fg = 'red')
                            self.label_PRO5ST_W.place(x = 370, y = 490)
                            self.PRO5ST_W.set('')
                            if self.discount_ls[4] != 0:
                                tk.Label(self.root, text = 'Enjoy ' + str(self.discount_ls[4]) + '% Discount', font = self.tinytext, fg = 'red').place(x = 580, y = 490)
                
                
        # Checkbutton for selection for checkout       
        if len(self.price_ls) >= 1:
            self.check_PRO1 = tk.Checkbutton(self.root, variable = self.selected1)
            self.check_PRO1.place(x = 705 ,y = 180)
            if self.SPCT_ID_ls[0] in self.selected_ls: self.selected1.set(1)
            if self.PRO_inventory_ls[0] == 0:
                self.entry_PRO1.config(state = 'disabled')
                self.check_PRO1.configure(state = tk.DISABLED)
                self.PRO1ST_W.set('No Inventory available yet')
            else:
                if self.quantity_ls[0] > self.PRO_inventory_ls[0]: 
                    self.check_PRO1.configure(state = tk.DISABLED)
                    self.PRO1ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[0]))
            self.selected1.trace_add('write', lambda *args: self.assign_C(self.selected1.get(), 1))

                
            if len(self.price_ls) >= 2:    
                self.check_PRO2 = tk.Checkbutton(self.root, variable = self.selected2)
                self.check_PRO2.place(x = 705, y = 250)
                if self.SPCT_ID_ls[1] in self.selected_ls: self.selected2.set(1)
                if self.PRO_inventory_ls[1] == 0:
                    self.entry_PRO2.config(state = 'disabled')
                    self.check_PRO2.configure(state = tk.DISABLED)
                    self.PRO2ST_W.set('No Inventory available yet')   
                else:
                    if self.quantity_ls[1] > self.PRO_inventory_ls[1]: 
                        self.check_PRO2.configure(state = tk.DISABLED)
                        self.PRO2ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[1]))
                self.selected2.trace_add('write', lambda *args: self.assign_C(self.selected2.get(), 2))

                    
                if len(self.price_ls) >= 3:
                    self.check_PRO3 = tk.Checkbutton(self.root, variable = self.selected3)
                    self.check_PRO3.place(x = 706, y = 320)
                    if self.SPCT_ID_ls[2] in self.selected_ls: self.selected3.set(1)
                    if self.PRO_inventory_ls[2] == 0:
                        self.entry_PRO3.config(state = 'disabled')
                        self.check_PRO3.configure(state = tk.DISABLED)
                        self.PRO3ST_W.set('No Inventory available yet')  
                    else:
                        if self.quantity_ls[2] > self.PRO_inventory_ls[2]: 
                            self.check_PRO3.configure(state = tk.DISABLED)
                            self.PRO3ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[2]))
                    self.selected3.trace_add('write', lambda *args: self.assign_C(self.selected3.get(), 3))
                    
                    if len(self.price_ls) >= 4:
                        self.check_PRO4 = tk.Checkbutton(self.root, variable = self.selected4)
                        self.check_PRO4.place(x = 705, y = 390)
                        if self.SPCT_ID_ls[3] in self.selected_ls: self.selected4.set(1)
                        if self.PRO_inventory_ls[3] == 0:
                            self.entry_PRO4.config(state = 'disabled')
                            self.check_PRO4.configure(state = tk.DISABLED)
                            self.PRO4ST_W.set('No Inventory available yet')  
                        else:
                            if self.quantity_ls[3] > self.PRO_inventory_ls[3]: 
                                self.check_PRO4.configure(state = tk.DISABLED)
                                self.PRO4ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[3]))
                        self.selected4.trace_add('write', lambda *args: self.assign_C(self.selected4.get(), 4))
                        
                        if len(self.price_ls) == 5:
                            self.check_PRO5 = tk.Checkbutton(self.root, variable = self.selected5)
                            self.check_PRO5.place(x = 705, y = 460)
                            if self.SPCT_ID_ls[4] in self.selected_ls: self.selected5.set(1)
                            if self.PRO_inventory_ls[4] == 0:
                                self.entry_PRO5.config(state = 'disabled')
                                self.check_PRO5.configure(state = tk.DISABLED)
                                self.PRO5ST_W.set('No Inventory available yet') 
                            else:
                                if self.quantity_ls[4] > self.PRO_inventory_ls[4]: 
                                    self.check_PRO5.configure(state = tk.DISABLED)
                                    self.PRO5ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[4]))
                            self.selected5.trace_add('write', lambda *args: self.assign_C(self.selected5.get(), 5))
                    
        
        # Buttons
        if len(self.item_ls) != 0:
            But_checkout = tk.Button(self.root, text='Checkout', font = "bold", fg = 'orange', width = 18, command = self.checkout).place(x = 120,y = 600)
            But_delete = tk.Button(self.root, text='Delete', width = 18, command = self.delete, font="bold", fg = 'orange').place(x = 560,y = 600)
        
        But_back = tk.Button(self.root, text = 'Back to Main Page', width = 18,command=self.back, font = "bold", fg = 'orange').place(x = 340,y = 600)
        
        if self.remaining_row > 0:
            But_next = tk.Button(self.root, text = 'Next Page', width = 18, command = self.next_page, font = "bold", fg = 'orange').place(x = 560, y = 550)
        
        if self.first_row != 0:
            But_next = tk.Button(self.root, text = 'Previous Page', width = 18, command = self.previous_page, font = "bold", fg = 'orange').place(x = 120, y = 550)
        
        self.root.mainloop()
    
    def pre_set(self):
        connect = connection()
         
        # Retreive the total amount of Shooping Cart
        connect.c.execute(
            """
                SELECT COUNT(*)
                FROM PRODUCT, SHOPPING_CART
                WHERE SHOPPING_CART.PRODUCT_PRO_ID = PRODUCT.PRO_ID AND MEMBER_MEM_ID = '{}' AND PRO_AVA != 0
            """.format(self.MEM_ID, self.first_row))
        
        for row in connect.c:
            self.remaining_row = row[0] - self.first_row - 5

            
        # Retrieve Needed Shopping Cart Data
        connect.c.execute(
            """
                SELECT PRO_NAME, PRO_PRICE, PRO_DISCOUNT_RATE, SPCT_QUANTITY, SPCT_ID, PRO_INVENTORY
                FROM PRODUCT, SHOPPING_CART
                WHERE SHOPPING_CART.PRODUCT_PRO_ID = PRODUCT.PRO_ID AND MEMBER_MEM_ID = '{}' AND PRO_AVA != 0
                ORDER BY ROWNUM
                OFFSET {} ROWS FETCH NEXT 5 ROWS ONLY
            """.format(self.MEM_ID, self.first_row))

        for row in connect.c:
            self.item_ls.append(row[0])
            self.price_ls.append(row[1])
            self.discount_ls.append(row[2])
            self.quantity_ls.append(row[3])
            self.SPCT_ID_ls.append(row[4])
            self.PRO_inventory_ls.append(row[5])
        
        connect.c.close() 
    
    def assign_C(self, sv, PRO):
        if sv == 1:
            self.selected_ls.append(self.SPCT_ID_ls[PRO - 1])
        else:
            self.selected_ls.remove(self.SPCT_ID_ls[PRO - 1])
        
    def assign_Q(self, sv, PRO): # Retrieve the dropdown list value in Product Selection
        if PRO == 1:
            try: 
                self.PRO1Q_info = int(sv)
            except: 
                if self.selected1.get() == 1: self.check_PRO1.deselect()
                self.check_PRO1.configure(state = tk.DISABLED)
                self.PRO1ST_W.set('Please input an integer')
                return # Return non-int input
            if self.PRO1Q_info < 0:
                if self.selected1.get() == 1: self.check_PRO1.deselect()
                self.check_PRO1.configure(state = tk.DISABLED)
                self.PRO1ST_W.set('Quantity cannot be negative')
                return
            if self.PRO1Q_info == 0:
                if self.selected1.get() == 1: self.check_PRO1.deselect()
                self.check_PRO1.configure(state = tk.DISABLED)
                self.PRO1ST_W.set('Quantity cannot be zero')
                return
            if self.PRO1Q_info > self.PRO_inventory_ls[0]:
                self.PRO1ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[0]))
                if self.selected1.get() == 1: self.check_PRO1.deselect()
                self.check_PRO1.configure(state = tk.DISABLED)
                return
            else: 
                self.PRO1ST_W.set('')
                self.check_PRO1.configure(state = tk.NORMAL)
            self.PRO1ST_info = self.PRO1Q_info * self.price_ls[0] * (1 - self.discount_ls[0] / 100)
            self.PRO1ST.set('$' + str(round(self.PRO1ST_info, 2)))
            self.update_ProQ = self.PRO1Q_info
        if PRO == 2:
            try: 
                self.PRO2Q_info = int(sv)
            except: 
                if self.selected2.get() == 1: self.check_PRO2.deselect()
                self.check_PRO2.configure(state = tk.DISABLED)
                self.PRO2ST_W.set('Please input an integer')
                return # Return non-int input
            if self.PRO2Q_info < 0:
                if self.selected2.get() == 1: self.check_PRO2.deselect()
                self.check_PRO2.configure(state = tk.DISABLED)
                self.PRO2ST_W.set('Quantity cannot be negative')
                return
            if self.PRO2Q_info == 0:
                if self.selected2.get() == 1: self.check_PRO2.deselect()
                self.check_PRO2.configure(state = tk.DISABLED)
                self.PRO2ST_W.set('Quantity cannot be zero')
                return
            if self.PRO2Q_info > self.PRO_inventory_ls[1]:
                self.PRO2ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[1]))
                if self.selected2.get() == 1: self.check_PRO2.deselect()
                self.check_PRO2.configure(state = tk.DISABLED)
                return
            else: 
                self.PRO2ST_W.set('')
                self.check_PRO2.configure(state = tk.NORMAL)
            self.PRO2ST_info = self.PRO2Q_info * self.price_ls[1] * (1 - self.discount_ls[1] / 100)
            self.PRO2ST.set('$' + str(round(self.PRO2ST_info, 2)))
            self.update_ProQ = self.PRO2Q_info
        if PRO == 3:
            try: 
                self.PRO3Q_info = int(sv)
            except: 
                if self.selected3.get() == 1: self.check_PRO3.deselect()
                self.check_PRO3.configure(state = tk.DISABLED)
                self.PRO3ST_W.set('Please input an integer')
                return # Return non-int input
            if self.PRO3Q_info < 0:
                if self.selected3.get() == 1: self.check_PRO3.deselect()
                self.check_PRO3.configure(state = tk.DISABLED)
                self.PRO3ST_W.set('Quantity cannot be negative')
                return
            if self.PRO3Q_info == 0:
                if self.selected3.get() == 1: self.check_PRO3.deselect()
                self.check_PRO3.configure(state = tk.DISABLED)
                self.PRO3ST_W.set('Quantity cannot be zero')
                return
            if self.PRO3Q_info > self.PRO_inventory_ls[2]:
                self.PRO3ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[2]))
                if self.selected3.get() == 1: self.check_PRO3.deselect()
                self.check_PRO3.configure(state = tk.DISABLED)
                return
            else: 
                self.PRO3ST_W.set('')
                self.check_PRO3.configure(state = tk.NORMAL)
            self.PRO3ST_info = self.PRO3Q_info * self.price_ls[2] * (1 - self.discount_ls[2] / 100)
            self.PRO3ST.set('$'+ str(round(self.PRO3ST_info, 2)))
            self.update_ProQ = self.PRO3Q_info
        if PRO == 4:
            try: 
                self.PRO4Q_info = int(sv)
            except: 
                if self.selected4.get() == 1: self.check_PRO4.deselect()
                self.check_PRO4.configure(state = tk.DISABLED)
                self.PRO4ST_W.set('Please input an integer')
                return # Return non-int input
            if self.PRO4Q_info < 0:
                if self.selected4.get() == 1: self.check_PRO4.deselect()
                self.check_PRO4.configure(state = tk.DISABLED)
                self.PRO4ST_W.set('Quantity cannot be negative')
                return
            if self.PRO4Q_info == 0:
                if self.selected4.get() == 1: self.check_PRO4.deselect()
                self.check_PRO4.configure(state = tk.DISABLED)
                self.PRO4ST_W.set('Quantity cannot be zero')
                return
            if self.PRO4Q_info > self.PRO_inventory_ls[3]:
                self.PRO4ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[3]))
                if self.selected4.get() == 1: self.check_PRO4.deselect()
                self.check_PRO4.configure(state = tk.DISABLED)
                return
            else: 
                self.PRO4ST_W.set('')
                self.check_PRO4.configure(state = tk.NORMAL)
            self.PRO4ST_info = self.PRO4Q_info * self.price_ls[3] * (1 - self.discount_ls[3] / 100)
            self.PRO4ST.set('$'+ str(round(self.PRO4ST_info, 2)))
            self.update_ProQ = self.PRO4Q_info
        if PRO == 5:
            try: 
                self.PRO5Q_info = int(sv)
            except: 
                if self.selected5.get() == 1: self.check_PRO5.deselect()
                self.check_PRO5.configure(state = tk.DISABLED)
                self.PRO5ST_W.set('Please input an integer')
                return # Return non-int input
            if self.PRO5Q_info < 0: 
                if self.selected5.get() == 1: self.check_PRO5.deselect()
                self.check_PRO5.configure(state = tk.DISABLED)
                self.PRO5ST_W.set('Quantity cannot be negative')
                return
            if self.PRO5Q_info == 0: 
                if self.selected5.get() == 1: self.check_PRO5.deselect()
                self.check_PRO5.configure(state = tk.DISABLED)
                self.PRO5ST_W.set('Quantity cannot be zero')
                return
            if self.PRO5Q_info > self.PRO_inventory_ls[4]:
                self.PRO5ST_W.set('Maxium quantity = ' + str(self.PRO_inventory_ls[4]))
                if self.selected5.get() == 1: self.check_PRO5.deselect()
                self.check_PRO5.configure(state = tk.DISABLED)
                return
            else: 
                self.PRO5ST_W.set('')
                self.check_PRO5.configure(state = tk.NORMAL)
            self.PRO5ST_info = self.PRO5Q_info * self.price_ls[4] * (1 - self.discount_ls[4] / 100)
            self.PRO5ST.set('$'+ str(round(self.PRO5ST_info, 2)))
            self.update_ProQ = self.PRO5Q_info
        
        connect = connection()
        
        connect.c.execute(
            """
                UPDATE (SELECT *
                        FROM PRODUCT, SHOPPING_CART
                        WHERE SHOPPING_CART.PRODUCT_PRO_ID = PRODUCT.PRO_ID AND MEMBER_MEM_ID = '{}')
                SET SPCT_QUANTITY = {}
                WHERE SPCT_ID = '{}'
            """.format(self.MEM_ID, self.update_ProQ, self.SPCT_ID_ls[PRO - 1]))
        
        connect.c.execute("commit")
        connect.c.close()
    
    def checkout(self):
        self.root.destroy()
        if len(self.selected_ls) == 0:
            Shopping_Cart_Warning_Class(self.MEM_ID)
        else: Checkout_Class(self.MEM_ID, self.selected_ls)
    
    def back(self):
        self.root.destroy()
        Main_Page_Class(self.MEM_ID)
        
    def delete(self):
        if len(self.selected_ls) == 0:
            self.root.destroy()
            Shopping_Cart_Warning_Class(self.MEM_ID)
            
        else:   
            connect = connection()
            
            for i in self.selected_ls:
                connect.c.execute(
                    """
                        DELETE FROM SHOPPING_CART
                        WHERE SPCT_ID = '{}'
                    """.format(i))
                
            connect.c.execute("commit")
            connect.c.close()
    
            self.selected_ls = []
            self.root.destroy()
            Shopping_Cart_Class(self.MEM_ID, [], 0)
    
    def previous_page(self):
        self.root.destroy()
        Shopping_Cart_Class(self.MEM_ID, self.selected_ls, self.first_row - 5)
        
    def next_page(self):
        self.root.destroy()
        Shopping_Cart_Class(self.MEM_ID, self.selected_ls, self.first_row + 5)

# %%
class Shopping_Cart_Warning_Class:
    def __init__(self, MEM_ID):
        self.root = tk.Tk()
        self.root.geometry('350x200')
        self.root.title('Warning')
        self.MEM_ID = MEM_ID

        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 20, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        
        tk.Label(self.root, text = 'Nothing has selected!!!', font = self.Titletext).place(x = 40, y = 70)
        tk.Button(self.root, text='Back', width = 18, command= self.back, font="bold", fg = 'orange').place(x = 90,y = 140)
        
        self.root.mainloop()
        
    def back(self):
        self.root.destroy()
        Shopping_Cart_Class(self.MEM_ID, [], 0)

# %% [markdown]
# #### Check out  [Finished]

# %%
class Checkout_Class:
    def __init__(self, MEM_ID, Selected_ls):
        global MEMBER
        self.root = tk.Tk()
        self.root.geometry('850x600')
        self.root.title('Checkout Page')
        self.MEM_ID = MEM_ID; self.ODL_ID_ls = []; self.selected_ls = Selected_ls;
        self.no_of_PRO = len(self.selected_ls); self.odl_quantity_ls = []; self.odl_price_ls = []; self.odl_pro_id_ls = []
        self.retrieve_personal_information()
        
        # Create custom font
        self.CNametext = tkFont.Font(family = "Courier", size = 25, weight = "bold")
        self.Titletext = tkFont.Font(family = "Courier", size = 15, weight = "bold")
        self.bodytext = tkFont.Font(family = "Courier", size = 13, weight = "bold")
        self.tinytext = tkFont.Font(family = "Courier", size = 13, weight = "bold")
        
        # Background Design
        canvas = tk.Canvas(self.root, width = 850, height = 700)
        canvas.place(x = 0, y = 0)
        rectangle = canvas.create_rectangle(50, 106, 800, 520, fill = 'white')
        label_CName = tk.Label(self.root, text = "Super Clean", width = 20, font = self.CNametext).place(x = 270, y = 40)
        label_Introduction = tk.Label(self.root, text = "Check Out", width = 20, font = self.Titletext, fg = 'blue').place(x = 340, y = 70)
        
        # Logo
        self.logo = Image.open(get_image('logo.jpg')) 
        self.logo = self.logo.resize((150, 100), Image.ANTIALIAS)
        self.photo_logo = ImageTk.PhotoImage(self.logo)
        label_Logo = tk.Label(image = self.photo_logo)
        label_Logo.place(x = 50,y = 0)
        
        # Declare Variables
        self.FName = tk.StringVar()
        self.MName = tk.StringVar()
        self.LName = tk.StringVar()
        self.MOBILE = tk.StringVar()
        self.ADD_Line_1 = tk.StringVar()
        self.ADD_Line_2 = tk.StringVar()
        self.ADD_Country = tk.StringVar()
        self.Card = tk.StringVar()
        self.CardNo = tk.StringVar();self.errorMessage= tk.StringVar();self.errorMessage.set('')
        
        # Labels
        tk.Label(self.root, text = '1. Delivery Details',font = self.Titletext).place(x = 52, y = 120)
        tk.Label(self.root, text = 'Delivery Address', font = self.bodytext).place(x = 52,y = 220)
        tk.Label(self.root, text = self.address_l1, font = self.tinytext).place(x = 90, y = 240)
        tk.Label(self.root, text = self.address_l2, font = self.tinytext).place(x = 90, y = 260)
        tk.Label(self.root, text = self.address_country, font = self.tinytext).place(x = 90, y = 280)
        tk.Label(self.root, text = 'Recipient Information',font = self.bodytext).place(x = 52, y = 140)
        tk.Label(self.root, text = self.wname, font = self.tinytext).place(x = 90, y = 160)
        tk.Label(self.root, text = '2. Payment Method', font = self.Titletext).place(x = 52, y = 340)

        # Payment Method Choose
        radio_VISA = tk.Radiobutton(self.root, text = 'VISA', variable = self.Card, value = 'Visa').place(x = 70, y = 380)
        radio_MASTER = tk.Radiobutton(self.root, text = 'MASTERCARD', variable = self.Card, value = 'MasterCard').place(x = 200, y = 380)
        
        # Card Number
        tk.Label(self.root, text = 'Card Number').place(x = 70, y = 410)
        entry1 = tk.Entry(self.root, textvariable = self.CardNo, width=50).place(x=170,y=410)
        
        # ErrorMessageEmpty
        errorMessage = tk.Label(self.root, textvariable=self.errorMessage,font= self.bodytext, fg = 'red').place(x=170,y=440)
        
        # Buttons
        But_confirm = tk.Button(self.root, text='Confirm Payment', command=self.confirm, width=25, font = "bold", fg = 'orange').place(x=180,y=480)
        But_back = tk.Button(self.root, text='Back to Shopping Cart', width=25,command=self.back, font = "bold", fg = 'orange').place(x=420,y=480)
        
        self.root.mainloop()
 
    def retrieve_personal_information(self):
        connect = connection()
         
        connect.c.execute(
            """
                SELECT MEM_FNAME, MEM_MNAME, MEM_LNAME, MEM_ADD_LINE1, MEM_ADD_LINE2, MEM_ADD_COUNTRY
                FROM MEMBER
                WHERE MEM_ID = '{}'
            """.format(self.MEM_ID))
        
        for row in connect.c:
            self.fname = row[0]
            self.mname = row[1]
            self.lname = row[2]
            self.address_l1 = row[3]
            self.address_l2 = row[4]
            self.address_country = row[5]
        
        if self.mname is not None:
            self.wname = "{} {} {}".format(self.fname, self.mname, self.lname)
        else:
            self.wname = "{} {}".format(self.fname ,self.lname)
            
        connect.c.close() 
    
    def retrieve_Order_information(self):
        # TODO
        connect = connection()

        # Generate new ORD_ID
        connect.c.execute(
            """
                SELECT ORD_ID 
                FROM "ORDER"
            """)

        ls_ID = []
        for row in connect.c:
            ls_ID.append(int(row[0]))
            
        for i in range(len(ls_ID) + 1):
            if i not in ls_ID:
                self.ORD_ID = i
                break
        
        self.ORD_DATE = datetime.date.today()
        
        # Generate new ODL_ID (a list)
        for i in range(self.no_of_PRO):
            connect.c.execute(
                """
                    SELECT ODL_ID 
                    FROM ORDER_LINE
                """)

            ls_ID = []
            for row in connect.c:
                ls_ID.append(int(row[0]))

            i = 0
            while True:
                if i not in ls_ID and i not in self.ODL_ID_ls:
                    self.ODL_ID_ls.append(i)
                    break
                i += 1
        
        # Get Order line data
        for i in self.selected_ls:
            connect.c.execute(
                """
                  SELECT SPCT_QUANTITY, PRO_PRICE, PRO_DISCOUNT_RATE, PRODUCT_PRO_ID
                  FROM SHOPPING_CART, PRODUCT
                  WHERE SHOPPING_CART.PRODUCT_PRO_ID = PRODUCT.PRO_ID AND SPCT_ID = '{}'
                """.format(i))
            
            for row in connect.c:
                self.odl_quantity_ls.append(row[0])
                self.odl_price_ls.append(round(row[1] * (1 - row[2] / 100), 2))
                self.odl_pro_id_ls.append(row[3])
                
        connect.c.close()
        
    def confirm(self):
        self.CardNo_info = self.CardNo.get()
        # Prevent selecting multiple values together
        if self.Card.get() == '':
            self.errorMessage.set("Please select the card type.")
            return
        
        elif self.CardNo.get() == '':
            self.errorMessage.set("Please enter your 16-digit card number.")
            return
        
        elif len(self.CardNo_info) != 16:
            self.errorMessage.set("Invalid input! Please enter a 16-digit card number.")
            return
        self.retrieve_Order_information()
        connect = connection()
        
        # Insert Data into ORDER
        connect.c.execute(
            """
              INSERT INTO "ORDER"
              VALUES ('{}', SYSDATE, 'Preparation', '{}')
            """.format(self.ORD_ID, self.MEM_ID))
        
        connect.c.execute("commit")
        
        # Insert Date into ORDER_LINE
        for i in range(self.no_of_PRO):
            connect.c.execute(
                """
                  INSERT INTO ORDER_LINE
                  VALUES ('{}', {}, '{}', '{}', '{}')
                """.format(self.ODL_ID_ls[i], self.odl_quantity_ls[i], self.odl_price_ls[i], self.ORD_ID, self.odl_pro_id_ls[i]))
        
            connect.c.execute("commit")
            
            connect.c.execute(
                """
                  DELETE FROM SHOPPING_CART 
                  WHERE SPCT_ID = '{}'
                """.format(self.selected_ls[i]))
            
            connect.c.execute("commit")
            
            connect.c.execute(
                """
                  SELECT PRO_INVENTORY
                  FROM PRODUCT
                  WHERE PRO_ID = '{}'
                """.format(self.odl_pro_id_ls[i]))
            
            for row in connect.c:
                self.ori_inventory = row[0]
            
            connect.c.execute(
                """
                  UPDATE PRODUCT
                  SET PRO_INVENTORY = '{}'
                  WHERE PRO_ID = '{}'
                """.format(self.ori_inventory - self.odl_quantity_ls[i], self.odl_pro_id_ls[i]))
        
            connect.c.execute("commit")
        
        
        connect.c.close()
        
        # Clear all previous input
        self.CardNo.set('')
        
        self.root.destroy()
        Main_Page_Class(self.MEM_ID)
          
    def back(self):
        self.root.destroy()
        Shopping_Cart_Class(self.MEM_ID, self.selected_ls, 0)
